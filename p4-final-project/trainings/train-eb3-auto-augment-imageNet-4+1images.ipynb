# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
from autoaugment import ImageNetPolicy

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    #tf.config.experimental.set_virtual_device_configuration(d,
    #    [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10240)])
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = './'
  data_dir = './datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    auto_augmentation_policy = ImageNetPolicy()
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-auto-aug/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-auto-aug.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 120
    learning_rate = .01

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-auto-aug-ft/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-auto-aug-ft.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image
from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
#%%time
#%%bash

#  if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
#    mkdir -p /root/tensorflow_datasets/amazon-from-space/

#    gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
    # If the above is not working:
    # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
    #    /root/tensorflow_datasets/amazon-from-space/
#  else
#    echo "Dir $data_path found. Skipping."
#  fi

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (tf.numpy_function(auto_augment_fn, [image], tf.uint8)
           if augment
           else default_policy_fn(image))
  #image = tf.ensure_shape(image, Config.data.shape)
  if augment:
    image = tf.ensure_shape(image, (5, *Config.data.shape))
  else:
    image = tf.ensure_shape(image, Config.data.shape)

  #image = (augment_policy_fn(image)
  #         if augment
  #         else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  if augment:
    return image, tf.reshape(tf.tile(labels_to_one_hot(labels), [5]), (5, 17))
  else:
    return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  if augment:
    return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
              .unbatch()
              .shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed + 1)
              .batch(batch_size, drop_remainder=True)
              .prefetch(Config.data.prefetch_buffer_size))
  else:
    return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
              .batch(batch_size, drop_remainder=True)
              .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image

def auto_augment_fn(image):
  #image = Image.fromarray(np.uint8(image))
  #image = Config.aug.auto_augmentation_policy(image)
  #image = np.asarray(image)
  image = Image.fromarray(np.uint8(image))
  #(8, 256, 256, 3)
  images = [np.asarray(Config.aug.auto_augmentation_policy(image)) for _ in range(4)]
  images.append(np.asarray(image))

  return np.asarray(images)


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.uint8, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

from pathlib import Path

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples*5 // Config.data.batch_size, # Multiplicar num_train_samples pelo número de novas imagens geradas (Ex. 8)
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# Overriding previous training at .//logs/amazon-from-space-mo444/eb6-ce-auto-aug/.
# Epoch 1/80
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 2213/2213 [==============================] - ETA: 0s - loss: 0.2186 - precision: 0.8681 - recall: 0.7122 - f1_score: 0.0623 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.7779
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# 2213/2213 [==============================] - 249s 108ms/step - loss: 0.2186 - precision: 0.8681 - recall: 0.7122 - f1_score: 0.0623 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.7779 - val_loss: 0.1963 - val_precision: 0.8696 - val_recall: 0.6957 - val_f1_score: 0.0569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8027
#
# Epoch 00001: val_loss improved from inf to 0.19630, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 2/80
# 2213/2213 [==============================] - 240s 108ms/step - loss: 0.1991 - precision: 0.8706 - recall: 0.7093 - f1_score: 0.0587 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8089 - val_loss: 0.1943 - val_precision: 0.8822 - val_recall: 0.6884 - val_f1_score: 0.0567 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8136
#
# Epoch 00002: val_loss improved from 0.19630 to 0.19425, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 3/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1972 - precision: 0.8710 - recall: 0.7089 - f1_score: 0.0585 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8163 - val_loss: 0.1905 - val_precision: 0.8779 - val_recall: 0.7076 - val_f1_score: 0.0571 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8118
#
# Epoch 00003: val_loss improved from 0.19425 to 0.19051, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 4/80
# 2213/2213 [==============================] - 239s 107ms/step - loss: 0.1969 - precision: 0.8711 - recall: 0.7089 - f1_score: 0.0585 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8176 - val_loss: 0.1920 - val_precision: 0.8623 - val_recall: 0.7126 - val_f1_score: 0.0567 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8134
#
# Epoch 00004: val_loss did not improve from 0.19051
# Epoch 5/80
# 2213/2213 [==============================] - 240s 107ms/step - loss: 0.1967 - precision: 0.8711 - recall: 0.7082 - f1_score: 0.0585 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8208 - val_loss: 0.1926 - val_precision: 0.8632 - val_recall: 0.7152 - val_f1_score: 0.0570 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8212
#
# Epoch 00005: val_loss did not improve from 0.19051
# Epoch 6/80
# 2213/2213 [==============================] - 236s 106ms/step - loss: 0.1965 - precision: 0.8713 - recall: 0.7088 - f1_score: 0.0582 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8171 - val_loss: 0.1914 - val_precision: 0.8839 - val_recall: 0.7093 - val_f1_score: 0.0572 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8038
#
# Epoch 00006: val_loss did not improve from 0.19051
# Epoch 7/80
# 2213/2213 [==============================] - 236s 106ms/step - loss: 0.1966 - precision: 0.8711 - recall: 0.7088 - f1_score: 0.0585 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8116 - val_loss: 0.1915 - val_precision: 0.8713 - val_recall: 0.7125 - val_f1_score: 0.0569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8124
#
# Epoch 00007: val_loss did not improve from 0.19051
# Epoch 8/80
# 2213/2213 [==============================] - 239s 107ms/step - loss: 0.1964 - precision: 0.8713 - recall: 0.7086 - f1_score: 0.0585 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8095 - val_loss: 0.1914 - val_precision: 0.8801 - val_recall: 0.7029 - val_f1_score: 0.0581 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8115
#
# Epoch 00008: val_loss did not improve from 0.19051
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# Epoch 9/80
# 2213/2213 [==============================] - 236s 105ms/step - loss: 0.1960 - precision: 0.8708 - recall: 0.7077 - f1_score: 0.0581 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8028 - val_loss: 0.1900 - val_precision: 0.8657 - val_recall: 0.7039 - val_f1_score: 0.0569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8064
#
# Epoch 00009: val_loss improved from 0.19051 to 0.19003, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 10/80
# 2213/2213 [==============================] - 238s 107ms/step - loss: 0.1959 - precision: 0.8707 - recall: 0.7078 - f1_score: 0.0580 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8012 - val_loss: 0.1892 - val_precision: 0.8751 - val_recall: 0.7192 - val_f1_score: 0.0575 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8060
#
# Epoch 00010: val_loss improved from 0.19003 to 0.18922, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 11/80
# 2213/2213 [==============================] - 241s 108ms/step - loss: 0.1958 - precision: 0.8712 - recall: 0.7079 - f1_score: 0.0578 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8025 - val_loss: 0.1901 - val_precision: 0.8757 - val_recall: 0.7023 - val_f1_score: 0.0567 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8032
#
# Epoch 00011: val_loss did not improve from 0.18922
# Epoch 12/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1960 - precision: 0.8711 - recall: 0.7081 - f1_score: 0.0579 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8000 - val_loss: 0.1913 - val_precision: 0.8654 - val_recall: 0.7103 - val_f1_score: 0.0571 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8050
#
# Epoch 00012: val_loss did not improve from 0.18922
# Epoch 13/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1958 - precision: 0.8711 - recall: 0.7079 - f1_score: 0.0579 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8019 - val_loss: 0.1901 - val_precision: 0.8762 - val_recall: 0.7016 - val_f1_score: 0.0573 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8112
#
# Epoch 00013: val_loss did not improve from 0.18922
# Epoch 14/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1959 - precision: 0.8713 - recall: 0.7076 - f1_score: 0.0579 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8025 - val_loss: 0.1896 - val_precision: 0.8773 - val_recall: 0.7059 - val_f1_score: 0.0578 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8055
#
# Epoch 00014: val_loss did not improve from 0.18922
# Epoch 15/80
# 2213/2213 [==============================] - 239s 107ms/step - loss: 0.1960 - precision: 0.8705 - recall: 0.7076 - f1_score: 0.0580 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8018 - val_loss: 0.1904 - val_precision: 0.8742 - val_recall: 0.7044 - val_f1_score: 0.0569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8080
#
# Epoch 00015: val_loss did not improve from 0.18922
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# Epoch 16/80
# 2213/2213 [==============================] - 238s 106ms/step - loss: 0.1956 - precision: 0.8708 - recall: 0.7073 - f1_score: 0.0577 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8009 - val_loss: 0.1890 - val_precision: 0.8682 - val_recall: 0.7197 - val_f1_score: 0.0573 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8069
#
# Epoch 00016: val_loss improved from 0.18922 to 0.18897, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 17/80
# 2213/2213 [==============================] - 237s 106ms/step - loss: 0.1956 - precision: 0.8707 - recall: 0.7074 - f1_score: 0.0578 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8009 - val_loss: 0.1885 - val_precision: 0.8800 - val_recall: 0.7079 - val_f1_score: 0.0573 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8073
#
# Epoch 00017: val_loss improved from 0.18897 to 0.18854, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug.h5
# Epoch 18/80
# 2213/2213 [==============================] - 239s 107ms/step - loss: 0.1955 - precision: 0.8713 - recall: 0.7076 - f1_score: 0.0579 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8015 - val_loss: 0.1893 - val_precision: 0.8701 - val_recall: 0.7119 - val_f1_score: 0.0569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8063
#
# Epoch 00018: val_loss did not improve from 0.18854
# Epoch 19/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1956 - precision: 0.8712 - recall: 0.7076 - f1_score: 0.0577 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8015 - val_loss: 0.1890 - val_precision: 0.8826 - val_recall: 0.7047 - val_f1_score: 0.0573 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8072
#
# Epoch 00019: val_loss did not improve from 0.18854
# Epoch 20/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1958 - precision: 0.8707 - recall: 0.7073 - f1_score: 0.0578 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8000 - val_loss: 0.1893 - val_precision: 0.8685 - val_recall: 0.7104 - val_f1_score: 0.0569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8068
#
# Epoch 00020: val_loss did not improve from 0.18854
# Epoch 21/80
# 2213/2213 [==============================] - 242s 108ms/step - loss: 0.1956 - precision: 0.8710 - recall: 0.7074 - f1_score: 0.0578 - Multilabel_confusion_matrix: 35408.0000 - auc: 0.8007 - val_loss: 0.1887 - val_precision: 0.8831 - val_recall: 0.7082 - val_f1_score: 0.0575 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8062
#
# Epoch 00021: val_loss did not improve from 0.18854
# Epoch 00021: early stopping
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 17

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# Epoch 18/120
# 442/442 [==============================] - 116s 240ms/step - loss: 0.2109 - precision_1: 0.8701 - recall_1: 0.7078 - f1_score: 0.0685 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7603 - val_loss: 0.1707 - val_precision_1: 0.8990 - val_recall_1: 0.7648 - val_f1_score: 0.1202 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8113
#
# Epoch 00018: val_loss improved from inf to 0.17073, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 19/120
# 442/442 [==============================] - 104s 235ms/step - loss: 0.1735 - precision_1: 0.8959 - recall_1: 0.7561 - f1_score: 0.1101 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7963 - val_loss: 0.1511 - val_precision_1: 0.9051 - val_recall_1: 0.8005 - val_f1_score: 0.1475 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8362
#
# Epoch 00019: val_loss improved from 0.17073 to 0.15108, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 20/120
# 442/442 [==============================] - 102s 231ms/step - loss: 0.1619 - precision_1: 0.9000 - recall_1: 0.7743 - f1_score: 0.1260 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8284 - val_loss: 0.1412 - val_precision_1: 0.9143 - val_recall_1: 0.8150 - val_f1_score: 0.1636 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8628
#
# Epoch 00020: val_loss improved from 0.15108 to 0.14118, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 21/120
# 442/442 [==============================] - 102s 230ms/step - loss: 0.1539 - precision_1: 0.9055 - recall_1: 0.7872 - f1_score: 0.1349 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8583 - val_loss: 0.1340 - val_precision_1: 0.9173 - val_recall_1: 0.8295 - val_f1_score: 0.1730 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8782
#
# Epoch 00021: val_loss improved from 0.14118 to 0.13404, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 22/120
# 442/442 [==============================] - 102s 230ms/step - loss: 0.1476 - precision_1: 0.9089 - recall_1: 0.7982 - f1_score: 0.1461 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8568 - val_loss: 0.1285 - val_precision_1: 0.9239 - val_recall_1: 0.8334 - val_f1_score: 0.1805 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8739
#
# Epoch 00022: val_loss improved from 0.13404 to 0.12847, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 23/120
# 442/442 [==============================] - 104s 235ms/step - loss: 0.1426 - precision_1: 0.9092 - recall_1: 0.8056 - f1_score: 0.1492 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8724 - val_loss: 0.1250 - val_precision_1: 0.9229 - val_recall_1: 0.8399 - val_f1_score: 0.1755 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8902
#
# Epoch 00023: val_loss improved from 0.12847 to 0.12503, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 24/120
# 442/442 [==============================] - 102s 230ms/step - loss: 0.1386 - precision_1: 0.9105 - recall_1: 0.8121 - f1_score: 0.1519 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8772 - val_loss: 0.1223 - val_precision_1: 0.9197 - val_recall_1: 0.8464 - val_f1_score: 0.1808 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8892
#
# Epoch 00024: val_loss improved from 0.12503 to 0.12229, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 25/120
# 442/442 [==============================] - 102s 230ms/step - loss: 0.1373 - precision_1: 0.9086 - recall_1: 0.8162 - f1_score: 0.1569 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8819 - val_loss: 0.1200 - val_precision_1: 0.9292 - val_recall_1: 0.8421 - val_f1_score: 0.1887 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9004
#
# Epoch 00025: val_loss improved from 0.12229 to 0.12004, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 26/120
# 442/442 [==============================] - 104s 234ms/step - loss: 0.1341 - precision_1: 0.9133 - recall_1: 0.8185 - f1_score: 0.1596 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8937 - val_loss: 0.1178 - val_precision_1: 0.9229 - val_recall_1: 0.8507 - val_f1_score: 0.1903 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9032
#
# Epoch 00026: val_loss improved from 0.12004 to 0.11783, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 27/120
# 442/442 [==============================] - 105s 238ms/step - loss: 0.1310 - precision_1: 0.9158 - recall_1: 0.8251 - f1_score: 0.1650 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8803 - val_loss: 0.1157 - val_precision_1: 0.9225 - val_recall_1: 0.8548 - val_f1_score: 0.1949 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8930
#
# Epoch 00027: val_loss improved from 0.11783 to 0.11573, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 28/120
# 442/442 [==============================] - 106s 240ms/step - loss: 0.1293 - precision_1: 0.9137 - recall_1: 0.8266 - f1_score: 0.1653 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8971 - val_loss: 0.1143 - val_precision_1: 0.9218 - val_recall_1: 0.8544 - val_f1_score: 0.1823 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9068
#
# Epoch 00028: val_loss improved from 0.11573 to 0.11429, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 29/120
# 442/442 [==============================] - 103s 234ms/step - loss: 0.1278 - precision_1: 0.9144 - recall_1: 0.8292 - f1_score: 0.1683 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8897 - val_loss: 0.1130 - val_precision_1: 0.9265 - val_recall_1: 0.8525 - val_f1_score: 0.1873 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9005
#
# Epoch 00029: val_loss improved from 0.11429 to 0.11297, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 30/120
# 442/442 [==============================] - 105s 238ms/step - loss: 0.1275 - precision_1: 0.9132 - recall_1: 0.8281 - f1_score: 0.1684 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8957 - val_loss: 0.1122 - val_precision_1: 0.9261 - val_recall_1: 0.8565 - val_f1_score: 0.2029 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9092
#
# Epoch 00030: val_loss improved from 0.11297 to 0.11220, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 31/120
# 442/442 [==============================] - 104s 235ms/step - loss: 0.1267 - precision_1: 0.9159 - recall_1: 0.8303 - f1_score: 0.1704 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9016 - val_loss: 0.1111 - val_precision_1: 0.9274 - val_recall_1: 0.8577 - val_f1_score: 0.2014 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9094
#
# Epoch 00031: val_loss improved from 0.11220 to 0.11112, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 32/120
# 442/442 [==============================] - 101s 228ms/step - loss: 0.1236 - precision_1: 0.9174 - recall_1: 0.8375 - f1_score: 0.1717 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8902 - val_loss: 0.1106 - val_precision_1: 0.9305 - val_recall_1: 0.8506 - val_f1_score: 0.1917 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9061
#
# Epoch 00032: val_loss improved from 0.11112 to 0.11064, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 33/120
# 442/442 [==============================] - 106s 240ms/step - loss: 0.1233 - precision_1: 0.9170 - recall_1: 0.8336 - f1_score: 0.1716 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9052 - val_loss: 0.1088 - val_precision_1: 0.9292 - val_recall_1: 0.8593 - val_f1_score: 0.1876 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9090
#
# Epoch 00033: val_loss improved from 0.11064 to 0.10876, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 34/120
# 442/442 [==============================] - 104s 236ms/step - loss: 0.1217 - precision_1: 0.9163 - recall_1: 0.8394 - f1_score: 0.1722 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8973 - val_loss: 0.1083 - val_precision_1: 0.9280 - val_recall_1: 0.8588 - val_f1_score: 0.1958 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9122
#
# Epoch 00034: val_loss improved from 0.10876 to 0.10834, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 35/120
# 442/442 [==============================] - 104s 235ms/step - loss: 0.1212 - precision_1: 0.9150 - recall_1: 0.8377 - f1_score: 0.1763 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9013 - val_loss: 0.1075 - val_precision_1: 0.9284 - val_recall_1: 0.8627 - val_f1_score: 0.2091 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9106
#
# Epoch 00035: val_loss improved from 0.10834 to 0.10746, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 36/120
# 442/442 [==============================] - 105s 237ms/step - loss: 0.1216 - precision_1: 0.9171 - recall_1: 0.8368 - f1_score: 0.1748 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9056 - val_loss: 0.1071 - val_precision_1: 0.9248 - val_recall_1: 0.8665 - val_f1_score: 0.1998 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9124
#
# Epoch 00036: val_loss improved from 0.10746 to 0.10709, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 37/120
# 442/442 [==============================] - 102s 231ms/step - loss: 0.1189 - precision_1: 0.9193 - recall_1: 0.8448 - f1_score: 0.1776 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8950 - val_loss: 0.1065 - val_precision_1: 0.9299 - val_recall_1: 0.8593 - val_f1_score: 0.1864 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9105
#
# Epoch 00037: val_loss improved from 0.10709 to 0.10653, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 38/120
# 442/442 [==============================] - 105s 237ms/step - loss: 0.1174 - precision_1: 0.9198 - recall_1: 0.8422 - f1_score: 0.1762 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9103 - val_loss: 0.1054 - val_precision_1: 0.9297 - val_recall_1: 0.8620 - val_f1_score: 0.2009 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9144
#
# Epoch 00038: val_loss improved from 0.10653 to 0.10543, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 39/120
# 442/442 [==============================] - 103s 234ms/step - loss: 0.1177 - precision_1: 0.9186 - recall_1: 0.8458 - f1_score: 0.1778 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9009 - val_loss: 0.1053 - val_precision_1: 0.9282 - val_recall_1: 0.8630 - val_f1_score: 0.2054 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9151
#
# Epoch 00039: val_loss improved from 0.10543 to 0.10534, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 40/120
# 442/442 [==============================] - 102s 232ms/step - loss: 0.1171 - precision_1: 0.9174 - recall_1: 0.8447 - f1_score: 0.1843 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9064 - val_loss: 0.1050 - val_precision_1: 0.9309 - val_recall_1: 0.8602 - val_f1_score: 0.2082 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9174
#
# Epoch 00040: val_loss improved from 0.10534 to 0.10503, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 41/120
# 442/442 [==============================] - 104s 234ms/step - loss: 0.1165 - precision_1: 0.9201 - recall_1: 0.8446 - f1_score: 0.1832 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9110 - val_loss: 0.1049 - val_precision_1: 0.9195 - val_recall_1: 0.8733 - val_f1_score: 0.2075 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9151
#
# Epoch 00041: val_loss improved from 0.10503 to 0.10493, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 42/120
# 442/442 [==============================] - 103s 233ms/step - loss: 0.1153 - precision_1: 0.9208 - recall_1: 0.8497 - f1_score: 0.1829 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9051 - val_loss: 0.1040 - val_precision_1: 0.9305 - val_recall_1: 0.8612 - val_f1_score: 0.1936 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9067
#
# Epoch 00042: val_loss improved from 0.10493 to 0.10403, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 43/120
# 442/442 [==============================] - 105s 237ms/step - loss: 0.1156 - precision_1: 0.9192 - recall_1: 0.8467 - f1_score: 0.1791 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9100 - val_loss: 0.1040 - val_precision_1: 0.9239 - val_recall_1: 0.8710 - val_f1_score: 0.2073 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9172
#
# Epoch 00043: val_loss improved from 0.10403 to 0.10395, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 44/120
# 442/442 [==============================] - 101s 228ms/step - loss: 0.1133 - precision_1: 0.9199 - recall_1: 0.8504 - f1_score: 0.1834 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9038 - val_loss: 0.1036 - val_precision_1: 0.9273 - val_recall_1: 0.8672 - val_f1_score: 0.1977 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9148
#
# Epoch 00044: val_loss improved from 0.10395 to 0.10355, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 45/120
# 442/442 [==============================] - 102s 231ms/step - loss: 0.1151 - precision_1: 0.9184 - recall_1: 0.8485 - f1_score: 0.1866 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9076 - val_loss: 0.1035 - val_precision_1: 0.9262 - val_recall_1: 0.8693 - val_f1_score: 0.2258 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9197
#
# Epoch 00045: val_loss improved from 0.10355 to 0.10355, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 46/120
# 442/442 [==============================] - 103s 233ms/step - loss: 0.1127 - precision_1: 0.9223 - recall_1: 0.8516 - f1_score: 0.1851 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9100 - val_loss: 0.1027 - val_precision_1: 0.9257 - val_recall_1: 0.8699 - val_f1_score: 0.1995 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9196
#
# Epoch 00046: val_loss improved from 0.10355 to 0.10274, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 47/120
# 442/442 [==============================] - 102s 232ms/step - loss: 0.1125 - precision_1: 0.9232 - recall_1: 0.8532 - f1_score: 0.1857 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9082 - val_loss: 0.1027 - val_precision_1: 0.9254 - val_recall_1: 0.8700 - val_f1_score: 0.1910 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9179
#
# Epoch 00047: val_loss improved from 0.10274 to 0.10268, saving model to .//models/amazon-from-space-mo444\eb6-ce-auto-aug-ft.h5
# Epoch 48/120
# 442/442 [==============================] - 106s 240ms/step - loss: 0.1118 - precision_1: 0.9213 - recall_1: 0.8534 - f1_score: 0.1817 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9155 - val_loss: 0.1031 - val_precision_1: 0.9328 - val_recall_1: 0.8612 - val_f1_score: 0.1968 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9166
#
# Epoch 00048: val_loss did not improve from 0.10268
# Epoch 49/120
# 442/442 [==============================] - 104s 234ms/step - loss: 0.1104 - precision_1: 0.9230 - recall_1: 0.8555 - f1_score: 0.1878 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9096 - val_loss: 0.1028 - val_precision_1: 0.9258 - val_recall_1: 0.8679 - val_f1_score: 0.1942 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9189
#
# Epoch 00049: val_loss did not improve from 0.10268
# Epoch 50/120
# 442/442 [==============================] - 103s 234ms/step - loss: 0.1126 - precision_1: 0.9201 - recall_1: 0.8514 - f1_score: 0.1887 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9108 - val_loss: 0.1030 - val_precision_1: 0.9216 - val_recall_1: 0.8739 - val_f1_score: 0.2278 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9206
#
# Epoch 00050: val_loss did not improve from 0.10268
# Epoch 00050: early stopping
#
# done

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %% [markdown]
# unfreeze_top_layers(
#   backbone,
#   Config.fine_tuning.unfreeze_layers,
#   Config.fine_tuning.frozen_bn
# )
#
# nn.load_weights(Config.fine_tuning.weights)

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ............................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  false positive r  false negative r  \
# 0            0.7881           0.9483            0.0517            0.2119
# 1            0.7573           0.9988            0.0012            0.2427
# 2            0.0562           0.9990            0.0010            0.9438
# 3            0.0000           1.0000            0.0000            1.0000
# 4            0.0000           1.0000            0.0000            1.0000
# 5            0.9687           0.9189            0.0811            0.0313
# 6            0.7945           0.9940            0.0060            0.2055
# 7            0.0000           1.0000            0.0000            1.0000
# 8            0.5176           0.9615            0.0385            0.4824
# 9            0.6697           0.9804            0.0196            0.3303
# 10           0.6457           0.9850            0.0150            0.3543
# 11           0.9074           0.9824            0.0176            0.0926
# 12           0.9910           0.7222            0.2778            0.0090
# 13           0.8097           0.9743            0.0257            0.1903
# 14           0.0000           1.0000            0.0000            1.0000
# 15           0.0000           1.0000            0.0000            1.0000
# 16           0.7445           0.9708            0.0292            0.2555
#
#     precision  recall  auc_score  f1_score  f2_score  support  \
# 0      0.8703  0.7881     0.9618    0.8272    0.8033     3696
# 1      0.8478  0.7573     0.9968    0.8000    0.7738      103
# 2      0.5385  0.0562     0.9110    0.1018    0.0685      249
# 3      0.0000  0.0000     0.8436    0.0000    0.0000      101
# 4      0.0000  0.0000     0.8169    0.0000    0.0000       40
# 5      0.9654  0.9687     0.9896    0.9671    0.9681     8473
# 6      0.8832  0.7945     0.9955    0.8365    0.8108      657
# 7      0.0000  0.0000     0.9440    0.0000    0.0000       22
# 8      0.6196  0.5176     0.9187    0.5640    0.5352     1306
# 9      0.7763  0.6697     0.9624    0.7190    0.6886     1114
# 10     0.7515  0.6457     0.9706    0.6946    0.6644      796
# 11     0.9184  0.9074     0.9937    0.9128    0.9096     2170
# 12     0.9778  0.9910     0.9831    0.9843    0.9883    11189
# 13     0.8886  0.8097     0.9784    0.8474    0.8244     2444
# 14     0.0000  0.0000     0.8917    0.0000    0.0000      100
# 15     0.0000  0.0000     0.9189    0.0000    0.0000       59
# 16     0.8515  0.7445     0.9621    0.7944    0.7637     2219
#
#                 label
# 0         agriculture
# 1      artisinal_mine
# 2         bare_ground
# 3            blooming
# 4           blow_down
# 5               clear
# 6              cloudy
# 7   conventional_mine
# 8         cultivation
# 9          habitation
# 10               haze
# 11      partly_cloudy
# 12            primary
# 13               road
# 14  selective_logging
# 15         slash_burn
# 16              water

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
#%%bash

#if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#  mkdir -p /root/tensorflow_datasets/amazon-from-space/
#  gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
  # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
  #   /root/tensorflow_datasets/amazon-from-space/
#fi

# %%
test_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer.csv'), index=False)
answer.head()
# Out:
#    image_name                            tags
# 0  test_17823                   clear primary
# 1  test_29423  agriculture clear primary road
# 2   file_7472       clear cultivation primary
# 3  file_11084                   clear primary
# 4  file_16408  agriculture clear primary road
