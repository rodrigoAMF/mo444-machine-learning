# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
import tensorflow_addons as tfa

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
#      |████████████████████████████████| 679 kB 4.3 MB/s
#      |████████████████████████████████| 3.9 MB 4.3 MB/s
# Mounted at /content/drive
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = '/home/ldavid/Workspace'
  data_dir = '/home/ldavid/Workspace/datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )
    #optimizer = tfa.optimizers.SWA(optimizer)

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-class-weights/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-class-weights.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 80
    learning_rate = .01

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )
    #optimizer = tfa.optimizers.SWA(optimizer)

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-class-weights/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-class-weights.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
# %%time
# %%bash

if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
  mkdir -p /root/tensorflow_datasets/amazon-from-space/

  gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
  # If the above is not working:
  # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
  #    /root/tensorflow_datasets/amazon-from-space/
else
  echo "Dir $data_path found. Skipping."
fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N
# To: /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
# 7.96GB [01:34, 84.5MB/s]
# CPU times: user 824 ms, sys: 243 ms, total: 1.07 s
# Wall time: 3min 32s

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 1s 0us/step

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    # add class_weights, using counts shown in notebook
    #class_weights_labels = \
    #  ['agriculture', 'artisinal_mine', 'bare_ground','blooming',
    #  'blow_down', 'clear', 'cloudy', 'conventional_mine',
    #  'cultivation', 'habitation', 'haze', 'partly_cloudy', 'primary',
    #  'road', 'selective_logging', 'slash_burn', 'water']
    class_weights = [690, 150, 167, 119, 91, 1232, 103, 115, 323, 308, 150,
                     307, 1643, 628, 133, 125, 483]
    class_weights /= np.sum(class_weights)
    class_weights = {i : 1/class_weights[i] \
                      for i in range(len(class_weights))}
    print("Class weights dictionary:")
    print(class_weights)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks,
      class_weight=class_weights);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# Overriding previous training at /content/drive/MyDrive/logs/amazon-from-space-mo444/eb6-class-weights/.
# Class weights dictionary:
# {0: 9.807246376811593, 1: 45.11333333333334, 2: 40.52095808383234, 3: 56.8655462184874, 4: 74.36263736263736, 5: 5.492694805194805, 6: 65.69902912621359, 7: 58.84347826086957, 8: 20.95046439628483, 9: 21.97077922077922, 10: 45.11333333333334, 11: 22.042345276872965, 12: 4.118685331710286, 13: 10.775477707006369, 14: 50.8796992481203, 15: 54.136, 16: 14.010351966873706}
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/80
# 442/442 [==============================] - ETA: 0s - loss: 2.9687 - precision: 0.8650 - recall: 0.7481 - f1_score: 0.1385 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8367
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 195s 383ms/step - loss: 2.9687 - precision: 0.8650 - recall: 0.7481 - f1_score: 0.1385 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8367 - val_loss: 0.5562 - val_precision: 0.9146 - val_recall: 0.7289 - val_f1_score: 0.1440 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8582
#
# Epoch 00001: val_loss improved from inf to 0.55616, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 2/80
# 442/442 [==============================] - 175s 397ms/step - loss: 2.8286 - precision: 0.8783 - recall: 0.7522 - f1_score: 0.1418 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8547 - val_loss: 0.5217 - val_precision: 0.8767 - val_recall: 0.7798 - val_f1_score: 0.1399 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8751
#
# Epoch 00002: val_loss improved from 0.55616 to 0.52175, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 3/80
# 442/442 [==============================] - 175s 397ms/step - loss: 2.8439 - precision: 0.8744 - recall: 0.7511 - f1_score: 0.1384 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8552 - val_loss: 0.5205 - val_precision: 0.9091 - val_recall: 0.7376 - val_f1_score: 0.1268 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8818
#
# Epoch 00003: val_loss improved from 0.52175 to 0.52045, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 4/80
# 442/442 [==============================] - 163s 369ms/step - loss: 2.8071 - precision: 0.8769 - recall: 0.7525 - f1_score: 0.1423 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8588 - val_loss: 0.5217 - val_precision: 0.9150 - val_recall: 0.7249 - val_f1_score: 0.1613 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8882
#
# Epoch 00004: val_loss did not improve from 0.52045
# Epoch 5/80
# 442/442 [==============================] - 175s 397ms/step - loss: 2.8114 - precision: 0.8753 - recall: 0.7511 - f1_score: 0.1411 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8608 - val_loss: 0.5226 - val_precision: 0.8894 - val_recall: 0.7610 - val_f1_score: 0.1462 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8895
#
# Epoch 00005: val_loss did not improve from 0.52045
# Epoch 6/80
# 442/442 [==============================] - 168s 381ms/step - loss: 2.8152 - precision: 0.8765 - recall: 0.7521 - f1_score: 0.1370 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8575 - val_loss: 0.5182 - val_precision: 0.8954 - val_recall: 0.7308 - val_f1_score: 0.1396 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8893
#
# Epoch 00006: val_loss improved from 0.52045 to 0.51817, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 7/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.8176 - precision: 0.8758 - recall: 0.7517 - f1_score: 0.1427 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8628 - val_loss: 0.5184 - val_precision: 0.8764 - val_recall: 0.7779 - val_f1_score: 0.1268 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8840
#
# Epoch 00007: val_loss did not improve from 0.51817
# Epoch 8/80
# 442/442 [==============================] - 175s 397ms/step - loss: 2.8166 - precision: 0.8771 - recall: 0.7505 - f1_score: 0.1405 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8648 - val_loss: 0.5264 - val_precision: 0.9019 - val_recall: 0.7157 - val_f1_score: 0.1464 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8987
#
# Epoch 00008: val_loss did not improve from 0.51817
# Epoch 9/80
# 442/442 [==============================] - 168s 380ms/step - loss: 2.8062 - precision: 0.8769 - recall: 0.7510 - f1_score: 0.1402 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8625 - val_loss: 0.5030 - val_precision: 0.8903 - val_recall: 0.7673 - val_f1_score: 0.1333 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8965
#
# Epoch 00009: val_loss improved from 0.51817 to 0.50299, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 10/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.7817 - precision: 0.8779 - recall: 0.7529 - f1_score: 0.1416 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8600 - val_loss: 0.5127 - val_precision: 0.8978 - val_recall: 0.7493 - val_f1_score: 0.1421 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8956
#
# Epoch 00010: val_loss did not improve from 0.50299
# Epoch 11/80
# 442/442 [==============================] - 168s 381ms/step - loss: 2.7933 - precision: 0.8779 - recall: 0.7532 - f1_score: 0.1396 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8593 - val_loss: 0.5155 - val_precision: 0.8882 - val_recall: 0.7601 - val_f1_score: 0.1296 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8830
#
# Epoch 00011: val_loss did not improve from 0.50299
# Epoch 12/80
# 442/442 [==============================] - 177s 399ms/step - loss: 2.8207 - precision: 0.8757 - recall: 0.7513 - f1_score: 0.1389 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8602 - val_loss: 0.5286 - val_precision: 0.8964 - val_recall: 0.7541 - val_f1_score: 0.1373 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8823
#
# Epoch 00012: val_loss did not improve from 0.50299
# Epoch 13/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.8065 - precision: 0.8777 - recall: 0.7516 - f1_score: 0.1378 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8595 - val_loss: 0.5283 - val_precision: 0.8998 - val_recall: 0.7531 - val_f1_score: 0.1118 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8772
#
# Epoch 00013: val_loss did not improve from 0.50299
# Epoch 14/80
# 442/442 [==============================] - 177s 400ms/step - loss: 2.8048 - precision: 0.8792 - recall: 0.7512 - f1_score: 0.1393 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8586 - val_loss: 0.4890 - val_precision: 0.8803 - val_recall: 0.7850 - val_f1_score: 0.1524 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8898
#
# Epoch 00014: val_loss improved from 0.50299 to 0.48905, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 15/80
# 442/442 [==============================] - 177s 400ms/step - loss: 2.8037 - precision: 0.8771 - recall: 0.7514 - f1_score: 0.1394 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8625 - val_loss: 0.5152 - val_precision: 0.8919 - val_recall: 0.7712 - val_f1_score: 0.1452 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8721
#
# Epoch 00015: val_loss did not improve from 0.48905
# Epoch 16/80
# 442/442 [==============================] - 169s 382ms/step - loss: 2.8086 - precision: 0.8766 - recall: 0.7502 - f1_score: 0.1420 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8594 - val_loss: 0.5195 - val_precision: 0.8955 - val_recall: 0.7489 - val_f1_score: 0.1328 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8920
#
# Epoch 00016: val_loss did not improve from 0.48905
# Epoch 17/80
# 442/442 [==============================] - 179s 402ms/step - loss: 2.8122 - precision: 0.8749 - recall: 0.7514 - f1_score: 0.1407 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8612 - val_loss: 0.5304 - val_precision: 0.9062 - val_recall: 0.7500 - val_f1_score: 0.1311 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8911
#
# Epoch 00017: val_loss did not improve from 0.48905
# Epoch 18/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.8093 - precision: 0.8763 - recall: 0.7512 - f1_score: 0.1395 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8600 - val_loss: 0.5353 - val_precision: 0.8833 - val_recall: 0.7401 - val_f1_score: 0.1402 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8917
#
# Epoch 00018: val_loss did not improve from 0.48905
# Epoch 19/80
# 442/442 [==============================] - 176s 400ms/step - loss: 2.7834 - precision: 0.8775 - recall: 0.7509 - f1_score: 0.1430 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8623 - val_loss: 0.5008 - val_precision: 0.8923 - val_recall: 0.7608 - val_f1_score: 0.1501 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8826
#
# Epoch 00019: val_loss did not improve from 0.48905
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# Epoch 20/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.5908 - precision: 0.8938 - recall: 0.7572 - f1_score: 0.1366 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8798 - val_loss: 0.4263 - val_precision: 0.9012 - val_recall: 0.7699 - val_f1_score: 0.1404 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9038
#
# Epoch 00020: val_loss improved from 0.48905 to 0.42634, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 21/80
# 442/442 [==============================] - 169s 382ms/step - loss: 2.5922 - precision: 0.8919 - recall: 0.7553 - f1_score: 0.1366 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8845 - val_loss: 0.4296 - val_precision: 0.9167 - val_recall: 0.7456 - val_f1_score: 0.1293 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9022
#
# Epoch 00021: val_loss did not improve from 0.42634
# Epoch 22/80
# 442/442 [==============================] - 178s 400ms/step - loss: 2.5984 - precision: 0.8923 - recall: 0.7578 - f1_score: 0.1381 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8801 - val_loss: 0.4364 - val_precision: 0.9093 - val_recall: 0.7514 - val_f1_score: 0.1526 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9025
#
# Epoch 00022: val_loss did not improve from 0.42634
# Epoch 23/80
# 442/442 [==============================] - 177s 400ms/step - loss: 2.5958 - precision: 0.8923 - recall: 0.7563 - f1_score: 0.1363 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8793 - val_loss: 0.4412 - val_precision: 0.9010 - val_recall: 0.7575 - val_f1_score: 0.1370 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9035
#
# Epoch 00023: val_loss did not improve from 0.42634
# Epoch 24/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.5726 - precision: 0.8943 - recall: 0.7574 - f1_score: 0.1369 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8784 - val_loss: 0.4322 - val_precision: 0.9127 - val_recall: 0.7490 - val_f1_score: 0.1279 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9023
#
# Epoch 00024: val_loss did not improve from 0.42634
# Epoch 25/80
# 442/442 [==============================] - 169s 382ms/step - loss: 2.5826 - precision: 0.8930 - recall: 0.7560 - f1_score: 0.1367 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8795 - val_loss: 0.4366 - val_precision: 0.9212 - val_recall: 0.7320 - val_f1_score: 0.1446 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9067
#
# Epoch 00025: val_loss did not improve from 0.42634
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# Epoch 26/80
# 442/442 [==============================] - 178s 400ms/step - loss: 2.4919 - precision: 0.9000 - recall: 0.7586 - f1_score: 0.1343 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8932 - val_loss: 0.3977 - val_precision: 0.9177 - val_recall: 0.7524 - val_f1_score: 0.1348 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9156
#
# Epoch 00026: val_loss improved from 0.42634 to 0.39765, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 27/80
# 442/442 [==============================] - 170s 384ms/step - loss: 2.4710 - precision: 0.9020 - recall: 0.7612 - f1_score: 0.1340 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8944 - val_loss: 0.3968 - val_precision: 0.9224 - val_recall: 0.7492 - val_f1_score: 0.1396 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9122
#
# Epoch 00027: val_loss improved from 0.39765 to 0.39678, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 28/80
# 442/442 [==============================] - 176s 399ms/step - loss: 2.4713 - precision: 0.9016 - recall: 0.7610 - f1_score: 0.1356 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8960 - val_loss: 0.3982 - val_precision: 0.9140 - val_recall: 0.7517 - val_f1_score: 0.1363 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9113
#
# Epoch 00028: val_loss did not improve from 0.39678
# Epoch 29/80
# 442/442 [==============================] - 170s 386ms/step - loss: 2.4808 - precision: 0.9007 - recall: 0.7597 - f1_score: 0.1369 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8968 - val_loss: 0.3994 - val_precision: 0.9084 - val_recall: 0.7598 - val_f1_score: 0.1422 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9137
#
# Epoch 00029: val_loss did not improve from 0.39678
# Epoch 30/80
# 442/442 [==============================] - 172s 387ms/step - loss: 2.4863 - precision: 0.9004 - recall: 0.7592 - f1_score: 0.1336 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8951 - val_loss: 0.3996 - val_precision: 0.9097 - val_recall: 0.7694 - val_f1_score: 0.1452 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9155
#
# Epoch 00030: val_loss did not improve from 0.39678
# Epoch 31/80
# 442/442 [==============================] - 172s 387ms/step - loss: 2.4782 - precision: 0.9013 - recall: 0.7593 - f1_score: 0.1355 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8959 - val_loss: 0.3898 - val_precision: 0.9095 - val_recall: 0.7756 - val_f1_score: 0.1421 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9112
#
# Epoch 00031: val_loss improved from 0.39678 to 0.38982, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 32/80
# 442/442 [==============================] - 178s 403ms/step - loss: 2.4688 - precision: 0.9029 - recall: 0.7599 - f1_score: 0.1351 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8944 - val_loss: 0.3923 - val_precision: 0.9145 - val_recall: 0.7652 - val_f1_score: 0.1424 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9122
#
# Epoch 00032: val_loss did not improve from 0.38982
# Epoch 33/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.4685 - precision: 0.9031 - recall: 0.7601 - f1_score: 0.1356 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8975 - val_loss: 0.3918 - val_precision: 0.9089 - val_recall: 0.7662 - val_f1_score: 0.1442 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9162
#
# Epoch 00033: val_loss did not improve from 0.38982
# Epoch 34/80
# 442/442 [==============================] - 178s 403ms/step - loss: 2.4745 - precision: 0.9024 - recall: 0.7609 - f1_score: 0.1328 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8930 - val_loss: 0.3936 - val_precision: 0.9075 - val_recall: 0.7617 - val_f1_score: 0.1487 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9088
#
# Epoch 00034: val_loss did not improve from 0.38982
# Epoch 35/80
# 442/442 [==============================] - 178s 404ms/step - loss: 2.4829 - precision: 0.9016 - recall: 0.7594 - f1_score: 0.1342 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8931 - val_loss: 0.3900 - val_precision: 0.9154 - val_recall: 0.7662 - val_f1_score: 0.1357 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9098
#
# Epoch 00035: val_loss did not improve from 0.38982
# Epoch 36/80
# 442/442 [==============================] - 170s 386ms/step - loss: 2.4799 - precision: 0.9012 - recall: 0.7599 - f1_score: 0.1368 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8908 - val_loss: 0.3963 - val_precision: 0.9122 - val_recall: 0.7605 - val_f1_score: 0.1415 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9114
#
# Epoch 00036: val_loss did not improve from 0.38982
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# Epoch 37/80
# 442/442 [==============================] - 172s 386ms/step - loss: 2.4348 - precision: 0.9057 - recall: 0.7608 - f1_score: 0.1350 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9020 - val_loss: 0.3755 - val_precision: 0.9155 - val_recall: 0.7708 - val_f1_score: 0.1380 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9163
#
# Epoch 00037: val_loss improved from 0.38982 to 0.37552, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 38/80
# 442/442 [==============================] - 171s 388ms/step - loss: 2.4227 - precision: 0.9068 - recall: 0.7614 - f1_score: 0.1333 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9052 - val_loss: 0.3774 - val_precision: 0.9168 - val_recall: 0.7658 - val_f1_score: 0.1357 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9165
#
# Epoch 00038: val_loss did not improve from 0.37552
# Epoch 39/80
# 442/442 [==============================] - 180s 406ms/step - loss: 2.4288 - precision: 0.9068 - recall: 0.7602 - f1_score: 0.1347 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9016 - val_loss: 0.3734 - val_precision: 0.9200 - val_recall: 0.7551 - val_f1_score: 0.1462 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9162
#
# Epoch 00039: val_loss improved from 0.37552 to 0.37342, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 40/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.4160 - precision: 0.9057 - recall: 0.7616 - f1_score: 0.1344 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9026 - val_loss: 0.3804 - val_precision: 0.9171 - val_recall: 0.7628 - val_f1_score: 0.1378 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9160
#
# Epoch 00040: val_loss did not improve from 0.37342
# Epoch 41/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.4326 - precision: 0.9058 - recall: 0.7615 - f1_score: 0.1353 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9031 - val_loss: 0.3755 - val_precision: 0.9193 - val_recall: 0.7622 - val_f1_score: 0.1435 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9178
#
# Epoch 00041: val_loss did not improve from 0.37342
# Epoch 42/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.4276 - precision: 0.9068 - recall: 0.7610 - f1_score: 0.1373 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9000 - val_loss: 0.3755 - val_precision: 0.9175 - val_recall: 0.7637 - val_f1_score: 0.1395 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9157
#
# Epoch 00042: val_loss did not improve from 0.37342
# Epoch 43/80
# 442/442 [==============================] - 170s 386ms/step - loss: 2.4248 - precision: 0.9067 - recall: 0.7608 - f1_score: 0.1361 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9043 - val_loss: 0.3754 - val_precision: 0.9159 - val_recall: 0.7688 - val_f1_score: 0.1379 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9172
#
# Epoch 00043: val_loss did not improve from 0.37342
# Epoch 44/80
# 442/442 [==============================] - 180s 406ms/step - loss: 2.4125 - precision: 0.9066 - recall: 0.7601 - f1_score: 0.1356 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9045 - val_loss: 0.3825 - val_precision: 0.9190 - val_recall: 0.7526 - val_f1_score: 0.1442 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9193
#
# Epoch 00044: val_loss did not improve from 0.37342
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# Epoch 45/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.3944 - precision: 0.9106 - recall: 0.7640 - f1_score: 0.1368 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9064 - val_loss: 0.3675 - val_precision: 0.9171 - val_recall: 0.7699 - val_f1_score: 0.1431 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9178
#
# Epoch 00045: val_loss improved from 0.37342 to 0.36750, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 46/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.3886 - precision: 0.9094 - recall: 0.7641 - f1_score: 0.1361 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9107 - val_loss: 0.3682 - val_precision: 0.9162 - val_recall: 0.7645 - val_f1_score: 0.1436 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9174
#
# Epoch 00046: val_loss did not improve from 0.36750
# Epoch 47/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.3946 - precision: 0.9100 - recall: 0.7599 - f1_score: 0.1342 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9109 - val_loss: 0.3664 - val_precision: 0.9100 - val_recall: 0.7768 - val_f1_score: 0.1403 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9182
#
# Epoch 00047: val_loss improved from 0.36750 to 0.36643, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 48/80
# 442/442 [==============================] - 171s 388ms/step - loss: 2.3940 - precision: 0.9078 - recall: 0.7610 - f1_score: 0.1329 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9115 - val_loss: 0.3675 - val_precision: 0.9206 - val_recall: 0.7588 - val_f1_score: 0.1445 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9156
#
# Epoch 00048: val_loss did not improve from 0.36643
# Epoch 49/80
# 442/442 [==============================] - 181s 406ms/step - loss: 2.4014 - precision: 0.9082 - recall: 0.7610 - f1_score: 0.1342 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9075 - val_loss: 0.3672 - val_precision: 0.9193 - val_recall: 0.7659 - val_f1_score: 0.1423 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9160
#
# Epoch 00049: val_loss did not improve from 0.36643
# Epoch 50/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.3964 - precision: 0.9100 - recall: 0.7630 - f1_score: 0.1344 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9077 - val_loss: 0.3670 - val_precision: 0.9159 - val_recall: 0.7686 - val_f1_score: 0.1408 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9149
#
# Epoch 00050: val_loss did not improve from 0.36643
# Epoch 51/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.3931 - precision: 0.9100 - recall: 0.7628 - f1_score: 0.1373 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9092 - val_loss: 0.3672 - val_precision: 0.9206 - val_recall: 0.7639 - val_f1_score: 0.1391 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9170
#
# Epoch 00051: val_loss did not improve from 0.36643
# Epoch 52/80
# 442/442 [==============================] - 180s 407ms/step - loss: 2.3886 - precision: 0.9096 - recall: 0.7614 - f1_score: 0.1352 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9080 - val_loss: 0.3674 - val_precision: 0.9192 - val_recall: 0.7665 - val_f1_score: 0.1387 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9180
#
# Epoch 00052: val_loss did not improve from 0.36643
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0031250000465661287.
# Epoch 53/80
# 442/442 [==============================] - 179s 405ms/step - loss: 2.3887 - precision: 0.9100 - recall: 0.7617 - f1_score: 0.1360 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9084 - val_loss: 0.3653 - val_precision: 0.9178 - val_recall: 0.7652 - val_f1_score: 0.1466 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9179
#
# Epoch 00053: val_loss improved from 0.36643 to 0.36530, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 54/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.3827 - precision: 0.9101 - recall: 0.7623 - f1_score: 0.1343 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9136 - val_loss: 0.3653 - val_precision: 0.9174 - val_recall: 0.7659 - val_f1_score: 0.1432 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9194
#
# Epoch 00054: val_loss improved from 0.36530 to 0.36527, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 55/80
# 442/442 [==============================] - 171s 388ms/step - loss: 2.3774 - precision: 0.9105 - recall: 0.7616 - f1_score: 0.1351 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9132 - val_loss: 0.3644 - val_precision: 0.9182 - val_recall: 0.7657 - val_f1_score: 0.1436 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9177
#
# Epoch 00055: val_loss improved from 0.36527 to 0.36444, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 56/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.3735 - precision: 0.9104 - recall: 0.7620 - f1_score: 0.1326 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9124 - val_loss: 0.3636 - val_precision: 0.9170 - val_recall: 0.7687 - val_f1_score: 0.1428 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9207
#
# Epoch 00056: val_loss improved from 0.36444 to 0.36364, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 57/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.3846 - precision: 0.9112 - recall: 0.7623 - f1_score: 0.1343 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9089 - val_loss: 0.3644 - val_precision: 0.9214 - val_recall: 0.7625 - val_f1_score: 0.1420 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9181
#
# Epoch 00057: val_loss did not improve from 0.36364
# Epoch 58/80
# 442/442 [==============================] - 178s 404ms/step - loss: 2.3781 - precision: 0.9103 - recall: 0.7620 - f1_score: 0.1322 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9105 - val_loss: 0.3640 - val_precision: 0.9189 - val_recall: 0.7666 - val_f1_score: 0.1441 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9192
#
# Epoch 00058: val_loss did not improve from 0.36364
# Epoch 59/80
# 442/442 [==============================] - 179s 406ms/step - loss: 2.3820 - precision: 0.9107 - recall: 0.7628 - f1_score: 0.1335 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9127 - val_loss: 0.3661 - val_precision: 0.9186 - val_recall: 0.7642 - val_f1_score: 0.1425 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9195
#
# Epoch 00059: val_loss did not improve from 0.36364
# Epoch 60/80
# 442/442 [==============================] - 179s 404ms/step - loss: 2.3820 - precision: 0.9110 - recall: 0.7631 - f1_score: 0.1373 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9118 - val_loss: 0.3643 - val_precision: 0.9201 - val_recall: 0.7667 - val_f1_score: 0.1397 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9179
#
# Epoch 00060: val_loss did not improve from 0.36364
# Epoch 61/80
# 442/442 [==============================] - 171s 386ms/step - loss: 2.3898 - precision: 0.9105 - recall: 0.7620 - f1_score: 0.1333 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9132 - val_loss: 0.3635 - val_precision: 0.9179 - val_recall: 0.7666 - val_f1_score: 0.1457 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9203
#
# Epoch 00061: val_loss improved from 0.36364 to 0.36351, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 62/80
# 442/442 [==============================] - 171s 387ms/step - loss: 2.3808 - precision: 0.9106 - recall: 0.7617 - f1_score: 0.1329 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9140 - val_loss: 0.3651 - val_precision: 0.9178 - val_recall: 0.7658 - val_f1_score: 0.1444 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9185
#
# Epoch 00062: val_loss did not improve from 0.36351
# Epoch 63/80
# 442/442 [==============================] - 172s 387ms/step - loss: 2.3858 - precision: 0.9106 - recall: 0.7625 - f1_score: 0.1330 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9115 - val_loss: 0.3623 - val_precision: 0.9189 - val_recall: 0.7689 - val_f1_score: 0.1415 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9187
#
# Epoch 00063: val_loss improved from 0.36351 to 0.36231, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 64/80
# 442/442 [==============================] - 171s 387ms/step - loss: 2.3800 - precision: 0.9099 - recall: 0.7624 - f1_score: 0.1347 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9126 - val_loss: 0.3619 - val_precision: 0.9189 - val_recall: 0.7690 - val_f1_score: 0.1394 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9192
#
# Epoch 00064: val_loss improved from 0.36231 to 0.36190, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 65/80
# 442/442 [==============================] - 178s 404ms/step - loss: 2.3818 - precision: 0.9106 - recall: 0.7619 - f1_score: 0.1328 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9155 - val_loss: 0.3618 - val_precision: 0.9182 - val_recall: 0.7685 - val_f1_score: 0.1451 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9211
#
# Epoch 00065: val_loss improved from 0.36190 to 0.36179, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 66/80
# 442/442 [==============================] - 171s 387ms/step - loss: 2.3835 - precision: 0.9096 - recall: 0.7614 - f1_score: 0.1342 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9134 - val_loss: 0.3626 - val_precision: 0.9190 - val_recall: 0.7665 - val_f1_score: 0.1433 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9207
#
# Epoch 00066: val_loss did not improve from 0.36179
# Epoch 67/80
# 442/442 [==============================] - 170s 382ms/step - loss: 2.3787 - precision: 0.9098 - recall: 0.7620 - f1_score: 0.1362 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9134 - val_loss: 0.3628 - val_precision: 0.9175 - val_recall: 0.7690 - val_f1_score: 0.1436 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9204
#
# Epoch 00067: val_loss did not improve from 0.36179
# Epoch 68/80
# 442/442 [==============================] - 178s 400ms/step - loss: 2.3758 - precision: 0.9112 - recall: 0.7631 - f1_score: 0.1351 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9101 - val_loss: 0.3624 - val_precision: 0.9191 - val_recall: 0.7683 - val_f1_score: 0.1410 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9194
#
# Epoch 00068: val_loss did not improve from 0.36179
# Epoch 69/80
# 442/442 [==============================] - 167s 379ms/step - loss: 2.3821 - precision: 0.9103 - recall: 0.7627 - f1_score: 0.1350 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9126 - val_loss: 0.3627 - val_precision: 0.9164 - val_recall: 0.7702 - val_f1_score: 0.1430 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9196
#
# Epoch 00069: val_loss did not improve from 0.36179
# Epoch 70/80
# 442/442 [==============================] - 179s 401ms/step - loss: 2.3790 - precision: 0.9103 - recall: 0.7631 - f1_score: 0.1365 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9118 - val_loss: 0.3619 - val_precision: 0.9160 - val_recall: 0.7726 - val_f1_score: 0.1386 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9191
#
# Epoch 00070: val_loss did not improve from 0.36179
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0015625000232830644.
# Epoch 71/80
# 442/442 [==============================] - 168s 381ms/step - loss: 2.3748 - precision: 0.9103 - recall: 0.7624 - f1_score: 0.1337 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9137 - val_loss: 0.3622 - val_precision: 0.9203 - val_recall: 0.7666 - val_f1_score: 0.1428 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9200
#
# Epoch 00071: val_loss did not improve from 0.36179
# Epoch 72/80
# 442/442 [==============================] - 170s 382ms/step - loss: 2.3672 - precision: 0.9118 - recall: 0.7639 - f1_score: 0.1360 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9141 - val_loss: 0.3612 - val_precision: 0.9195 - val_recall: 0.7695 - val_f1_score: 0.1395 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9200
#
# Epoch 00072: val_loss improved from 0.36179 to 0.36125, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-class-weights.h5
# Epoch 73/80
# 442/442 [==============================] - 168s 381ms/step - loss: 2.3686 - precision: 0.9114 - recall: 0.7622 - f1_score: 0.1335 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9125 - val_loss: 0.3619 - val_precision: 0.9197 - val_recall: 0.7682 - val_f1_score: 0.1409 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9211
#
# Epoch 00073: val_loss did not improve from 0.36125
# Epoch 00073: early stopping
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 31

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# Class weights dictionary:
# {0: 9.807246376811593, 1: 45.11333333333334, 2: 40.52095808383234, 3: 56.8655462184874, 4: 74.36263736263736, 5: 5.492694805194805, 6: 65.69902912621359, 7: 58.84347826086957, 8: 20.95046439628483, 9: 21.97077922077922, 10: 45.11333333333334, 11: 22.042345276872965, 12: 4.118685331710286, 13: 10.775477707006369, 14: 50.8796992481203, 15: 54.136, 16: 14.010351966873706}
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 32/80
# 442/442 [==============================] - ETA: 0s - loss: 2.1111 - precision_1: 0.9033 - recall_1: 0.8039 - f1_score: 0.1928 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9098
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 247s 529ms/step - loss: 2.1111 - precision_1: 0.9033 - recall_1: 0.8039 - f1_score: 0.1928 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9098 - val_loss: 0.2319 - val_precision_1: 0.9051 - val_recall_1: 0.8483 - val_f1_score: 0.2079 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9395
#
# Epoch 00032: val_loss improved from inf to 0.23194, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-class-weights.h5
# Epoch 33/80
# 442/442 [==============================] - 242s 547ms/step - loss: 1.6965 - precision_1: 0.9115 - recall_1: 0.8389 - f1_score: 0.2091 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9495 - val_loss: 0.2000 - val_precision_1: 0.9191 - val_recall_1: 0.8394 - val_f1_score: 0.2035 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9534
#
# Epoch 00033: val_loss improved from 0.23194 to 0.20004, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-class-weights.h5
# Epoch 34/80
# 442/442 [==============================] - 241s 547ms/step - loss: 1.5626 - precision_1: 0.9143 - recall_1: 0.8501 - f1_score: 0.2152 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9560 - val_loss: 0.1903 - val_precision_1: 0.9193 - val_recall_1: 0.8471 - val_f1_score: 0.2186 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9483
#
# Epoch 00034: val_loss improved from 0.20004 to 0.19025, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-class-weights.h5
# Epoch 35/80
# 442/442 [==============================] - 242s 549ms/step - loss: 1.4826 - precision_1: 0.9146 - recall_1: 0.8567 - f1_score: 0.2253 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9598 - val_loss: 0.1941 - val_precision_1: 0.9160 - val_recall_1: 0.8471 - val_f1_score: 0.2575 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9469
#
# Epoch 00035: val_loss did not improve from 0.19025
# Epoch 36/80
# 442/442 [==============================] - 241s 545ms/step - loss: 1.4093 - precision_1: 0.9167 - recall_1: 0.8639 - f1_score: 0.2263 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9621 - val_loss: 0.1891 - val_precision_1: 0.9207 - val_recall_1: 0.8430 - val_f1_score: 0.2512 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9517
#
# Epoch 00036: val_loss improved from 0.19025 to 0.18908, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-class-weights.h5
# Epoch 37/80
# 442/442 [==============================] - 242s 548ms/step - loss: 1.3255 - precision_1: 0.9196 - recall_1: 0.8703 - f1_score: 0.2339 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9632 - val_loss: 0.1899 - val_precision_1: 0.9158 - val_recall_1: 0.8544 - val_f1_score: 0.2450 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9483
#
# Epoch 00037: val_loss did not improve from 0.18908
# Epoch 38/80
# 442/442 [==============================] - 233s 528ms/step - loss: 1.2910 - precision_1: 0.9214 - recall_1: 0.8740 - f1_score: 0.2434 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9661 - val_loss: 0.1910 - val_precision_1: 0.9131 - val_recall_1: 0.8538 - val_f1_score: 0.2831 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9504
#
# Epoch 00038: val_loss did not improve from 0.18908
# Epoch 39/80
# 207/442 [=============>................] - ETA: 1:46 - loss: 1.2513 - precision_1: 0.9235 - recall_1: 0.8777 - f1_score: 0.2651 - Multilabel_confusion_matrix: 3312.0000 - auc_1: 0.9666

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)

# %%
l, p = labels_and_probs(nn, valid)

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)

# %%
test_report.round(4)

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
# %%bash
#
# if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#   mkdir -p /root/tensorflow_datasets/amazon-from-space/
#   gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
#   # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
#   #   /root/tensorflow_datasets/amazon-from-space/
# fi

# %%
test_dataset = AmazonFromSpace.load('/root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer_class-weights.csv'), index=False)
answer.head()

# %%
while True:pass
