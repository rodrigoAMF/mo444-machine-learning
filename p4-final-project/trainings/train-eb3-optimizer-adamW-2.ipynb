# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
import tensorflow_addons as tfa

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    #tf.config.experimental.set_virtual_device_configuration(d,
    #    [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10240)])
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = './'
  data_dir = './datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = 1e-4
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tfa.optimizers.AdamW(
      learning_rate=learning_rate,
      weight_decay=1e-4
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb3-ce-adamw-2/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb3-ce-adamw-2.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 120
    learning_rate = 1e-5

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tfa.optimizers.AdamW(
      learning_rate=learning_rate,
      weight_decay=1e-5
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb3-ce-adamw-ft-2/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb3-ce-adamw-ft-2.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
#%%time
#%%bash

#  if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
#    mkdir -p /root/tensorflow_datasets/amazon-from-space/

#    gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
    # If the above is not working:
    # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
    #    /root/tensorflow_datasets/amazon-from-space/
#  else
#    echo "Dir $data_path found. Skipping."
#  fi

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

from pathlib import Path

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# Overriding previous training at .//logs/amazon-from-space-mo444/eb3-ce-adamw-2/.
# Epoch 1/80
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 442/442 [==============================] - ETA: 0s - loss: 0.5337 - precision: 0.7560 - recall: 0.6563 - f1_score: 0.0645 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6716
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# 442/442 [==============================] - 87s 174ms/step - loss: 0.5337 - precision: 0.7560 - recall: 0.6563 - f1_score: 0.0645 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6716 - val_loss: 0.3485 - val_precision: 0.8712 - val_recall: 0.6905 - val_f1_score: 0.0612 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7589
#
# Epoch 00001: val_loss improved from inf to 0.34853, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 2/80
# 442/442 [==============================] - 73s 160ms/step - loss: 0.2891 - precision: 0.8749 - recall: 0.7092 - f1_score: 0.0676 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7550 - val_loss: 0.2509 - val_precision: 0.8796 - val_recall: 0.7128 - val_f1_score: 0.0708 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7813
#
# Epoch 00002: val_loss improved from 0.34853 to 0.25087, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 3/80
# 442/442 [==============================] - 73s 160ms/step - loss: 0.2387 - precision: 0.8778 - recall: 0.7185 - f1_score: 0.0737 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7657 - val_loss: 0.2282 - val_precision: 0.8825 - val_recall: 0.7203 - val_f1_score: 0.0748 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7898
#
# Epoch 00003: val_loss improved from 0.25087 to 0.22822, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 4/80
# 442/442 [==============================] - 72s 158ms/step - loss: 0.2259 - precision: 0.8812 - recall: 0.7231 - f1_score: 0.0778 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7756 - val_loss: 0.2219 - val_precision: 0.8848 - val_recall: 0.7222 - val_f1_score: 0.0773 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7924
#
# Epoch 00004: val_loss improved from 0.22822 to 0.22185, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 5/80
# 442/442 [==============================] - 72s 157ms/step - loss: 0.2221 - precision: 0.8821 - recall: 0.7257 - f1_score: 0.0785 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7738 - val_loss: 0.2194 - val_precision: 0.8855 - val_recall: 0.7224 - val_f1_score: 0.0783 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7946
#
# Epoch 00005: val_loss improved from 0.22185 to 0.21939, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 6/80
# 442/442 [==============================] - 71s 156ms/step - loss: 0.2202 - precision: 0.8833 - recall: 0.7262 - f1_score: 0.0794 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7763 - val_loss: 0.2180 - val_precision: 0.8847 - val_recall: 0.7230 - val_f1_score: 0.0783 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7955
#
# Epoch 00006: val_loss improved from 0.21939 to 0.21805, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 7/80
# 442/442 [==============================] - 73s 160ms/step - loss: 0.2193 - precision: 0.8827 - recall: 0.7248 - f1_score: 0.0787 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7771 - val_loss: 0.2173 - val_precision: 0.8860 - val_recall: 0.7236 - val_f1_score: 0.0795 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7956
#
# Epoch 00007: val_loss improved from 0.21805 to 0.21734, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 8/80
# 442/442 [==============================] - 73s 160ms/step - loss: 0.2185 - precision: 0.8831 - recall: 0.7258 - f1_score: 0.0805 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7744 - val_loss: 0.2166 - val_precision: 0.8867 - val_recall: 0.7233 - val_f1_score: 0.0802 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7963
#
# Epoch 00008: val_loss improved from 0.21734 to 0.21657, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 9/80
# 442/442 [==============================] - 72s 158ms/step - loss: 0.2180 - precision: 0.8837 - recall: 0.7273 - f1_score: 0.0799 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7779 - val_loss: 0.2161 - val_precision: 0.8877 - val_recall: 0.7247 - val_f1_score: 0.0816 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7976
#
# Epoch 00009: val_loss improved from 0.21657 to 0.21609, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 10/80
# 442/442 [==============================] - 72s 158ms/step - loss: 0.2177 - precision: 0.8841 - recall: 0.7259 - f1_score: 0.0800 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7766 - val_loss: 0.2156 - val_precision: 0.8844 - val_recall: 0.7251 - val_f1_score: 0.0782 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7965
#
# Epoch 00010: val_loss improved from 0.21609 to 0.21565, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 11/80
# 442/442 [==============================] - 70s 153ms/step - loss: 0.2170 - precision: 0.8828 - recall: 0.7260 - f1_score: 0.0791 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7776 - val_loss: 0.2152 - val_precision: 0.8859 - val_recall: 0.7232 - val_f1_score: 0.0783 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7966
#
# Epoch 00011: val_loss improved from 0.21565 to 0.21519, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 12/80
# 442/442 [==============================] - 71s 157ms/step - loss: 0.2167 - precision: 0.8833 - recall: 0.7253 - f1_score: 0.0790 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7760 - val_loss: 0.2148 - val_precision: 0.8856 - val_recall: 0.7244 - val_f1_score: 0.0796 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7965
#
# Epoch 00012: val_loss improved from 0.21519 to 0.21482, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 13/80
# 442/442 [==============================] - 74s 163ms/step - loss: 0.2162 - precision: 0.8837 - recall: 0.7251 - f1_score: 0.0781 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7765 - val_loss: 0.2143 - val_precision: 0.8868 - val_recall: 0.7239 - val_f1_score: 0.0795 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7978
#
# Epoch 00013: val_loss improved from 0.21482 to 0.21434, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 14/80
# 442/442 [==============================] - 74s 163ms/step - loss: 0.2157 - precision: 0.8841 - recall: 0.7263 - f1_score: 0.0793 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7769 - val_loss: 0.2140 - val_precision: 0.8866 - val_recall: 0.7242 - val_f1_score: 0.0799 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7976
#
# Epoch 00014: val_loss improved from 0.21434 to 0.21397, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 15/80
# 442/442 [==============================] - 74s 162ms/step - loss: 0.2155 - precision: 0.8833 - recall: 0.7253 - f1_score: 0.0775 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7788 - val_loss: 0.2136 - val_precision: 0.8863 - val_recall: 0.7246 - val_f1_score: 0.0799 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7984
#
# Epoch 00015: val_loss improved from 0.21397 to 0.21357, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 16/80
# 442/442 [==============================] - 71s 155ms/step - loss: 0.2151 - precision: 0.8833 - recall: 0.7252 - f1_score: 0.0788 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7794 - val_loss: 0.2132 - val_precision: 0.8864 - val_recall: 0.7243 - val_f1_score: 0.0772 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7978
#
# Epoch 00016: val_loss improved from 0.21357 to 0.21323, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 17/80
# 442/442 [==============================] - 74s 162ms/step - loss: 0.2146 - precision: 0.8846 - recall: 0.7259 - f1_score: 0.0777 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7799 - val_loss: 0.2129 - val_precision: 0.8866 - val_recall: 0.7248 - val_f1_score: 0.0788 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7996
#
# Epoch 00017: val_loss improved from 0.21323 to 0.21287, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 18/80
# 442/442 [==============================] - 73s 161ms/step - loss: 0.2144 - precision: 0.8839 - recall: 0.7265 - f1_score: 0.0784 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7790 - val_loss: 0.2126 - val_precision: 0.8865 - val_recall: 0.7236 - val_f1_score: 0.0773 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7999
#
# Epoch 00018: val_loss improved from 0.21287 to 0.21260, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 19/80
# 442/442 [==============================] - 74s 163ms/step - loss: 0.2139 - precision: 0.8841 - recall: 0.7258 - f1_score: 0.0781 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7792 - val_loss: 0.2122 - val_precision: 0.8868 - val_recall: 0.7226 - val_f1_score: 0.0790 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7994
#
# Epoch 00019: val_loss improved from 0.21260 to 0.21222, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 20/80
# 442/442 [==============================] - 71s 156ms/step - loss: 0.2136 - precision: 0.8836 - recall: 0.7255 - f1_score: 0.0784 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7836 - val_loss: 0.2119 - val_precision: 0.8871 - val_recall: 0.7235 - val_f1_score: 0.0800 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7999
#
# Epoch 00020: val_loss improved from 0.21222 to 0.21192, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 21/80
# 442/442 [==============================] - 74s 162ms/step - loss: 0.2134 - precision: 0.8837 - recall: 0.7254 - f1_score: 0.0779 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7787 - val_loss: 0.2117 - val_precision: 0.8866 - val_recall: 0.7245 - val_f1_score: 0.0791 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7994
#
# Epoch 00021: val_loss improved from 0.21192 to 0.21170, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 22/80
# 442/442 [==============================] - 72s 159ms/step - loss: 0.2135 - precision: 0.8834 - recall: 0.7246 - f1_score: 0.0769 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7768 - val_loss: 0.2114 - val_precision: 0.8864 - val_recall: 0.7240 - val_f1_score: 0.0782 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7999
#
# Epoch 00022: val_loss improved from 0.21170 to 0.21143, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 23/80
# 442/442 [==============================] - 74s 162ms/step - loss: 0.2129 - precision: 0.8836 - recall: 0.7256 - f1_score: 0.0762 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7779 - val_loss: 0.2111 - val_precision: 0.8875 - val_recall: 0.7238 - val_f1_score: 0.0784 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7997
#
# Epoch 00023: val_loss improved from 0.21143 to 0.21113, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 24/80
# 442/442 [==============================] - 74s 163ms/step - loss: 0.2125 - precision: 0.8843 - recall: 0.7256 - f1_score: 0.0774 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7790 - val_loss: 0.2110 - val_precision: 0.8862 - val_recall: 0.7237 - val_f1_score: 0.0774 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7997
#
# Epoch 00024: val_loss improved from 0.21113 to 0.21100, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 25/80
# 442/442 [==============================] - 70s 154ms/step - loss: 0.2124 - precision: 0.8837 - recall: 0.7245 - f1_score: 0.0770 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7808 - val_loss: 0.2108 - val_precision: 0.8864 - val_recall: 0.7222 - val_f1_score: 0.0762 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8006
#
# Epoch 00025: val_loss improved from 0.21100 to 0.21077, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 26/80
# 442/442 [==============================] - 71s 156ms/step - loss: 0.2122 - precision: 0.8834 - recall: 0.7247 - f1_score: 0.0768 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7777 - val_loss: 0.2105 - val_precision: 0.8866 - val_recall: 0.7246 - val_f1_score: 0.0790 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8010
#
# Epoch 00026: val_loss improved from 0.21077 to 0.21049, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-2.h5
# Epoch 00026: early stopping
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 28

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 29/120
# 442/442 [==============================] - ETA: 0s - loss: 0.3692 - precision_1: 0.7271 - recall_1: 0.7421 - f1_score: 0.1241 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.6870
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# 442/442 [==============================] - 132s 266ms/step - loss: 0.3692 - precision_1: 0.7271 - recall_1: 0.7421 - f1_score: 0.1241 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.6870 - val_loss: 0.2221 - val_precision_1: 0.8876 - val_recall_1: 0.7449 - val_f1_score: 0.1379 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.7875
#
# Epoch 00029: val_loss improved from inf to 0.22208, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 30/120
# 442/442 [==============================] - 121s 268ms/step - loss: 0.2137 - precision_1: 0.9004 - recall_1: 0.7368 - f1_score: 0.1220 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7974 - val_loss: 0.1908 - val_precision_1: 0.9069 - val_recall_1: 0.7726 - val_f1_score: 0.1448 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8280
#
# Epoch 00030: val_loss improved from 0.22208 to 0.19079, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 31/120
# 442/442 [==============================] - 121s 270ms/step - loss: 0.1890 - precision_1: 0.9095 - recall_1: 0.7686 - f1_score: 0.1326 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8417 - val_loss: 0.1725 - val_precision_1: 0.9181 - val_recall_1: 0.7994 - val_f1_score: 0.1531 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8633
#
# Epoch 00031: val_loss improved from 0.19079 to 0.17249, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 32/120
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1752 - precision_1: 0.9157 - recall_1: 0.7914 - f1_score: 0.1431 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8629 - val_loss: 0.1620 - val_precision_1: 0.9218 - val_recall_1: 0.8139 - val_f1_score: 0.1600 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8814
#
# Epoch 00032: val_loss improved from 0.17249 to 0.16199, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 33/120
# 442/442 [==============================] - 119s 266ms/step - loss: 0.1663 - precision_1: 0.9169 - recall_1: 0.8048 - f1_score: 0.1515 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8833 - val_loss: 0.1537 - val_precision_1: 0.9234 - val_recall_1: 0.8294 - val_f1_score: 0.1730 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8989
#
# Epoch 00033: val_loss improved from 0.16199 to 0.15365, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 34/120
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1593 - precision_1: 0.9186 - recall_1: 0.8166 - f1_score: 0.1580 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8958 - val_loss: 0.1479 - val_precision_1: 0.9273 - val_recall_1: 0.8377 - val_f1_score: 0.1788 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9093
#
# Epoch 00034: val_loss improved from 0.15365 to 0.14790, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 35/120
# 442/442 [==============================] - 122s 272ms/step - loss: 0.1543 - precision_1: 0.9208 - recall_1: 0.8252 - f1_score: 0.1651 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9019 - val_loss: 0.1432 - val_precision_1: 0.9299 - val_recall_1: 0.8428 - val_f1_score: 0.1822 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9161
#
# Epoch 00035: val_loss improved from 0.14790 to 0.14320, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 36/120
# 442/442 [==============================] - 122s 270ms/step - loss: 0.1499 - precision_1: 0.9216 - recall_1: 0.8331 - f1_score: 0.1691 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9092 - val_loss: 0.1402 - val_precision_1: 0.9314 - val_recall_1: 0.8473 - val_f1_score: 0.1859 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9214
#
# Epoch 00036: val_loss improved from 0.14320 to 0.14019, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 37/120
# 442/442 [==============================] - 226s 507ms/step - loss: 0.1472 - precision_1: 0.9218 - recall_1: 0.8362 - f1_score: 0.1718 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9110 - val_loss: 0.1369 - val_precision_1: 0.9305 - val_recall_1: 0.8507 - val_f1_score: 0.1910 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9217
#
# Epoch 00037: val_loss improved from 0.14019 to 0.13691, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 38/120
# 442/442 [==============================] - 305s 686ms/step - loss: 0.1438 - precision_1: 0.9241 - recall_1: 0.8415 - f1_score: 0.1748 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9152 - val_loss: 0.1348 - val_precision_1: 0.9305 - val_recall_1: 0.8529 - val_f1_score: 0.1929 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9244
#
# Epoch 00038: val_loss improved from 0.13691 to 0.13482, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 39/120
# 442/442 [==============================] - 118s 263ms/step - loss: 0.1421 - precision_1: 0.9229 - recall_1: 0.8435 - f1_score: 0.1766 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9155 - val_loss: 0.1333 - val_precision_1: 0.9307 - val_recall_1: 0.8555 - val_f1_score: 0.1935 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9263
#
# Epoch 00039: val_loss improved from 0.13482 to 0.13333, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 40/120
# 442/442 [==============================] - 123s 274ms/step - loss: 0.1400 - precision_1: 0.9247 - recall_1: 0.8470 - f1_score: 0.1787 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9155 - val_loss: 0.1320 - val_precision_1: 0.9314 - val_recall_1: 0.8565 - val_f1_score: 0.1915 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9289
#
# Epoch 00040: val_loss improved from 0.13333 to 0.13199, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 41/120
# 442/442 [==============================] - 136s 302ms/step - loss: 0.1381 - precision_1: 0.9246 - recall_1: 0.8501 - f1_score: 0.1810 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9197 - val_loss: 0.1306 - val_precision_1: 0.9307 - val_recall_1: 0.8585 - val_f1_score: 0.1976 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9293
#
# Epoch 00041: val_loss improved from 0.13199 to 0.13058, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 42/120
# 442/442 [==============================] - 120s 267ms/step - loss: 0.1365 - precision_1: 0.9262 - recall_1: 0.8522 - f1_score: 0.1838 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9226 - val_loss: 0.1300 - val_precision_1: 0.9309 - val_recall_1: 0.8600 - val_f1_score: 0.1969 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9310
#
# Epoch 00042: val_loss improved from 0.13058 to 0.12999, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 43/120
# 442/442 [==============================] - 120s 266ms/step - loss: 0.1355 - precision_1: 0.9261 - recall_1: 0.8529 - f1_score: 0.1844 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9232 - val_loss: 0.1290 - val_precision_1: 0.9320 - val_recall_1: 0.8599 - val_f1_score: 0.1936 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9324
#
# Epoch 00043: val_loss improved from 0.12999 to 0.12895, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 44/120
# 442/442 [==============================] - 120s 268ms/step - loss: 0.1340 - precision_1: 0.9270 - recall_1: 0.8563 - f1_score: 0.1846 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9236 - val_loss: 0.1277 - val_precision_1: 0.9312 - val_recall_1: 0.8624 - val_f1_score: 0.1985 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9344
#
# Epoch 00044: val_loss improved from 0.12895 to 0.12772, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 45/120
# 442/442 [==============================] - 120s 268ms/step - loss: 0.1331 - precision_1: 0.9266 - recall_1: 0.8577 - f1_score: 0.1846 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9226 - val_loss: 0.1276 - val_precision_1: 0.9316 - val_recall_1: 0.8621 - val_f1_score: 0.1950 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9338
#
# Epoch 00045: val_loss improved from 0.12772 to 0.12759, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 46/120
# 442/442 [==============================] - 120s 266ms/step - loss: 0.1321 - precision_1: 0.9273 - recall_1: 0.8584 - f1_score: 0.1840 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9286 - val_loss: 0.1266 - val_precision_1: 0.9317 - val_recall_1: 0.8648 - val_f1_score: 0.2005 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9338
#
# Epoch 00046: val_loss improved from 0.12759 to 0.12657, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 47/120
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1314 - precision_1: 0.9270 - recall_1: 0.8599 - f1_score: 0.1866 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9288 - val_loss: 0.1261 - val_precision_1: 0.9306 - val_recall_1: 0.8659 - val_f1_score: 0.2003 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9349
#
# Epoch 00047: val_loss improved from 0.12657 to 0.12614, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 48/120
# 442/442 [==============================] - 120s 267ms/step - loss: 0.1301 - precision_1: 0.9290 - recall_1: 0.8618 - f1_score: 0.1875 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9291 - val_loss: 0.1259 - val_precision_1: 0.9309 - val_recall_1: 0.8662 - val_f1_score: 0.2001 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9354
#
# Epoch 00048: val_loss improved from 0.12614 to 0.12589, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 49/120
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1297 - precision_1: 0.9278 - recall_1: 0.8628 - f1_score: 0.1871 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9307 - val_loss: 0.1255 - val_precision_1: 0.9312 - val_recall_1: 0.8671 - val_f1_score: 0.1994 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9358
#
# Epoch 00049: val_loss improved from 0.12589 to 0.12553, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 50/120
# 442/442 [==============================] - 120s 266ms/step - loss: 0.1289 - precision_1: 0.9285 - recall_1: 0.8640 - f1_score: 0.1903 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9343 - val_loss: 0.1252 - val_precision_1: 0.9307 - val_recall_1: 0.8673 - val_f1_score: 0.2013 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9359
#
# Epoch 00050: val_loss improved from 0.12553 to 0.12522, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 51/120
# 442/442 [==============================] - 121s 269ms/step - loss: 0.1278 - precision_1: 0.9301 - recall_1: 0.8661 - f1_score: 0.1911 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9324 - val_loss: 0.1243 - val_precision_1: 0.9292 - val_recall_1: 0.8706 - val_f1_score: 0.2012 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9352
#
# Epoch 00051: val_loss improved from 0.12522 to 0.12435, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 52/120
# 442/442 [==============================] - 121s 268ms/step - loss: 0.1272 - precision_1: 0.9303 - recall_1: 0.8680 - f1_score: 0.1895 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9358 - val_loss: 0.1245 - val_precision_1: 0.9301 - val_recall_1: 0.8688 - val_f1_score: 0.1982 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9365
#
# Epoch 00052: val_loss did not improve from 0.12435
# Epoch 53/120
# 442/442 [==============================] - 121s 269ms/step - loss: 0.1268 - precision_1: 0.9301 - recall_1: 0.8683 - f1_score: 0.1900 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9337 - val_loss: 0.1245 - val_precision_1: 0.9313 - val_recall_1: 0.8678 - val_f1_score: 0.2012 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9374
#
# Epoch 00053: val_loss did not improve from 0.12435
# Epoch 54/120
# 442/442 [==============================] - 121s 269ms/step - loss: 0.1261 - precision_1: 0.9311 - recall_1: 0.8703 - f1_score: 0.1901 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9338 - val_loss: 0.1238 - val_precision_1: 0.9299 - val_recall_1: 0.8704 - val_f1_score: 0.2029 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9366
#
# Epoch 00054: val_loss improved from 0.12435 to 0.12381, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 55/120
# 442/442 [==============================] - 120s 266ms/step - loss: 0.1257 - precision_1: 0.9312 - recall_1: 0.8704 - f1_score: 0.1899 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9334 - val_loss: 0.1238 - val_precision_1: 0.9293 - val_recall_1: 0.8706 - val_f1_score: 0.1977 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9374
#
# Epoch 00055: val_loss improved from 0.12381 to 0.12378, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 56/120
# 442/442 [==============================] - 118s 263ms/step - loss: 0.1243 - precision_1: 0.9331 - recall_1: 0.8726 - f1_score: 0.1920 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9381 - val_loss: 0.1235 - val_precision_1: 0.9304 - val_recall_1: 0.8707 - val_f1_score: 0.1998 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9364
#
# Epoch 00056: val_loss improved from 0.12378 to 0.12346, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 57/120
# 442/442 [==============================] - 117s 261ms/step - loss: 0.1241 - precision_1: 0.9326 - recall_1: 0.8727 - f1_score: 0.1919 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9384 - val_loss: 0.1231 - val_precision_1: 0.9295 - val_recall_1: 0.8724 - val_f1_score: 0.2037 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9369
#
# Epoch 00057: val_loss improved from 0.12346 to 0.12311, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 58/120
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1237 - precision_1: 0.9346 - recall_1: 0.8739 - f1_score: 0.1925 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9395 - val_loss: 0.1235 - val_precision_1: 0.9297 - val_recall_1: 0.8714 - val_f1_score: 0.1983 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9360
#
# Epoch 00058: val_loss did not improve from 0.12311
# Epoch 59/120
# 442/442 [==============================] - 118s 261ms/step - loss: 0.1230 - precision_1: 0.9335 - recall_1: 0.8749 - f1_score: 0.1940 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9389 - val_loss: 0.1238 - val_precision_1: 0.9307 - val_recall_1: 0.8692 - val_f1_score: 0.2003 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9390
#
# Epoch 00059: val_loss did not improve from 0.12311
# Epoch 60/120
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1223 - precision_1: 0.9339 - recall_1: 0.8757 - f1_score: 0.1941 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9406 - val_loss: 0.1230 - val_precision_1: 0.9297 - val_recall_1: 0.8710 - val_f1_score: 0.1987 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9379
#
# Epoch 00060: val_loss improved from 0.12311 to 0.12300, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 61/120
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1222 - precision_1: 0.9341 - recall_1: 0.8768 - f1_score: 0.1938 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9390 - val_loss: 0.1234 - val_precision_1: 0.9297 - val_recall_1: 0.8715 - val_f1_score: 0.1970 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9389
#
# Epoch 00061: val_loss did not improve from 0.12300
# Epoch 62/120
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1216 - precision_1: 0.9344 - recall_1: 0.8776 - f1_score: 0.1957 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9402 - val_loss: 0.1235 - val_precision_1: 0.9309 - val_recall_1: 0.8702 - val_f1_score: 0.1976 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9388
#
# Epoch 00062: val_loss did not improve from 0.12300
# Epoch 63/120
# 442/442 [==============================] - 121s 268ms/step - loss: 0.1209 - precision_1: 0.9360 - recall_1: 0.8779 - f1_score: 0.1952 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9425 - val_loss: 0.1237 - val_precision_1: 0.9311 - val_recall_1: 0.8696 - val_f1_score: 0.1990 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9384
#
# Epoch 00063: val_loss did not improve from 0.12300
# Epoch 64/120
# 442/442 [==============================] - 120s 266ms/step - loss: 0.1205 - precision_1: 0.9373 - recall_1: 0.8793 - f1_score: 0.1937 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9411 - val_loss: 0.1231 - val_precision_1: 0.9299 - val_recall_1: 0.8713 - val_f1_score: 0.1998 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9379
#
# Epoch 00064: val_loss did not improve from 0.12300
# Epoch 65/120
# 442/442 [==============================] - 118s 263ms/step - loss: 0.1203 - precision_1: 0.9361 - recall_1: 0.8788 - f1_score: 0.1944 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9420 - val_loss: 0.1232 - val_precision_1: 0.9306 - val_recall_1: 0.8719 - val_f1_score: 0.1990 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9387
#
# Epoch 00065: val_loss did not improve from 0.12300
# Epoch 66/120
# 442/442 [==============================] - 118s 263ms/step - loss: 0.1198 - precision_1: 0.9371 - recall_1: 0.8800 - f1_score: 0.1981 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9433 - val_loss: 0.1230 - val_precision_1: 0.9297 - val_recall_1: 0.8719 - val_f1_score: 0.2046 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9387
#
# Epoch 00066: val_loss improved from 0.12300 to 0.12295, saving model to .//models/amazon-from-space-mo444\eb3-ce-adamw-ft-2.h5
# Epoch 00066: early stopping
#
# done

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ............................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  false positive r  false negative r  \
# 0            0.8258           0.9330            0.0670            0.1742
# 1            0.5049           0.9992            0.0008            0.4951
# 2            0.0000           1.0000            0.0000            1.0000
# 3            0.0000           1.0000            0.0000            1.0000
# 4            0.0000           1.0000            0.0000            1.0000
# 5            0.9726           0.9117            0.0883            0.0274
# 6            0.8021           0.9923            0.0077            0.1979
# 7            0.0000           1.0000            0.0000            1.0000
# 8            0.4127           0.9834            0.0166            0.5873
# 9            0.5063           0.9951            0.0049            0.4937
# 10           0.5905           0.9864            0.0136            0.4095
# 11           0.8811           0.9896            0.0104            0.1189
# 12           0.9910           0.6869            0.3131            0.0090
# 13           0.7885           0.9771            0.0229            0.2115
# 14           0.0000           1.0000            0.0000            1.0000
# 15           0.0000           1.0000            0.0000            1.0000
# 16           0.7188           0.9762            0.0238            0.2812
#
#     precision  recall  auc_score  f1_score  f2_score  support  \
# 0      0.8443  0.8258     0.9627    0.8349    0.8294     3696
# 1      0.8525  0.5049     0.9978    0.6341    0.5497      103
# 2      0.0000  0.0000     0.9114    0.0000    0.0000      249
# 3      0.0000  0.0000     0.8374    0.0000    0.0000      101
# 4      0.0000  0.0000     0.8562    0.0000    0.0000       40
# 5      0.9626  0.9726     0.9894    0.9676    0.9706     8473
# 6      0.8569  0.8021     0.9922    0.8286    0.8125      657
# 7      0.0000  0.0000     0.9218    0.0000    0.0000       22
# 8      0.7507  0.4127     0.9224    0.5326    0.4536     1306
# 9      0.9126  0.5063     0.9611    0.6513    0.5558     1114
# 10     0.7532  0.5905     0.9673    0.6620    0.6171      796
# 11     0.9489  0.8811     0.9928    0.9137    0.8939     2170
# 12     0.9750  0.9910     0.9764    0.9829    0.9877    11189
# 13     0.8971  0.7885     0.9777    0.8393    0.8080     2444
# 14     0.0000  0.0000     0.9024    0.0000    0.0000      100
# 15     0.0000  0.0000     0.8840    0.0000    0.0000       59
# 16     0.8716  0.7188     0.9612    0.7878    0.7449     2219
#
#                 label
# 0         agriculture
# 1      artisinal_mine
# 2         bare_ground
# 3            blooming
# 4           blow_down
# 5               clear
# 6              cloudy
# 7   conventional_mine
# 8         cultivation
# 9          habitation
# 10               haze
# 11      partly_cloudy
# 12            primary
# 13               road
# 14  selective_logging
# 15         slash_burn
# 16              water

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
#%%bash

#if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#  mkdir -p /root/tensorflow_datasets/amazon-from-space/
#  gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
  # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
  #   /root/tensorflow_datasets/amazon-from-space/
#fi

# %%
test_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer.csv'), index=False)
answer.head()
# Out:
#    image_name                                   tags
# 0  test_17823                          clear primary
# 1  test_29423         agriculture clear primary road
# 2   file_7472  agriculture clear cultivation primary
# 3  file_11084                          clear primary
# 4  file_16408         agriculture clear primary road
