# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
#      |████████████████████████████████| 686kB 5.4MB/s
#      |████████████████████████████████| 3.9MB 4.3MB/s
# Mounted at /content/drive
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = '/home/ldavid/Workspace'
  data_dir = '/home/ldavid/Workspace/datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 80
    learning_rate = .01

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-adamw-ft/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
# %%time
# %%bash

if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
  mkdir -p /root/tensorflow_datasets/amazon-from-space/

  gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
  # If the above is not working:
  # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
  #    /root/tensorflow_datasets/amazon-from-space/
else
  echo "Dir $data_path found. Skipping."
fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N
# To: /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
# 7.96GB [01:30, 88.2MB/s]
# CPU times: user 901 ms, sys: 237 ms, total: 1.14 s
# Wall time: 3min 28s

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 2s 0us/step

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/80
# 442/442 [==============================] - ETA: 0s - loss: 0.2424 - precision: 0.8720 - recall: 0.7206 - f1_score: 0.0797 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7674
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 201s 398ms/step - loss: 0.2424 - precision: 0.8720 - recall: 0.7206 - f1_score: 0.0797 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7674 - val_loss: 0.2082 - val_precision: 0.8775 - val_recall: 0.7299 - val_f1_score: 0.0748 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8022
#
# Epoch 00001: val_loss improved from inf to 0.20822, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 2/80
# 442/442 [==============================] - 175s 391ms/step - loss: 0.2066 - precision: 0.8831 - recall: 0.7250 - f1_score: 0.0749 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7829 - val_loss: 0.2013 - val_precision: 0.8874 - val_recall: 0.7192 - val_f1_score: 0.0730 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8046
#
# Epoch 00002: val_loss improved from 0.20822 to 0.20133, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 3/80
# 442/442 [==============================] - 175s 389ms/step - loss: 0.2014 - precision: 0.8829 - recall: 0.7220 - f1_score: 0.0710 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7922 - val_loss: 0.1968 - val_precision: 0.8821 - val_recall: 0.7209 - val_f1_score: 0.0730 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8117
#
# Epoch 00003: val_loss improved from 0.20133 to 0.19682, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 4/80
# 442/442 [==============================] - 173s 386ms/step - loss: 0.1973 - precision: 0.8838 - recall: 0.7221 - f1_score: 0.0695 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7980 - val_loss: 0.1938 - val_precision: 0.8828 - val_recall: 0.7268 - val_f1_score: 0.0713 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8167
#
# Epoch 00004: val_loss improved from 0.19682 to 0.19375, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 5/80
# 442/442 [==============================] - 161s 359ms/step - loss: 0.1945 - precision: 0.8833 - recall: 0.7212 - f1_score: 0.0691 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8011 - val_loss: 0.1918 - val_precision: 0.8879 - val_recall: 0.7120 - val_f1_score: 0.0669 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8219
#
# Epoch 00005: val_loss improved from 0.19375 to 0.19184, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 6/80
# 442/442 [==============================] - 176s 391ms/step - loss: 0.1927 - precision: 0.8846 - recall: 0.7199 - f1_score: 0.0656 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8092 - val_loss: 0.1908 - val_precision: 0.8889 - val_recall: 0.7083 - val_f1_score: 0.0680 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8244
#
# Epoch 00006: val_loss improved from 0.19184 to 0.19078, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 7/80
# 442/442 [==============================] - 177s 394ms/step - loss: 0.1914 - precision: 0.8845 - recall: 0.7194 - f1_score: 0.0658 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8135 - val_loss: 0.1890 - val_precision: 0.8854 - val_recall: 0.7152 - val_f1_score: 0.0707 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8311
#
# Epoch 00007: val_loss improved from 0.19078 to 0.18904, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 8/80
# 442/442 [==============================] - 169s 375ms/step - loss: 0.1903 - precision: 0.8845 - recall: 0.7199 - f1_score: 0.0654 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8150 - val_loss: 0.1883 - val_precision: 0.8843 - val_recall: 0.7161 - val_f1_score: 0.0669 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8301
#
# Epoch 00008: val_loss improved from 0.18904 to 0.18826, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 9/80
# 442/442 [==============================] - 178s 394ms/step - loss: 0.1901 - precision: 0.8847 - recall: 0.7192 - f1_score: 0.0660 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8173 - val_loss: 0.1879 - val_precision: 0.8922 - val_recall: 0.7128 - val_f1_score: 0.0696 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8377
#
# Epoch 00009: val_loss improved from 0.18826 to 0.18789, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 10/80
# 442/442 [==============================] - 170s 376ms/step - loss: 0.1895 - precision: 0.8844 - recall: 0.7169 - f1_score: 0.0645 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8244 - val_loss: 0.1874 - val_precision: 0.8815 - val_recall: 0.7171 - val_f1_score: 0.0640 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8333
#
# Epoch 00010: val_loss improved from 0.18789 to 0.18740, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 11/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1888 - precision: 0.8843 - recall: 0.7184 - f1_score: 0.0650 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8274 - val_loss: 0.1868 - val_precision: 0.8886 - val_recall: 0.7139 - val_f1_score: 0.0666 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8344
#
# Epoch 00011: val_loss improved from 0.18740 to 0.18677, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 12/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1886 - precision: 0.8841 - recall: 0.7185 - f1_score: 0.0647 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8274 - val_loss: 0.1868 - val_precision: 0.8866 - val_recall: 0.7117 - val_f1_score: 0.0647 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8408
#
# Epoch 00012: val_loss improved from 0.18677 to 0.18676, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 13/80
# 442/442 [==============================] - 178s 396ms/step - loss: 0.1883 - precision: 0.8848 - recall: 0.7176 - f1_score: 0.0651 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8314 - val_loss: 0.1861 - val_precision: 0.8832 - val_recall: 0.7145 - val_f1_score: 0.0644 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8468
#
# Epoch 00013: val_loss improved from 0.18676 to 0.18613, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 14/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1882 - precision: 0.8837 - recall: 0.7179 - f1_score: 0.0624 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8266 - val_loss: 0.1862 - val_precision: 0.8832 - val_recall: 0.7204 - val_f1_score: 0.0687 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8471
#
# Epoch 00014: val_loss did not improve from 0.18613
# Epoch 15/80
# 442/442 [==============================] - 170s 378ms/step - loss: 0.1882 - precision: 0.8841 - recall: 0.7174 - f1_score: 0.0635 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8316 - val_loss: 0.1860 - val_precision: 0.8883 - val_recall: 0.7146 - val_f1_score: 0.0661 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8391
#
# Epoch 00015: val_loss improved from 0.18613 to 0.18598, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 16/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1881 - precision: 0.8841 - recall: 0.7174 - f1_score: 0.0640 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8266 - val_loss: 0.1866 - val_precision: 0.8847 - val_recall: 0.7127 - val_f1_score: 0.0648 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8482
#
# Epoch 00016: val_loss did not improve from 0.18598
# Epoch 17/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1879 - precision: 0.8841 - recall: 0.7185 - f1_score: 0.0634 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8282 - val_loss: 0.1860 - val_precision: 0.8819 - val_recall: 0.7160 - val_f1_score: 0.0643 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8507
#
# Epoch 00017: val_loss did not improve from 0.18598
# Epoch 18/80
# 442/442 [==============================] - 170s 377ms/step - loss: 0.1876 - precision: 0.8849 - recall: 0.7181 - f1_score: 0.0630 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8247 - val_loss: 0.1859 - val_precision: 0.8865 - val_recall: 0.7137 - val_f1_score: 0.0648 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8544
#
# Epoch 00018: val_loss improved from 0.18598 to 0.18595, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 19/80
# 442/442 [==============================] - 171s 378ms/step - loss: 0.1877 - precision: 0.8845 - recall: 0.7178 - f1_score: 0.0636 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8292 - val_loss: 0.1856 - val_precision: 0.8866 - val_recall: 0.7133 - val_f1_score: 0.0674 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8438
#
# Epoch 00019: val_loss improved from 0.18595 to 0.18561, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 20/80
# 442/442 [==============================] - 170s 377ms/step - loss: 0.1874 - precision: 0.8846 - recall: 0.7189 - f1_score: 0.0625 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8266 - val_loss: 0.1855 - val_precision: 0.8884 - val_recall: 0.7154 - val_f1_score: 0.0668 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8449
#
# Epoch 00020: val_loss improved from 0.18561 to 0.18553, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 21/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1875 - precision: 0.8840 - recall: 0.7180 - f1_score: 0.0635 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8283 - val_loss: 0.1856 - val_precision: 0.8846 - val_recall: 0.7158 - val_f1_score: 0.0635 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8387
#
# Epoch 00021: val_loss did not improve from 0.18553
# Epoch 22/80
# 442/442 [==============================] - 178s 396ms/step - loss: 0.1876 - precision: 0.8840 - recall: 0.7179 - f1_score: 0.0624 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8290 - val_loss: 0.1856 - val_precision: 0.8838 - val_recall: 0.7143 - val_f1_score: 0.0659 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8503
#
# Epoch 00022: val_loss did not improve from 0.18553
# Epoch 23/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1875 - precision: 0.8851 - recall: 0.7173 - f1_score: 0.0632 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8327 - val_loss: 0.1854 - val_precision: 0.8870 - val_recall: 0.7142 - val_f1_score: 0.0668 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8307
#
# Epoch 00023: val_loss improved from 0.18553 to 0.18545, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 24/80
# 442/442 [==============================] - 171s 379ms/step - loss: 0.1870 - precision: 0.8856 - recall: 0.7197 - f1_score: 0.0634 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8340 - val_loss: 0.1855 - val_precision: 0.8859 - val_recall: 0.7117 - val_f1_score: 0.0603 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8319
#
# Epoch 00024: val_loss did not improve from 0.18545
# Epoch 25/80
# 442/442 [==============================] - 178s 396ms/step - loss: 0.1876 - precision: 0.8838 - recall: 0.7170 - f1_score: 0.0633 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8321 - val_loss: 0.1856 - val_precision: 0.8841 - val_recall: 0.7150 - val_f1_score: 0.0620 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8359
#
# Epoch 00025: val_loss did not improve from 0.18545
# Epoch 26/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1873 - precision: 0.8846 - recall: 0.7180 - f1_score: 0.0637 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8341 - val_loss: 0.1855 - val_precision: 0.8867 - val_recall: 0.7115 - val_f1_score: 0.0636 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8332
#
# Epoch 00026: val_loss did not improve from 0.18545
# Epoch 27/80
# 442/442 [==============================] - 170s 377ms/step - loss: 0.1874 - precision: 0.8850 - recall: 0.7189 - f1_score: 0.0641 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8356 - val_loss: 0.1857 - val_precision: 0.8820 - val_recall: 0.7133 - val_f1_score: 0.0607 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8513
#
# Epoch 00027: val_loss did not improve from 0.18545
# Epoch 28/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1873 - precision: 0.8833 - recall: 0.7173 - f1_score: 0.0643 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8353 - val_loss: 0.1855 - val_precision: 0.8870 - val_recall: 0.7150 - val_f1_score: 0.0672 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8340
#
# Epoch 00028: val_loss did not improve from 0.18545
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# Epoch 29/80
# 442/442 [==============================] - 169s 376ms/step - loss: 0.1869 - precision: 0.8850 - recall: 0.7174 - f1_score: 0.0632 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8396 - val_loss: 0.1850 - val_precision: 0.8869 - val_recall: 0.7171 - val_f1_score: 0.0662 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8452
#
# Epoch 00029: val_loss improved from 0.18545 to 0.18500, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 30/80
# 442/442 [==============================] - 177s 394ms/step - loss: 0.1870 - precision: 0.8850 - recall: 0.7182 - f1_score: 0.0635 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8389 - val_loss: 0.1848 - val_precision: 0.8858 - val_recall: 0.7183 - val_f1_score: 0.0604 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8431
#
# Epoch 00030: val_loss improved from 0.18500 to 0.18483, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 31/80
# 442/442 [==============================] - 178s 394ms/step - loss: 0.1868 - precision: 0.8843 - recall: 0.7180 - f1_score: 0.0625 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8375 - val_loss: 0.1848 - val_precision: 0.8871 - val_recall: 0.7150 - val_f1_score: 0.0641 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8438
#
# Epoch 00031: val_loss did not improve from 0.18483
# Epoch 00031: early stopping
#
# done

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=2,  # num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 31

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# Epoch 32/80
# 442/442 [==============================] - 245s 549ms/step - loss: 0.2021 - precision_1: 0.8876 - recall_1: 0.7153 - f1_score: 0.0932 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7855 - val_loss: 0.1650 - val_precision_1: 0.9063 - val_recall_1: 0.7792 - val_f1_score: 0.1487 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8373
#
# Epoch 00032: val_loss improved from inf to 0.16497, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 33/80
# 442/442 [==============================] - 242s 543ms/step - loss: 0.1616 - precision_1: 0.9092 - recall_1: 0.7756 - f1_score: 0.1305 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8471 - val_loss: 0.1460 - val_precision_1: 0.9170 - val_recall_1: 0.8077 - val_f1_score: 0.1637 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8703
#
# Epoch 00033: val_loss improved from 0.16497 to 0.14604, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 34/80
# 442/442 [==============================] - 243s 542ms/step - loss: 0.1479 - precision_1: 0.9131 - recall_1: 0.8005 - f1_score: 0.1437 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8679 - val_loss: 0.1349 - val_precision_1: 0.9226 - val_recall_1: 0.8260 - val_f1_score: 0.1802 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8873
#
# Epoch 00034: val_loss improved from 0.14604 to 0.13495, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 35/80
# 442/442 [==============================] - 230s 517ms/step - loss: 0.1394 - precision_1: 0.9157 - recall_1: 0.8150 - f1_score: 0.1563 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8813 - val_loss: 0.1279 - val_precision_1: 0.9253 - val_recall_1: 0.8358 - val_f1_score: 0.1869 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8962
#
# Epoch 00035: val_loss improved from 0.13495 to 0.12788, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 36/80
# 442/442 [==============================] - 230s 516ms/step - loss: 0.1338 - precision_1: 0.9181 - recall_1: 0.8231 - f1_score: 0.1601 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8854 - val_loss: 0.1232 - val_precision_1: 0.9267 - val_recall_1: 0.8426 - val_f1_score: 0.1911 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9021
#
# Epoch 00036: val_loss improved from 0.12788 to 0.12315, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 37/80
# 442/442 [==============================] - 228s 512ms/step - loss: 0.1296 - precision_1: 0.9180 - recall_1: 0.8303 - f1_score: 0.1646 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8938 - val_loss: 0.1198 - val_precision_1: 0.9272 - val_recall_1: 0.8472 - val_f1_score: 0.1957 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9055
#
# Epoch 00037: val_loss improved from 0.12315 to 0.11975, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 38/80
# 442/442 [==============================] - 239s 533ms/step - loss: 0.1270 - precision_1: 0.9173 - recall_1: 0.8332 - f1_score: 0.1678 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8965 - val_loss: 0.1172 - val_precision_1: 0.9279 - val_recall_1: 0.8474 - val_f1_score: 0.1915 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9077
#
# Epoch 00038: val_loss improved from 0.11975 to 0.11717, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 39/80
# 442/442 [==============================] - 239s 537ms/step - loss: 0.1238 - precision_1: 0.9200 - recall_1: 0.8382 - f1_score: 0.1729 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8997 - val_loss: 0.1148 - val_precision_1: 0.9282 - val_recall_1: 0.8515 - val_f1_score: 0.1954 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9084
#
# Epoch 00039: val_loss improved from 0.11717 to 0.11483, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 40/80
# 442/442 [==============================] - 234s 522ms/step - loss: 0.1218 - precision_1: 0.9200 - recall_1: 0.8406 - f1_score: 0.1744 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9018 - val_loss: 0.1129 - val_precision_1: 0.9288 - val_recall_1: 0.8541 - val_f1_score: 0.2000 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9082
#
# Epoch 00040: val_loss improved from 0.11483 to 0.11290, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 41/80
# 442/442 [==============================] - 252s 544ms/step - loss: 0.1199 - precision_1: 0.9202 - recall_1: 0.8444 - f1_score: 0.1773 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9022 - val_loss: 0.1114 - val_precision_1: 0.9281 - val_recall_1: 0.8572 - val_f1_score: 0.2040 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9103
#
# Epoch 00041: val_loss improved from 0.11290 to 0.11139, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 42/80
# 442/442 [==============================] - 244s 544ms/step - loss: 0.1179 - precision_1: 0.9218 - recall_1: 0.8486 - f1_score: 0.1805 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9042 - val_loss: 0.1102 - val_precision_1: 0.9294 - val_recall_1: 0.8576 - val_f1_score: 0.2036 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9105
#
# Epoch 00042: val_loss improved from 0.11139 to 0.11019, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 43/80
# 442/442 [==============================] - 236s 526ms/step - loss: 0.1165 - precision_1: 0.9223 - recall_1: 0.8499 - f1_score: 0.1817 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9058 - val_loss: 0.1094 - val_precision_1: 0.9295 - val_recall_1: 0.8589 - val_f1_score: 0.2016 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9126
#
# Epoch 00043: val_loss improved from 0.11019 to 0.10936, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 44/80
# 442/442 [==============================] - 243s 542ms/step - loss: 0.1150 - precision_1: 0.9235 - recall_1: 0.8519 - f1_score: 0.1847 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9080 - val_loss: 0.1083 - val_precision_1: 0.9304 - val_recall_1: 0.8599 - val_f1_score: 0.2061 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9138
#
# Epoch 00044: val_loss improved from 0.10936 to 0.10827, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 45/80
# 442/442 [==============================] - 243s 544ms/step - loss: 0.1141 - precision_1: 0.9224 - recall_1: 0.8531 - f1_score: 0.1869 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9094 - val_loss: 0.1074 - val_precision_1: 0.9298 - val_recall_1: 0.8625 - val_f1_score: 0.2076 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9132
#
# Epoch 00045: val_loss improved from 0.10827 to 0.10741, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 46/80
# 442/442 [==============================] - 243s 543ms/step - loss: 0.1131 - precision_1: 0.9225 - recall_1: 0.8550 - f1_score: 0.1864 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9089 - val_loss: 0.1067 - val_precision_1: 0.9289 - val_recall_1: 0.8635 - val_f1_score: 0.1999 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9139
#
# Epoch 00046: val_loss improved from 0.10741 to 0.10675, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 47/80
# 442/442 [==============================] - 236s 527ms/step - loss: 0.1122 - precision_1: 0.9232 - recall_1: 0.8557 - f1_score: 0.1868 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9110 - val_loss: 0.1061 - val_precision_1: 0.9305 - val_recall_1: 0.8635 - val_f1_score: 0.2082 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9143
#
# Epoch 00047: val_loss improved from 0.10675 to 0.10608, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 48/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1108 - precision_1: 0.9237 - recall_1: 0.8568 - f1_score: 0.1879 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9122 - val_loss: 0.1058 - val_precision_1: 0.9315 - val_recall_1: 0.8621 - val_f1_score: 0.2002 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9155
#
# Epoch 00048: val_loss improved from 0.10608 to 0.10577, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 49/80
# 442/442 [==============================] - 244s 545ms/step - loss: 0.1102 - precision_1: 0.9253 - recall_1: 0.8586 - f1_score: 0.1874 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9131 - val_loss: 0.1046 - val_precision_1: 0.9297 - val_recall_1: 0.8678 - val_f1_score: 0.2022 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9167
#
# Epoch 00049: val_loss improved from 0.10577 to 0.10456, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 50/80
# 442/442 [==============================] - 244s 544ms/step - loss: 0.1095 - precision_1: 0.9248 - recall_1: 0.8592 - f1_score: 0.1900 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9140 - val_loss: 0.1043 - val_precision_1: 0.9275 - val_recall_1: 0.8698 - val_f1_score: 0.2089 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9175
#
# Epoch 00050: val_loss improved from 0.10456 to 0.10432, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 51/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1091 - precision_1: 0.9248 - recall_1: 0.8597 - f1_score: 0.1902 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9153 - val_loss: 0.1040 - val_precision_1: 0.9285 - val_recall_1: 0.8684 - val_f1_score: 0.2059 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9173
#
# Epoch 00051: val_loss improved from 0.10432 to 0.10403, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 52/80
# 442/442 [==============================] - 236s 527ms/step - loss: 0.1081 - precision_1: 0.9255 - recall_1: 0.8602 - f1_score: 0.1925 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9148 - val_loss: 0.1032 - val_precision_1: 0.9292 - val_recall_1: 0.8702 - val_f1_score: 0.2115 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9185
#
# Epoch 00052: val_loss improved from 0.10403 to 0.10319, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 53/80
# 442/442 [==============================] - 237s 528ms/step - loss: 0.1069 - precision_1: 0.9262 - recall_1: 0.8637 - f1_score: 0.1910 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9182 - val_loss: 0.1030 - val_precision_1: 0.9282 - val_recall_1: 0.8711 - val_f1_score: 0.2065 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9184
#
# Epoch 00053: val_loss improved from 0.10319 to 0.10304, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 54/80
# 442/442 [==============================] - 237s 529ms/step - loss: 0.1070 - precision_1: 0.9255 - recall_1: 0.8637 - f1_score: 0.1915 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9193 - val_loss: 0.1028 - val_precision_1: 0.9310 - val_recall_1: 0.8682 - val_f1_score: 0.2038 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9194
#
# Epoch 00054: val_loss improved from 0.10304 to 0.10282, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 55/80
# 442/442 [==============================] - 244s 545ms/step - loss: 0.1064 - precision_1: 0.9261 - recall_1: 0.8644 - f1_score: 0.1916 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9165 - val_loss: 0.1021 - val_precision_1: 0.9284 - val_recall_1: 0.8716 - val_f1_score: 0.2116 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9200
#
# Epoch 00055: val_loss improved from 0.10282 to 0.10213, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 56/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1056 - precision_1: 0.9265 - recall_1: 0.8654 - f1_score: 0.1939 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9178 - val_loss: 0.1018 - val_precision_1: 0.9275 - val_recall_1: 0.8732 - val_f1_score: 0.2078 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9207
#
# Epoch 00056: val_loss improved from 0.10213 to 0.10175, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 57/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1048 - precision_1: 0.9275 - recall_1: 0.8668 - f1_score: 0.1952 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9185 - val_loss: 0.1019 - val_precision_1: 0.9271 - val_recall_1: 0.8727 - val_f1_score: 0.2128 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9196
#
# Epoch 00057: val_loss did not improve from 0.10175
# Epoch 58/80
# 442/442 [==============================] - 244s 546ms/step - loss: 0.1043 - precision_1: 0.9272 - recall_1: 0.8672 - f1_score: 0.1981 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9202 - val_loss: 0.1013 - val_precision_1: 0.9292 - val_recall_1: 0.8715 - val_f1_score: 0.2072 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9207
#
# Epoch 00058: val_loss improved from 0.10175 to 0.10133, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 59/80
# 442/442 [==============================] - 244s 546ms/step - loss: 0.1038 - precision_1: 0.9277 - recall_1: 0.8675 - f1_score: 0.1946 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9196 - val_loss: 0.1009 - val_precision_1: 0.9286 - val_recall_1: 0.8732 - val_f1_score: 0.2093 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9217
#
# Epoch 00059: val_loss improved from 0.10133 to 0.10093, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 60/80
# 442/442 [==============================] - 237s 529ms/step - loss: 0.1033 - precision_1: 0.9268 - recall_1: 0.8679 - f1_score: 0.1962 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9226 - val_loss: 0.1010 - val_precision_1: 0.9289 - val_recall_1: 0.8719 - val_f1_score: 0.2115 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9218
#
# Epoch 00060: val_loss did not improve from 0.10093
# Epoch 61/80
# 442/442 [==============================] - 244s 545ms/step - loss: 0.1023 - precision_1: 0.9283 - recall_1: 0.8704 - f1_score: 0.1971 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9232 - val_loss: 0.1010 - val_precision_1: 0.9293 - val_recall_1: 0.8712 - val_f1_score: 0.2089 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9231
#
# Epoch 00061: val_loss did not improve from 0.10093
# Epoch 62/80
# 442/442 [==============================] - 244s 544ms/step - loss: 0.1025 - precision_1: 0.9279 - recall_1: 0.8686 - f1_score: 0.1954 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9250 - val_loss: 0.1004 - val_precision_1: 0.9272 - val_recall_1: 0.8747 - val_f1_score: 0.2074 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9222
#
# Epoch 00062: val_loss improved from 0.10093 to 0.10045, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 63/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1020 - precision_1: 0.9289 - recall_1: 0.8697 - f1_score: 0.1978 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9219 - val_loss: 0.1006 - val_precision_1: 0.9305 - val_recall_1: 0.8714 - val_f1_score: 0.2058 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9219
#
# Epoch 00063: val_loss did not improve from 0.10045
# Epoch 64/80
# 442/442 [==============================] - 244s 546ms/step - loss: 0.1013 - precision_1: 0.9292 - recall_1: 0.8711 - f1_score: 0.1970 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9198 - val_loss: 0.1003 - val_precision_1: 0.9289 - val_recall_1: 0.8728 - val_f1_score: 0.2022 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9240
#
# Epoch 00064: val_loss improved from 0.10045 to 0.10030, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 65/80
# 442/442 [==============================] - 237s 528ms/step - loss: 0.1011 - precision_1: 0.9293 - recall_1: 0.8719 - f1_score: 0.1964 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9259 - val_loss: 0.0997 - val_precision_1: 0.9284 - val_recall_1: 0.8750 - val_f1_score: 0.2072 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9246
#
# Epoch 00065: val_loss improved from 0.10030 to 0.09974, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 66/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1002 - precision_1: 0.9296 - recall_1: 0.8732 - f1_score: 0.1976 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9245 - val_loss: 0.0998 - val_precision_1: 0.9275 - val_recall_1: 0.8754 - val_f1_score: 0.2111 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9250
#
# Epoch 00066: val_loss did not improve from 0.09974
# Epoch 67/80
# 442/442 [==============================] - 245s 546ms/step - loss: 0.1000 - precision_1: 0.9298 - recall_1: 0.8729 - f1_score: 0.2010 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9275 - val_loss: 0.0995 - val_precision_1: 0.9269 - val_recall_1: 0.8766 - val_f1_score: 0.2140 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9254
#
# Epoch 00067: val_loss improved from 0.09974 to 0.09949, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 68/80
# 442/442 [==============================] - 245s 547ms/step - loss: 0.0998 - precision_1: 0.9302 - recall_1: 0.8730 - f1_score: 0.1983 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9243 - val_loss: 0.0997 - val_precision_1: 0.9277 - val_recall_1: 0.8741 - val_f1_score: 0.2111 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9266
#
# Epoch 00068: val_loss did not improve from 0.09949
# Epoch 69/80
# 442/442 [==============================] - 238s 532ms/step - loss: 0.0995 - precision_1: 0.9307 - recall_1: 0.8737 - f1_score: 0.2024 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9280 - val_loss: 0.0997 - val_precision_1: 0.9307 - val_recall_1: 0.8717 - val_f1_score: 0.2130 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9253
#
# Epoch 00069: val_loss did not improve from 0.09949
# Epoch 70/80
# 442/442 [==============================] - 244s 546ms/step - loss: 0.0988 - precision_1: 0.9310 - recall_1: 0.8745 - f1_score: 0.2021 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9266 - val_loss: 0.0995 - val_precision_1: 0.9280 - val_recall_1: 0.8745 - val_f1_score: 0.2133 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9262
#
# Epoch 00070: val_loss improved from 0.09949 to 0.09947, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 71/80
# 442/442 [==============================] - 245s 547ms/step - loss: 0.0988 - precision_1: 0.9292 - recall_1: 0.8754 - f1_score: 0.2007 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9292 - val_loss: 0.0990 - val_precision_1: 0.9292 - val_recall_1: 0.8737 - val_f1_score: 0.2124 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9264
#
# Epoch 00071: val_loss improved from 0.09947 to 0.09901, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 72/80
# 442/442 [==============================] - 245s 547ms/step - loss: 0.0980 - precision_1: 0.9316 - recall_1: 0.8761 - f1_score: 0.2012 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9285 - val_loss: 0.0992 - val_precision_1: 0.9273 - val_recall_1: 0.8756 - val_f1_score: 0.2187 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9268
#
# Epoch 00072: val_loss did not improve from 0.09901
# Epoch 73/80
# 442/442 [==============================] - 244s 546ms/step - loss: 0.0978 - precision_1: 0.9316 - recall_1: 0.8768 - f1_score: 0.2043 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9288 - val_loss: 0.0990 - val_precision_1: 0.9281 - val_recall_1: 0.8762 - val_f1_score: 0.2135 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9263
#
# Epoch 00073: val_loss improved from 0.09901 to 0.09895, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-ft.h5
# Epoch 74/80
# 442/442 [==============================] - 237s 528ms/step - loss: 0.0971 - precision_1: 0.9325 - recall_1: 0.8778 - f1_score: 0.2029 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9336 - val_loss: 0.0994 - val_precision_1: 0.9260 - val_recall_1: 0.8758 - val_f1_score: 0.2160 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9265
#
# Epoch 00074: val_loss did not improve from 0.09895
# Epoch 00074: early stopping
#
# done

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ............................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  ...  support              label
# 0            0.8471           0.9320  ...     3696        agriculture
# 1            0.7961           0.9989  ...      103     artisinal_mine
# 2            0.1044           0.9986  ...      249        bare_ground
# 3            0.0000           1.0000  ...      101           blooming
# 4            0.0000           1.0000  ...       40          blow_down
# 5            0.9691           0.9233  ...     8473              clear
# 6            0.8569           0.9902  ...      657             cloudy
# 7            0.0000           1.0000  ...       22  conventional_mine
# 8            0.4472           0.9797  ...     1306        cultivation
# 9            0.5934           0.9892  ...     1114         habitation
# 10           0.6420           0.9851  ...      796               haze
# 11           0.9129           0.9849  ...     2170      partly_cloudy
# 12           0.9870           0.7541  ...    11189            primary
# 13           0.8171           0.9733  ...     2444               road
# 14           0.0300           0.9998  ...      100  selective_logging
# 15           0.0000           1.0000  ...       59         slash_burn
# 16           0.7404           0.9769  ...     2219              water
#
# [17 rows x 11 columns]

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
# %%bash
#
# if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#   mkdir -p /root/tensorflow_datasets/amazon-from-space/
#   gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
#   # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
#   #   /root/tensorflow_datasets/amazon-from-space/
# fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC
# To: /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
# 12.0GB [02:18, 87.0MB/s]

# %%
test_dataset = AmazonFromSpace.load('/root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer.csv'), index=False)
answer.head()
# Out:
#    image_name                                   tags
# 0  test_17823                          clear primary
# 1  test_29423         agriculture clear primary road
# 2   file_7472  agriculture clear cultivation primary
# 3  file_11084                          clear primary
# 4  file_16408         agriculture clear primary road
