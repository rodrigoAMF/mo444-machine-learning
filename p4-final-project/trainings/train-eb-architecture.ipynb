# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = '/home/ldavid/Workspace'
  data_dir = '/home/ldavid/Workspace/datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 32
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB7

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb7-pyr-ce/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb7-pyr-ce.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.001, verbose=1),
    ]

  class fine_tuning:
    epochs = 120
    learning_rate = .01

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb7-pyr-ce-ft/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.001, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
# %%time
# %%bash

if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
  mkdir -p /root/tensorflow_datasets/amazon-from-space/

  gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
else
  echo "Dir $data_path found. Skipping."
fi
# Out:
# Dir  found. Skipping.
# CPU times: user 1.93 ms, sys: 16.7 ms, total: 18.6 ms
# Wall time: 35.4 ms

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((32, 256, 256, 3), (32, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 1264
#
# validation
#   <PrefetchDataset shapes: ((32, 256, 256, 3), (32, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 379

# %%
#@title

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB7

# %%
feature_layers = ['block3g_add', 'block5j_add', 'top_activation']

backbone = tf.keras.Model(
  inputs=backbone.inputs,
  outputs=[backbone.get_layer(l).output for l in feature_layers]
)

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import Conv2D, Dropout, Dense


def build_classifier(backbone, opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  
  activations = backbone(x)
  features = []

  for ix, y in enumerate(activations):
    y = tfa.layers.SpatialPyramidPooling2D(bins=[1, 3, 5], name=f'pyramid_features_{ix}')(y)
    y = tf.keras.layers.GlobalMaxPooling1D(name=f'max_pool_{ix}')(y)
    features.append(y)
  
  y = tf.keras.layers.concatenate(features)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(backbone, Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
#@title 

# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason.

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)


class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %%
metrics = [
  Precision(from_logits=True, name='precision'),
  Recall(from_logits=True, name='recall'),
  F1Score(num_classes=len(CLASSES), from_logits=True, average='macro', name='f1_score'),
  MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True, name='Multilabel_confusion_matrix'),
  tf.metrics.AUC(multi_label=True, from_logits=True, name='auc'),
]

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=metrics)

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/80
# 442/442 [==============================] - ETA: 0s - loss: 1.5724 - precision: 0.7280 - recall: 0.7236 - f1_score: 0.1912 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6637
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 424s 883ms/step - loss: 1.5724 - precision: 0.7280 - recall: 0.7236 - f1_score: 0.1912 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6637 - val_loss: 1.6105 - val_precision: 0.6977 - val_recall: 0.7946 - val_f1_score: 0.1414 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7458
#
# Epoch 00001: val_loss improved from inf to 1.61046, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 2/80
# 442/442 [==============================] - 434s 978ms/step - loss: 1.4084 - precision: 0.7355 - recall: 0.7289 - f1_score: 0.1936 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6736 - val_loss: 1.2787 - val_precision: 0.7166 - val_recall: 0.7381 - val_f1_score: 0.1190 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6967
#
# Epoch 00002: val_loss improved from 1.61046 to 1.27866, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 3/80
# 442/442 [==============================] - 435s 981ms/step - loss: 1.4279 - precision: 0.7357 - recall: 0.7291 - f1_score: 0.1919 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6711 - val_loss: 0.5756 - val_precision: 0.7907 - val_recall: 0.8159 - val_f1_score: 0.1951 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7708
#
# Epoch 00003: val_loss improved from 1.27866 to 0.57558, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 4/80
# 442/442 [==============================] - 389s 873ms/step - loss: 1.3975 - precision: 0.7378 - recall: 0.7290 - f1_score: 0.1920 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6786 - val_loss: 1.1496 - val_precision: 0.7913 - val_recall: 0.8114 - val_f1_score: 0.2055 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7362
#
# Epoch 00004: val_loss did not improve from 0.57558
# Epoch 5/80
# 442/442 [==============================] - 433s 975ms/step - loss: 1.5010 - precision: 0.7342 - recall: 0.7297 - f1_score: 0.1952 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6771 - val_loss: 1.1063 - val_precision: 0.8580 - val_recall: 0.7521 - val_f1_score: 0.1105 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7253
#
# Epoch 00005: val_loss did not improve from 0.57558
# Epoch 6/80
# 442/442 [==============================] - 433s 974ms/step - loss: 1.4194 - precision: 0.7350 - recall: 0.7289 - f1_score: 0.1891 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6757 - val_loss: 1.2861 - val_precision: 0.8161 - val_recall: 0.5634 - val_f1_score: 0.1447 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7445
#
# Epoch 00006: val_loss did not improve from 0.57558
# Epoch 7/80
# 442/442 [==============================] - 439s 976ms/step - loss: 1.4431 - precision: 0.7353 - recall: 0.7292 - f1_score: 0.1894 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6742 - val_loss: 0.6323 - val_precision: 0.8260 - val_recall: 0.7793 - val_f1_score: 0.1838 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7289
#
# Epoch 00007: val_loss did not improve from 0.57558
# Epoch 8/80
# 442/442 [==============================] - 435s 976ms/step - loss: 1.4253 - precision: 0.7376 - recall: 0.7301 - f1_score: 0.1883 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6785 - val_loss: 1.4165 - val_precision: 0.7320 - val_recall: 0.8056 - val_f1_score: 0.1640 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7313
#
# Epoch 00008: val_loss did not improve from 0.57558
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# Epoch 9/80
# 442/442 [==============================] - 434s 976ms/step - loss: 0.4509 - precision: 0.7874 - recall: 0.7622 - f1_score: 0.1850 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7729 - val_loss: 0.3648 - val_precision: 0.8686 - val_recall: 0.7076 - val_f1_score: 0.1194 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8127
#
# Epoch 00009: val_loss improved from 0.57558 to 0.36481, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 10/80
# 442/442 [==============================] - 437s 981ms/step - loss: 0.4439 - precision: 0.7878 - recall: 0.7606 - f1_score: 0.1803 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7754 - val_loss: 0.3907 - val_precision: 0.8587 - val_recall: 0.7005 - val_f1_score: 0.2097 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8390
#
# Epoch 00010: val_loss did not improve from 0.36481
# Epoch 11/80
# 442/442 [==============================] - 386s 868ms/step - loss: 0.4604 - precision: 0.7852 - recall: 0.7585 - f1_score: 0.1716 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7654 - val_loss: 0.2772 - val_precision: 0.7364 - val_recall: 0.8486 - val_f1_score: 0.2153 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8843
#
# Epoch 00011: val_loss improved from 0.36481 to 0.27722, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 12/80
# 442/442 [==============================] - 389s 873ms/step - loss: 0.4494 - precision: 0.7843 - recall: 0.7585 - f1_score: 0.1837 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7721 - val_loss: 0.4752 - val_precision: 0.7386 - val_recall: 0.8306 - val_f1_score: 0.0586 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8321
#
# Epoch 00012: val_loss did not improve from 0.27722
# Epoch 13/80
# 442/442 [==============================] - 432s 973ms/step - loss: 0.4511 - precision: 0.7851 - recall: 0.7586 - f1_score: 0.1797 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7738 - val_loss: 0.3488 - val_precision: 0.7820 - val_recall: 0.8224 - val_f1_score: 0.1414 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8702
#
# Epoch 00013: val_loss did not improve from 0.27722
# Epoch 14/80
# 442/442 [==============================] - 383s 862ms/step - loss: 0.4301 - precision: 0.7870 - recall: 0.7596 - f1_score: 0.1802 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7685 - val_loss: 0.3238 - val_precision: 0.7829 - val_recall: 0.8545 - val_f1_score: 0.1597 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8611
#
# Epoch 00014: val_loss did not improve from 0.27722
# Epoch 15/80
# 442/442 [==============================] - 432s 971ms/step - loss: 0.4663 - precision: 0.7855 - recall: 0.7595 - f1_score: 0.1783 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7691 - val_loss: 0.4494 - val_precision: 0.7125 - val_recall: 0.7512 - val_f1_score: 0.1663 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8281
#
# Epoch 00015: val_loss did not improve from 0.27722
# Epoch 16/80
# 442/442 [==============================] - 388s 870ms/step - loss: 0.4618 - precision: 0.7829 - recall: 0.7589 - f1_score: 0.1818 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7639 - val_loss: 0.2849 - val_precision: 0.8462 - val_recall: 0.8318 - val_f1_score: 0.1672 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8362
#
# Epoch 00016: val_loss did not improve from 0.27722
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# Epoch 17/80
# 442/442 [==============================] - 388s 871ms/step - loss: 0.1847 - precision: 0.8536 - recall: 0.7895 - f1_score: 0.1643 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8435 - val_loss: 0.1701 - val_precision: 0.8976 - val_recall: 0.7683 - val_f1_score: 0.1060 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9014
#
# Epoch 00017: val_loss improved from 0.27722 to 0.17005, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 18/80
# 442/442 [==============================] - 389s 873ms/step - loss: 0.1805 - precision: 0.8528 - recall: 0.7869 - f1_score: 0.1601 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8442 - val_loss: 0.1511 - val_precision: 0.9015 - val_recall: 0.7910 - val_f1_score: 0.2015 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8819
#
# Epoch 00018: val_loss improved from 0.17005 to 0.15106, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 19/80
# 442/442 [==============================] - 435s 978ms/step - loss: 0.1819 - precision: 0.8526 - recall: 0.7868 - f1_score: 0.1607 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8455 - val_loss: 0.1510 - val_precision: 0.8778 - val_recall: 0.8123 - val_f1_score: 0.1569 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9008
#
# Epoch 00019: val_loss improved from 0.15106 to 0.15099, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 20/80
# 442/442 [==============================] - 388s 872ms/step - loss: 0.1828 - precision: 0.8507 - recall: 0.7857 - f1_score: 0.1594 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8476 - val_loss: 0.1837 - val_precision: 0.8263 - val_recall: 0.8333 - val_f1_score: 0.1615 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8915
#
# Epoch 00020: val_loss did not improve from 0.15099
# Epoch 21/80
# 442/442 [==============================] - 434s 976ms/step - loss: 0.1833 - precision: 0.8500 - recall: 0.7848 - f1_score: 0.1605 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8451 - val_loss: 0.1534 - val_precision: 0.8656 - val_recall: 0.8245 - val_f1_score: 0.1556 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9001
#
# Epoch 00021: val_loss did not improve from 0.15099
# Epoch 22/80
# 442/442 [==============================] - 388s 872ms/step - loss: 0.1810 - precision: 0.8519 - recall: 0.7861 - f1_score: 0.1573 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8453 - val_loss: 0.1718 - val_precision: 0.9176 - val_recall: 0.7413 - val_f1_score: 0.1347 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8943
#
# Epoch 00022: val_loss did not improve from 0.15099
# Epoch 23/80
# 442/442 [==============================] - 434s 976ms/step - loss: 0.1843 - precision: 0.8509 - recall: 0.7846 - f1_score: 0.1601 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8425 - val_loss: 0.1477 - val_precision: 0.9053 - val_recall: 0.7942 - val_f1_score: 0.1718 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9059
#
# Epoch 00023: val_loss improved from 0.15099 to 0.14769, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce.h5
# Epoch 24/80
# 442/442 [==============================] - 389s 873ms/step - loss: 0.1797 - precision: 0.8525 - recall: 0.7865 - f1_score: 0.1585 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8470 - val_loss: 0.1864 - val_precision: 0.8698 - val_recall: 0.7411 - val_f1_score: 0.1770 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.9015
#
# Epoch 00024: val_loss did not improve from 0.14769
# Epoch 25/80
# 442/442 [==============================] - 388s 871ms/step - loss: 0.1825 - precision: 0.8515 - recall: 0.7854 - f1_score: 0.1613 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8449 - val_loss: 0.1515 - val_precision: 0.9093 - val_recall: 0.7843 - val_f1_score: 0.1623 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8885
#
# Epoch 00025: val_loss did not improve from 0.14769
# Epoch 26/80
# 368/442 [=======================>......] - ETA: 48s - loss: 0.1804 - precision: 0.8535 - recall: 0.7848 - f1_score: 0.1575 - Multilabel_confusion_matrix: 5888.0000 - auc: 0.8447
# interrupted

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 25

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=metrics)
# Out:
# Unfreezing 60% layers. Bottom-most is the 325-nth layer (block4e_activation).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 26/120
# 885/885 [==============================] - ETA: 0s - loss: 0.1566 - precision: 0.8768 - recall: 0.8010 - f1_score: 0.1576 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.8510
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 885/885 [==============================] - 746s 801ms/step - loss: 0.1566 - precision: 0.8768 - recall: 0.8010 - f1_score: 0.1576 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.8510 - val_loss: 0.1332 - val_precision: 0.8888 - val_recall: 0.8361 - val_f1_score: 0.1840 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9097
#
# Epoch 00026: val_loss improved from inf to 0.13317, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 27/120
# 885/885 [==============================] - 706s 795ms/step - loss: 0.1379 - precision: 0.8901 - recall: 0.8238 - f1_score: 0.1707 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.8832 - val_loss: 0.1244 - val_precision: 0.9197 - val_recall: 0.8284 - val_f1_score: 0.1914 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.8957
#
# Epoch 00027: val_loss improved from 0.13317 to 0.12444, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 28/120
# 885/885 [==============================] - 667s 748ms/step - loss: 0.1294 - precision: 0.8957 - recall: 0.8351 - f1_score: 0.1801 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.8942 - val_loss: 0.1162 - val_precision: 0.9056 - val_recall: 0.8563 - val_f1_score: 0.1914 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9090
#
# Epoch 00028: val_loss improved from 0.12444 to 0.11622, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 29/120
# 885/885 [==============================] - 706s 794ms/step - loss: 0.1241 - precision: 0.8996 - recall: 0.8422 - f1_score: 0.1794 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.8993 - val_loss: 0.1125 - val_precision: 0.9283 - val_recall: 0.8390 - val_f1_score: 0.2028 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9307
#
# Epoch 00029: val_loss improved from 0.11622 to 0.11250, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 30/120
# 885/885 [==============================] - 706s 794ms/step - loss: 0.1203 - precision: 0.9016 - recall: 0.8450 - f1_score: 0.1833 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9052 - val_loss: 0.1191 - val_precision: 0.8909 - val_recall: 0.8590 - val_f1_score: 0.1910 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9224
#
# Epoch 00030: val_loss did not improve from 0.11250
# Epoch 31/120
# 885/885 [==============================] - 705s 794ms/step - loss: 0.1178 - precision: 0.9035 - recall: 0.8491 - f1_score: 0.1880 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9099 - val_loss: 0.1069 - val_precision: 0.9061 - val_recall: 0.8736 - val_f1_score: 0.2089 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9314
#
# Epoch 00031: val_loss improved from 0.11250 to 0.10694, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 32/120
# 885/885 [==============================] - 666s 749ms/step - loss: 0.1142 - precision: 0.9065 - recall: 0.8544 - f1_score: 0.1899 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9130 - val_loss: 0.1099 - val_precision: 0.8941 - val_recall: 0.8810 - val_f1_score: 0.2004 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9334
#
# Epoch 00032: val_loss did not improve from 0.10694
# Epoch 33/120
# 885/885 [==============================] - 664s 747ms/step - loss: 0.1124 - precision: 0.9081 - recall: 0.8571 - f1_score: 0.1939 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9163 - val_loss: 0.1102 - val_precision: 0.9002 - val_recall: 0.8736 - val_f1_score: 0.2152 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9216
#
# Epoch 00033: val_loss did not improve from 0.10694
# Epoch 34/120
# 885/885 [==============================] - 704s 793ms/step - loss: 0.1108 - precision: 0.9083 - recall: 0.8587 - f1_score: 0.1941 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9186 - val_loss: 0.1092 - val_precision: 0.9028 - val_recall: 0.8705 - val_f1_score: 0.2177 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9277
#
# Epoch 00034: val_loss did not improve from 0.10694
# Epoch 35/120
# 885/885 [==============================] - 705s 793ms/step - loss: 0.1085 - precision: 0.9107 - recall: 0.8621 - f1_score: 0.1989 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9207 - val_loss: 0.1056 - val_precision: 0.9236 - val_recall: 0.8610 - val_f1_score: 0.1436 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9181
#
# Epoch 00035: val_loss improved from 0.10694 to 0.10561, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 36/120
# 885/885 [==============================] - 663s 747ms/step - loss: 0.1076 - precision: 0.9113 - recall: 0.8633 - f1_score: 0.1951 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9216 - val_loss: 0.1038 - val_precision: 0.9225 - val_recall: 0.8625 - val_f1_score: 0.2026 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9205
#
# Epoch 00036: val_loss improved from 0.10561 to 0.10379, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 37/120
# 885/885 [==============================] - 664s 748ms/step - loss: 0.1059 - precision: 0.9123 - recall: 0.8654 - f1_score: 0.1994 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9272 - val_loss: 0.1049 - val_precision: 0.9178 - val_recall: 0.8623 - val_f1_score: 0.2427 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9365
#
# Epoch 00037: val_loss did not improve from 0.10379
# Epoch 38/120
# 885/885 [==============================] - 705s 794ms/step - loss: 0.1048 - precision: 0.9142 - recall: 0.8679 - f1_score: 0.2010 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9265 - val_loss: 0.1084 - val_precision: 0.9125 - val_recall: 0.8602 - val_f1_score: 0.2625 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9312
#
# Epoch 00038: val_loss did not improve from 0.10379
# Epoch 39/120
# 885/885 [==============================] - 664s 748ms/step - loss: 0.1027 - precision: 0.9150 - recall: 0.8695 - f1_score: 0.2057 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9234 - val_loss: 0.1083 - val_precision: 0.8854 - val_recall: 0.8843 - val_f1_score: 0.2193 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9395
#
# Epoch 00039: val_loss did not improve from 0.10379
# Epoch 40/120
# 885/885 [==============================] - 664s 747ms/step - loss: 0.1010 - precision: 0.9179 - recall: 0.8714 - f1_score: 0.2051 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9342 - val_loss: 0.1025 - val_precision: 0.9198 - val_recall: 0.8657 - val_f1_score: 0.2188 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9394
#
# Epoch 00040: val_loss improved from 0.10379 to 0.10246, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 41/120
# 885/885 [==============================] - 705s 794ms/step - loss: 0.1005 - precision: 0.9167 - recall: 0.8730 - f1_score: 0.2064 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9317 - val_loss: 0.1054 - val_precision: 0.9081 - val_recall: 0.8766 - val_f1_score: 0.1930 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9363
#
# Epoch 00041: val_loss did not improve from 0.10246
# Epoch 42/120
# 885/885 [==============================] - 665s 748ms/step - loss: 0.0989 - precision: 0.9184 - recall: 0.8744 - f1_score: 0.2045 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9344 - val_loss: 0.1087 - val_precision: 0.9326 - val_recall: 0.8456 - val_f1_score: 0.2121 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9385
#
# Epoch 00042: val_loss did not improve from 0.10246
# Epoch 43/120
# 885/885 [==============================] - 664s 748ms/step - loss: 0.0973 - precision: 0.9189 - recall: 0.8771 - f1_score: 0.2049 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9358 - val_loss: 0.1055 - val_precision: 0.9192 - val_recall: 0.8652 - val_f1_score: 0.2297 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9306
#
# Epoch 00043: val_loss did not improve from 0.10246
# Epoch 44/120
# 885/885 [==============================] - 705s 794ms/step - loss: 0.0964 - precision: 0.9197 - recall: 0.8778 - f1_score: 0.2113 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9336 - val_loss: 0.1089 - val_precision: 0.9173 - val_recall: 0.8600 - val_f1_score: 0.2115 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9347
#
# Epoch 00044: val_loss did not improve from 0.10246
# Epoch 45/120
# 885/885 [==============================] - 664s 747ms/step - loss: 0.0949 - precision: 0.9209 - recall: 0.8796 - f1_score: 0.2078 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9384 - val_loss: 0.1056 - val_precision: 0.9215 - val_recall: 0.8590 - val_f1_score: 0.2225 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9358
#
# Epoch 00045: val_loss did not improve from 0.10246
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 46/120
# 885/885 [==============================] - 705s 794ms/step - loss: 0.0884 - precision: 0.9282 - recall: 0.8855 - f1_score: 0.2072 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9494 - val_loss: 0.1000 - val_precision: 0.9204 - val_recall: 0.8681 - val_f1_score: 0.2305 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9331
#
# Epoch 00046: val_loss improved from 0.10246 to 0.09998, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 47/120
# 885/885 [==============================] - 664s 747ms/step - loss: 0.0880 - precision: 0.9280 - recall: 0.8864 - f1_score: 0.2112 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9470 - val_loss: 0.1023 - val_precision: 0.9302 - val_recall: 0.8545 - val_f1_score: 0.2164 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9376
#
# Epoch 00047: val_loss did not improve from 0.09998
# Epoch 48/120
# 885/885 [==============================] - 705s 794ms/step - loss: 0.0864 - precision: 0.9291 - recall: 0.8877 - f1_score: 0.2081 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9512 - val_loss: 0.0995 - val_precision: 0.9253 - val_recall: 0.8660 - val_f1_score: 0.2270 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9391
#
# Epoch 00048: val_loss improved from 0.09998 to 0.09946, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 49/120
# 885/885 [==============================] - 664s 748ms/step - loss: 0.0858 - precision: 0.9296 - recall: 0.8882 - f1_score: 0.2113 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9508 - val_loss: 0.0996 - val_precision: 0.9231 - val_recall: 0.8677 - val_f1_score: 0.2245 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9409
#
# Epoch 00049: val_loss did not improve from 0.09946
# Epoch 50/120
# 885/885 [==============================] - 704s 793ms/step - loss: 0.0861 - precision: 0.9294 - recall: 0.8874 - f1_score: 0.2135 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9525 - val_loss: 0.0990 - val_precision: 0.9154 - val_recall: 0.8762 - val_f1_score: 0.2395 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9402
#
# Epoch 00050: val_loss improved from 0.09946 to 0.09903, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 51/120
# 885/885 [==============================] - 664s 747ms/step - loss: 0.0850 - precision: 0.9299 - recall: 0.8893 - f1_score: 0.2115 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9521 - val_loss: 0.1001 - val_precision: 0.9166 - val_recall: 0.8741 - val_f1_score: 0.2259 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9390
#
# Epoch 00051: val_loss did not improve from 0.09903
# Epoch 52/120
# 885/885 [==============================] - 704s 793ms/step - loss: 0.0843 - precision: 0.9298 - recall: 0.8909 - f1_score: 0.2134 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9537 - val_loss: 0.0985 - val_precision: 0.9238 - val_recall: 0.8687 - val_f1_score: 0.2424 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9409
#
# Epoch 00052: val_loss improved from 0.09903 to 0.09845, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb7-pyr-ce-ft.h5
# Epoch 53/120
# 885/885 [==============================] - 663s 747ms/step - loss: 0.0839 - precision: 0.9315 - recall: 0.8917 - f1_score: 0.2129 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9558 - val_loss: 0.1003 - val_precision: 0.9211 - val_recall: 0.8696 - val_f1_score: 0.2409 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9430
#
# Epoch 00053: val_loss did not improve from 0.09845
# Epoch 54/120
# 885/885 [==============================] - 662s 746ms/step - loss: 0.0823 - precision: 0.9334 - recall: 0.8934 - f1_score: 0.2170 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9556 - val_loss: 0.1010 - val_precision: 0.9205 - val_recall: 0.8712 - val_f1_score: 0.2037 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9430
#
# Epoch 00054: val_loss did not improve from 0.09845
# Epoch 55/120
# 885/885 [==============================] - 662s 746ms/step - loss: 0.0821 - precision: 0.9329 - recall: 0.8942 - f1_score: 0.2170 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9548 - val_loss: 0.1042 - val_precision: 0.9177 - val_recall: 0.8690 - val_f1_score: 0.2239 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9377
#
# Epoch 00055: val_loss did not improve from 0.09845
# Epoch 56/120
# 885/885 [==============================] - 707s 796ms/step - loss: 0.0816 - precision: 0.9336 - recall: 0.8941 - f1_score: 0.2149 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9582 - val_loss: 0.1029 - val_precision: 0.9161 - val_recall: 0.8684 - val_f1_score: 0.2070 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9407
#
# Epoch 00056: val_loss did not improve from 0.09845
# Epoch 57/120
# 885/885 [==============================] - 707s 796ms/step - loss: 0.0811 - precision: 0.9335 - recall: 0.8961 - f1_score: 0.2217 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9531 - val_loss: 0.1070 - val_precision: 0.9279 - val_recall: 0.8528 - val_f1_score: 0.2343 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9395
#
# Epoch 00057: val_loss did not improve from 0.09845
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 58/120
# 885/885 [==============================] - 707s 796ms/step - loss: 0.0775 - precision: 0.9367 - recall: 0.8988 - f1_score: 0.2209 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9600 - val_loss: 0.1009 - val_precision: 0.9249 - val_recall: 0.8631 - val_f1_score: 0.2500 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9432
#
# Epoch 00058: val_loss did not improve from 0.09845
# Epoch 59/120
# 885/885 [==============================] - 667s 751ms/step - loss: 0.0770 - precision: 0.9376 - recall: 0.8987 - f1_score: 0.2179 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9616 - val_loss: 0.0993 - val_precision: 0.9186 - val_recall: 0.8714 - val_f1_score: 0.2293 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9416
#
# Epoch 00059: val_loss did not improve from 0.09845
# Epoch 60/120
# 885/885 [==============================] - 666s 750ms/step - loss: 0.0763 - precision: 0.9376 - recall: 0.8999 - f1_score: 0.2170 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9616 - val_loss: 0.1002 - val_precision: 0.9199 - val_recall: 0.8687 - val_f1_score: 0.2231 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9400
#
# Epoch 00060: val_loss did not improve from 0.09845
# Epoch 61/120
# 885/885 [==============================] - 707s 796ms/step - loss: 0.0758 - precision: 0.9388 - recall: 0.9009 - f1_score: 0.2174 - Multilabel_confusion_matrix: 7080.0000 - auc: 0.9632 - val_loss: 0.1010 - val_precision: 0.9162 - val_recall: 0.8705 - val_f1_score: 0.2334 - val_Multilabel_confusion_matrix: 3032.0000 - val_auc: 0.9425
#
# Epoch 00061: val_loss did not improve from 0.09845
# Epoch 62/120
# 683/885 [======================>.......] - ETA: 2:08 - loss: 0.0752 - precision: 0.9390 - recall: 0.9010 - f1_score: 0.2160 - Multilabel_confusion_matrix: 5464.0000 - auc: 0.9642
# interrupted

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 325-nth layer (block4e_activation).

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ..........................................................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  ...  support              label
# 0            0.7957           0.9489  ...     3701        agriculture
# 1            0.8350           0.9978  ...      103     artisinal_mine
# 2            0.1520           0.9971  ...      250        bare_ground
# 3            0.0000           1.0000  ...      101           blooming
# 4            0.0000           1.0000  ...       40          blow_down
# 5            0.9617           0.9254  ...     8496              clear
# 6            0.8667           0.9881  ...      660             cloudy
# 7            0.1818           0.9998  ...       22  conventional_mine
# 8            0.4889           0.9699  ...     1307        cultivation
# 9            0.5727           0.9882  ...     1114         habitation
# 10           0.6342           0.9817  ...      801               haze
# 11           0.9277           0.9781  ...     2171      partly_cloudy
# 12           0.9807           0.7857  ...    11218            primary
# 13           0.8113           0.9729  ...     2448               road
# 14           0.1600           0.9989  ...      100  selective_logging
# 15           0.0000           1.0000  ...       59         slash_burn
# 16           0.7315           0.9758  ...     2220              water
#
# [17 rows x 11 columns]

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
# %%bash
#
# if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#   mkdir -p /root/tensorflow_datasets/amazon-from-space/
#   gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
#   # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
#   #   /root/tensorflow_datasets/amazon-from-space/
# fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC
# To: /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
# 12.0GB [02:16, 87.9MB/s]

# %%
test_dataset = AmazonFromSpace.load('/root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer.csv'), index=False)
answer.head()
# Out:
#    image_name                            tags
# 0  test_17823                   clear primary
# 1  test_29423  agriculture clear primary road
# 2   file_7472       clear cultivation primary
# 3  file_11084                   clear primary
# 4  file_16408  agriculture clear primary road
