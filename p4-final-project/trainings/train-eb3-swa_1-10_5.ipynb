# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
import tensorflow_addons as tfa

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
#      |████████████████████████████████| 679 kB 15.0 MB/s
#      |████████████████████████████████| 3.9 MB 15.3 MB/s
# Mounted at /content/drive
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = '/home/ldavid/Workspace'
  data_dir = '/home/ldavid/Workspace/datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )
    optimizer = tfa.optimizers.SWA(optimizer)

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce_swa_1-10_5/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce_swa_1-10_5.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tfa.callbacks.AverageModelCheckpoint(filepath=weights, update_weights=True),
      #tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 80
    learning_rate = .01

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )
    #optimizer = tfa.optimizers.SWA(optimizer)

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      #tfa.callbacks.AverageModelCheckpoint(filepath=weights, update_weights=True),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
# %%time
# %%bash

if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
  mkdir -p /root/tensorflow_datasets/amazon-from-space/

  gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
  # If the above is not working:
  # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
  #    /root/tensorflow_datasets/amazon-from-space/
else
  echo "Dir $data_path found. Skipping."
fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N
# To: /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
# 7.96GB [01:24, 94.2MB/s]
# CPU times: user 814 ms, sys: 215 ms, total: 1.03 s
# Wall time: 3min 25s

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 2s 0us/step

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/80
# 442/442 [==============================] - ETA: 0s - loss: 0.2429 - precision: 0.8683 - recall: 0.7216 - f1_score: 0.0802 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7682
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 156s 293ms/step - loss: 0.2429 - precision: 0.8683 - recall: 0.7216 - f1_score: 0.0802 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7682 - val_loss: 0.2083 - val_precision: 0.8789 - val_recall: 0.7265 - val_f1_score: 0.0762 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8000
# Streaming output truncated to the last 5000 lines.
#
#        [[[-7.70429075e-02],
#          [ 1.35194302e-01],
#          [ 2.38602180e-02],
#          ...,
#          [-4.69583422e-02],
#          [ 1.27352104e-02],
#          [-7.03235567e-02]],
#
#         [[-6.69617057e-02],
#          [ 1.48655444e-01],
#          [ 1.36044309e-01],
#          ...,
#          [-7.10463747e-02],
#          [ 1.40615404e-01],
#          [-1.29940420e-01]],
#
#         [[-4.94735539e-02],
#          [ 1.59622252e-01],
#          [ 2.14897111e-01],
#          ...,
#          [-6.21024370e-02],
#          [ 2.18211442e-01],
#          [-1.47659779e-01]],
#
#         [[-6.38500527e-02],
#          [-1.57007024e-01],
#          [ 1.36619687e-01],
#          ...,
#          [-6.99566901e-02],
#          [ 1.31631553e-01],
#          [-1.31685913e-01]],
#
#         [[-8.19320679e-02],
#          [-1.50478482e-01],
#          [ 1.85322464e-02],
#          ...,
#          [-4.47282642e-02],
#          [ 2.81547271e-02],
#          [-7.01122731e-02]]],
#
#
#        [[[-6.53636083e-02],
#          [ 1.31535977e-02],
#          [-3.57617438e-03],
#          ...,
#          [-2.87181586e-02],
#          [-9.34050977e-03],
#          [-1.69550329e-02]],
#
#         [[-8.33362788e-02],
#          [ 9.21142101e-03],
#          [-1.13565996e-02],
#          ...,
#          [-8.19391310e-02],
#          [ 3.06252986e-02],
#          [-9.68651474e-02]],
#
#         [[-7.84494504e-02],
#          [ 1.71422780e-01],
#          [ 2.16416419e-02],
#          ...,
#          [-6.38082623e-02],
#          [ 4.57435027e-02],
#          [-1.24966003e-01]],
#
#         [[-6.87844902e-02],
#          [-1.17677569e-01],
#          [-3.19798291e-03],
#          ...,
#          [-7.49913156e-02],
#          [ 1.26299262e-02],
#          [-8.65992010e-02]],
#
#         [[-5.60020097e-02],
#          [-1.07847646e-01],
#          [ 6.65999949e-04],
#          ...,
#          [-4.39583547e-02],
#          [-4.13373113e-03],
#          [-3.18845659e-02]]],
#
#
#        [[[-9.66383517e-03],
#          [ 4.98233736e-02],
#          [-7.08052516e-03],
#          ...,
#          [-1.57372374e-02],
#          [ 5.43594360e-05],
#          [-7.62562454e-03]],
#
#         [[-5.14079258e-02],
#          [ 3.00184786e-02],
#          [-6.07682019e-02],
#          ...,
#          [-2.85385288e-02],
#          [-3.37910131e-02],
#          [-8.87094066e-03]],
#
#         [[-9.71488208e-02],
#          [ 1.57443777e-01],
#          [-8.13888237e-02],
#          ...,
#          [-3.66506800e-02],
#          [-6.37193024e-02],
#          [-5.09973615e-02]],
#
#         [[-5.06086648e-02],
#          [-1.21147692e-01],
#          [-5.40952981e-02],
#          ...,
#          [-3.21619809e-02],
#          [-2.42190510e-02],
#          [-2.82374471e-02]],
#
#         [[-6.60735369e-03],
#          [-1.16735846e-01],
#          [-1.22846067e-02],
#          ...,
#          [-1.18325353e-02],
#          [-2.20278054e-02],
#          [-4.84113395e-03]]]], dtype=float32)> : 'block6a_dwconv/depthwise_kernel_4752'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'block6a_bn/gamma:0' shape=(816,) dtype=float32, numpy=
# array([2.4706318 , 4.056445  , 0.885751  , 1.6259284 , 0.7720455 ,
#        0.92442924, 0.95240515, 0.91074604, 1.5201957 , 0.8483966 ,
#        0.89580846, 0.9196571 , 1.1808265 , 0.74369985, 0.8073368 ,
#        0.8547703 , 0.8866467 , 0.9142623 , 1.8406501 , 0.80876696,
#        0.979161  , 0.9119585 , 0.9656242 , 2.7809057 , 0.83664006,
#        2.1340005 , 1.2297897 , 0.7851982 , 0.9452381 , 0.9292239 ,
#        2.064901  , 0.6691245 , 0.80644184, 0.7960945 , 0.88917536,
#        1.7355617 , 2.0090017 , 1.3405641 , 1.0534508 , 0.9644706 ,
#        0.9475252 , 2.1544924 , 0.79990125, 0.86045295, 1.2580007 ,

#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'top_bn/moving_mean:0' shape=(1536,) dtype=float32, numpy=
# array([-0.7824582 , -0.6517221 , -0.7151278 , ..., -0.60616785,
#        -0.88167506, -0.659207  ], dtype=float32)> : 'top_bn/moving_mean_6632'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'top_bn/moving_variance:0' shape=(1536,) dtype=float32, numpy=
# array([13.170659, 13.983763, 14.454587, ..., 12.546841, 14.921362,
#        13.314286], dtype=float32)> : 'top_bn/moving_variance_6637'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# Epoch 2/80
# 442/442 [==============================] - 130s 291ms/step - loss: 0.2110 - precision: 0.8830 - recall: 0.7249 - f1_score: 0.0765 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7755 - val_loss: 0.2048 - val_precision: 0.8883 - val_recall: 0.7176 - val_f1_score: 0.0751 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8025
# Epoch 3/80
# 442/442 [==============================] - 131s 290ms/step - loss: 0.2091 - precision: 0.8830 - recall: 0.7236 - f1_score: 0.0752 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7815 - val_loss: 0.2031 - val_precision: 0.8817 - val_recall: 0.7202 - val_f1_score: 0.0766 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8055
# Epoch 4/80
# 442/442 [==============================] - 130s 291ms/step - loss: 0.2075 - precision: 0.8827 - recall: 0.7247 - f1_score: 0.0743 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7864 - val_loss: 0.2020 - val_precision: 0.8834 - val_recall: 0.7262 - val_f1_score: 0.0762 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8064
# Epoch 5/80
# 442/442 [==============================] - 130s 290ms/step - loss: 0.2065 - precision: 0.8835 - recall: 0.7245 - f1_score: 0.0744 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7859 - val_loss: 0.2015 - val_precision: 0.8868 - val_recall: 0.7158 - val_f1_score: 0.0722 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8070
# Epoch 6/80
# 442/442 [==============================] - 150s 334ms/step - loss: 0.2060 - precision: 0.8848 - recall: 0.7238 - f1_score: 0.0742 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7887 - val_loss: 0.2015 - val_precision: 0.8879 - val_recall: 0.7137 - val_f1_score: 0.0738 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8071
# Epoch 7/80
# 442/442 [==============================] - 144s 318ms/step - loss: 0.2053 - precision: 0.8842 - recall: 0.7245 - f1_score: 0.0746 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7864 - val_loss: 0.2006 - val_precision: 0.8853 - val_recall: 0.7174 - val_f1_score: 0.0780 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8079
# Epoch 8/80
# 442/442 [==============================] - 153s 339ms/step - loss: 0.2049 - precision: 0.8832 - recall: 0.7244 - f1_score: 0.0738 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7858 - val_loss: 0.2003 - val_precision: 0.8833 - val_recall: 0.7191 - val_f1_score: 0.0727 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8058
# Epoch 9/80
# 442/442 [==============================] - 146s 322ms/step - loss: 0.2048 - precision: 0.8829 - recall: 0.7237 - f1_score: 0.0734 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7863 - val_loss: 0.2003 - val_precision: 0.8915 - val_recall: 0.7182 - val_f1_score: 0.0800 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8080
# Epoch 10/80
# 442/442 [==============================] - 140s 310ms/step - loss: 0.2043 - precision: 0.8848 - recall: 0.7234 - f1_score: 0.0734 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7881 - val_loss: 0.1998 - val_precision: 0.8817 - val_recall: 0.7225 - val_f1_score: 0.0710 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8068
# Epoch 11/80
# 442/442 [==============================] - 161s 339ms/step - loss: 0.2040 - precision: 0.8840 - recall: 0.7236 - f1_score: 0.0737 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7843 - val_loss: 0.1995 - val_precision: 0.8879 - val_recall: 0.7164 - val_f1_score: 0.0739 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8093
# Epoch 12/80
# 442/442 [==============================] - 146s 323ms/step - loss: 0.2039 - precision: 0.8826 - recall: 0.7233 - f1_score: 0.0731 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.
- val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8106
# Epoch 36/80
# 442/442 [==============================] - 146s 323ms/step - loss: 0.2020 - precision: 0.8853 - recall: 0.7247 - f1_score: 0.0736 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7902 - val_loss: 0.1998 - val_precision: 0.8851 - val_recall: 0.7240 - val_f1_score: 0.0729 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8118
# Epoch 37/80
# 442/442 [==============================] - 154s 341ms/step - loss: 0.2022 - precision: 0.8852 - recall: 0.7246 - f1_score: 0.0725 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7884 - val_loss: 0.1998 - val_precision: 0.8872 - val_recall: 0.7211 - val_f1_score: 0.0724 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8111
# Epoch 38/80
# 442/442 [==============================] - 146s 321ms/step - loss: 0.2021 - precision: 0.8843 - recall: 0.7240 - f1_score: 0.0733 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7889 - val_loss: 0.1998 - val_precision: 0.8871 - val_recall: 0.7226 - val_f1_score: 0.0741 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8118
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# Epoch 39/80
# 442/442 [==============================] - 155s 342ms/step - loss: 0.2023 - precision: 0.8842 - recall: 0.7233 - f1_score: 0.0717 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7919 - val_loss: 0.2004 - val_precision: 0.8869 - val_recall: 0.7214 - val_f1_score: 0.0736 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8098
# Epoch 00039: early stopping
#
# done

# %%
# just after training and before evaluation, apply weight averaging

Config.fine_tuning.optimizer.assign_average_vars(nn.variables)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-10383ced3e38> in <module>()
#       1 # just after training and before evaluation, apply weight averaging
#       2
# ----> 3 Config.fine_tuning.optimizer.assign_average_vars(nn.variables)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in __getattribute__(self, name)
#     836       if name in self._hyper:
#     837         return self._get_hyper(name)
# --> 838       raise e
#     839
#     840   def __dir__(self):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in __getattribute__(self, name)
#     826     """Overridden to support hyperparameter access."""
#     827     try:
# --> 828       return super(OptimizerV2, self).__getattribute__(name)
#     829     except AttributeError as e:
#     830       # Needed to avoid infinite recursion with __setattr__.
#
# AttributeError: 'SGD' object has no attribute 'assign_average_vars'

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 31

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 32/80
# 442/442 [==============================] - ETA: 0s - loss: 0.2502 - precision_1: 0.8736 - recall_1: 0.7215 - f1_score: 0.1044 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7304
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 199s 414ms/step - loss: 0.2502 - precision_1: 0.8736 - recall_1: 0.7215 - f1_score: 0.1044 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7304 - val_loss: 0.1827 - val_precision_1: 0.9013 - val_recall_1: 0.7741 - val_f1_score: 0.1464 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8122
#
# Epoch 00032: val_loss improved from inf to 0.18271, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 33/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1775 - precision_1: 0.9074 - recall_1: 0.7731 - f1_score: 0.1343 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8323 - val_loss: 0.1582 - val_precision_1: 0.9112 - val_recall_1: 0.8121 - val_f1_score: 0.1766 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8640
#
# Epoch 00033: val_loss improved from 0.18271 to 0.15822, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 34/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1599 - precision_1: 0.9124 - recall_1: 0.7994 - f1_score: 0.1531 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8654 - val_loss: 0.1459 - val_precision_1: 0.9160 - val_recall_1: 0.8303 - val_f1_score: 0.1919 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8899
#
# Epoch 00034: val_loss improved from 0.15822 to 0.14593, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 35/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1503 - precision_1: 0.9137 - recall_1: 0.8139 - f1_score: 0.1613 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8876 - val_loss: 0.1386 - val_precision_1: 0.9190 - val_recall_1: 0.8386 - val_f1_score: 0.1993 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9075
#
# Epoch 00035: val_loss improved from 0.14593 to 0.13865, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 36/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1443 - precision_1: 0.9149 - recall_1: 0.8220 - f1_score: 0.1694 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8961 - val_loss: 0.1339 - val_precision_1: 0.9196 - val_recall_1: 0.8457 - val_f1_score: 0.2058 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9148
#
# Epoch 00036: val_loss improved from 0.13865 to 0.13392, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 37/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1394 - precision_1: 0.9165 - recall_1: 0.8304 - f1_score: 0.1741 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9069 - val_loss: 0.1302 - val_precision_1: 0.9207 - val_recall_1: 0.8497 - val_f1_score: 0.2056 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9201
#
# Epoch 00037: val_loss improved from 0.13392 to 0.13015, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 38/80
# 442/442 [==============================] - 188s 412ms/step - loss: 0.1361 - precision_1: 0.9173 - recall_1: 0.8338 - f1_score: 0.1766 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9168 - val_loss: 0.1268 - val_precision_1: 0.9221 - val_recall_1: 0.8534 - val_f1_score: 0.2035 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9247
#
# Epoch 00038: val_loss improved from 0.13015 to 0.12676, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 39/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1335 - precision_1: 0.9187 - recall_1: 0.8376 - f1_score: 0.1774 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9155 - val_loss: 0.1246 - val_precision_1: 0.9241 - val_recall_1: 0.8540 - val_f1_score: 0.2053 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9270
#
# Epoch 00039: val_loss improved from 0.12676 to 0.12462, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 40/80
# 442/442 [==============================] - 177s 392ms/step - loss: 0.1309 - precision_1: 0.9188 - recall_1: 0.8413 - f1_score: 0.1828 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9162 - val_loss: 0.1231 - val_precision_1: 0.9253 - val_recall_1: 0.8547 - val_f1_score: 0.2047 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9280
#
# Epoch 00040: val_loss improved from 0.12462 to 0.12306, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 41/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1294 - precision_1: 0.9196 - recall_1: 0.8430 - f1_score: 0.1806 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9172 - val_loss: 0.1212 - val_precision_1: 0.9247 - val_recall_1: 0.8571 - val_f1_score: 0.2019 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9336
#
# Epoch 00041: val_loss improved from 0.12306 to 0.12125, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 42/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1265 - precision_1: 0.9209 - recall_1: 0.8469 - f1_score: 0.1838 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9262 - val_loss: 0.1196 - val_precision_1: 0.9240 - val_recall_1: 0.8602 - val_f1_score: 0.2007 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9324
#
# Epoch 00042: val_loss improved from 0.12125 to 0.11963, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 43/80
# 442/442 [==============================] - 184s 409ms/step - loss: 0.1250 - precision_1: 0.9208 - recall_1: 0.8482 - f1_score: 0.1849 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9225 - val_loss: 0.1184 - val_precision_1: 0.9261 - val_recall_1: 0.8587 - val_f1_score: 0.2050 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9339
#
# Epoch 00043: val_loss improved from 0.11963 to 0.11839, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 44/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1236 - precision_1: 0.9216 - recall_1: 0.8507 - f1_score: 0.1872 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9305 - val_loss: 0.1173 - val_precision_1: 0.9250 - val_recall_1: 0.8613 - val_f1_score: 0.2050 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9350
#
# Epoch 00044: val_loss improved from 0.11839 to 0.11729, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 45/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1226 - precision_1: 0.9217 - recall_1: 0.8520 - f1_score: 0.1854 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9302 - val_loss: 0.1162 - val_precision_1: 0.9261 - val_recall_1: 0.8606 - val_f1_score: 0.2013 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9363
#
# Epoch 00045: val_loss improved from 0.11729 to 0.11622, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 46/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1212 - precision_1: 0.9218 - recall_1: 0.8527 - f1_score: 0.1872 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9301 - val_loss: 0.1150 - val_precision_1: 0.9260 - val_recall_1: 0.8644 - val_f1_score: 0.2034 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9366
#
# Epoch 00046: val_loss improved from 0.11622 to 0.11504, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 47/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1202 - precision_1: 0.9226 - recall_1: 0.8549 - f1_score: 0.1878 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9320 - val_loss: 0.1142 - val_precision_1: 0.9261 - val_recall_1: 0.8640 - val_f1_score: 0.2054 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9371
#
# Epoch 00047: val_loss improved from 0.11504 to 0.11420, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 48/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1189 - precision_1: 0.9232 - recall_1: 0.8572 - f1_score: 0.1896 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9311 - val_loss: 0.1133 - val_precision_1: 0.9254 - val_recall_1: 0.8662 - val_f1_score: 0.2061 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9377
#
# Epoch 00048: val_loss improved from 0.11420 to 0.11328, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 49/80
# 442/442 [==============================] - 185s 412ms/step - loss: 0.1180 - precision_1: 0.9233 - recall_1: 0.8576 - f1_score: 0.1907 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9352 - val_loss: 0.1130 - val_precision_1: 0.9273 - val_recall_1: 0.8640 - val_f1_score: 0.2043 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9382
#
# Epoch 00049: val_loss improved from 0.11328 to 0.11295, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 50/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1171 - precision_1: 0.9231 - recall_1: 0.8585 - f1_score: 0.1896 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9362 - val_loss: 0.1119 - val_precision_1: 0.9267 - val_recall_1: 0.8659 - val_f1_score: 0.2008 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9396
#
# Epoch 00050: val_loss improved from 0.11295 to 0.11191, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 51/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1162 - precision_1: 0.9249 - recall_1: 0.8607 - f1_score: 0.1891 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9357 - val_loss: 0.1115 - val_precision_1: 0.9263 - val_recall_1: 0.8668 - val_f1_score: 0.2027 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9402
#
# Epoch 00051: val_loss improved from 0.11191 to 0.11152, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 52/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1155 - precision_1: 0.9238 - recall_1: 0.8604 - f1_score: 0.1879 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9358 - val_loss: 0.1112 - val_precision_1: 0.9262 - val_recall_1: 0.8669 - val_f1_score: 0.2029 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9408
#
# Epoch 00052: val_loss improved from 0.11152 to 0.11117, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 53/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1148 - precision_1: 0.9249 - recall_1: 0.8614 - f1_score: 0.1901 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9379 - val_loss: 0.1103 - val_precision_1: 0.9255 - val_recall_1: 0.8705 - val_f1_score: 0.2038 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9401
#
# Epoch 00053: val_loss improved from 0.11117 to 0.11029, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 54/80
# 442/442 [==============================] - 185s 412ms/step - loss: 0.1138 - precision_1: 0.9249 - recall_1: 0.8639 - f1_score: 0.1898 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9374 - val_loss: 0.1097 - val_precision_1: 0.9276 - val_recall_1: 0.8684 - val_f1_score: 0.2061 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9421
#
# Epoch 00054: val_loss improved from 0.11029 to 0.10975, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 55/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1133 - precision_1: 0.9248 - recall_1: 0.8628 - f1_score: 0.1914 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9376 - val_loss: 0.1092 - val_precision_1: 0.9270 - val_recall_1: 0.8698 - val_f1_score: 0.2048 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9414
#
# Epoch 00055: val_loss improved from 0.10975 to 0.10920, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 56/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1125 - precision_1: 0.9265 - recall_1: 0.8632 - f1_score: 0.1923 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9391 - val_loss: 0.1086 - val_precision_1: 0.9260 - val_recall_1: 0.8720 - val_f1_score: 0.2027 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9416
#
# Epoch 00056: val_loss improved from 0.10920 to 0.10856, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 57/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1117 - precision_1: 0.9251 - recall_1: 0.8651 - f1_score: 0.1906 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9407 - val_loss: 0.1084 - val_precision_1: 0.9260 - val_recall_1: 0.8716 - val_f1_score: 0.2050 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9418
#
# Epoch 00057: val_loss improved from 0.10856 to 0.10841, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 58/80
# 442/442 [==============================] - 185s 412ms/step - loss: 0.1114 - precision_1: 0.9258 - recall_1: 0.8656 - f1_score: 0.1918 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9411 - val_loss: 0.1080 - val_precision_1: 0.9267 - val_recall_1: 0.8699 - val_f1_score: 0.2056 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9434
#
# Epoch 00058: val_loss improved from 0.10841 to 0.10800, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 59/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1108 - precision_1: 0.9269 - recall_1: 0.8661 - f1_score: 0.1917 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9424 - val_loss: 0.1077 - val_precision_1: 0.9263 - val_recall_1: 0.8722 - val_f1_score: 0.2061 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9434
#
# Epoch 00059: val_loss improved from 0.10800 to 0.10771, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 60/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1099 - precision_1: 0.9265 - recall_1: 0.8679 - f1_score: 0.1942 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9417 - val_loss: 0.1077 - val_precision_1: 0.9251 - val_recall_1: 0.8721 - val_f1_score: 0.2076 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9433
#
# Epoch 00060: val_loss improved from 0.10771 to 0.10766, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 61/80
# 442/442 [==============================] - 185s 412ms/step - loss: 0.1091 - precision_1: 0.9278 - recall_1: 0.8674 - f1_score: 0.1966 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9409 - val_loss: 0.1068 - val_precision_1: 0.9278 - val_recall_1: 0.8717 - val_f1_score: 0.2026 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9444
#
# Epoch 00061: val_loss improved from 0.10766 to 0.10682, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 62/80
# 442/442 [==============================] - 175s 389ms/step - loss: 0.1089 - precision_1: 0.9275 - recall_1: 0.8687 - f1_score: 0.1935 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9419 - val_loss: 0.1067 - val_precision_1: 0.9245 - val_recall_1: 0.8751 - val_f1_score: 0.2016 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9440
#
# Epoch 00062: val_loss improved from 0.10682 to 0.10672, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 63/80
# 442/442 [==============================] - 186s 411ms/step - loss: 0.1079 - precision_1: 0.9289 - recall_1: 0.8697 - f1_score: 0.1950 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9433 - val_loss: 0.1064 - val_precision_1: 0.9257 - val_recall_1: 0.8739 - val_f1_score: 0.2063 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9431
#
# Epoch 00063: val_loss improved from 0.10672 to 0.10639, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 64/80
# 442/442 [==============================] - 177s 394ms/step - loss: 0.1075 - precision_1: 0.9292 - recall_1: 0.8713 - f1_score: 0.1959 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9452 - val_loss: 0.1066 - val_precision_1: 0.9275 - val_recall_1: 0.8712 - val_f1_score: 0.2024 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9429
#
# Epoch 00064: val_loss did not improve from 0.10639
# Epoch 65/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1070 - precision_1: 0.9278 - recall_1: 0.8709 - f1_score: 0.1942 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9442 - val_loss: 0.1060 - val_precision_1: 0.9280 - val_recall_1: 0.8725 - val_f1_score: 0.2057 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9458
#
# Epoch 00065: val_loss improved from 0.10639 to 0.10601, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 66/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1061 - precision_1: 0.9301 - recall_1: 0.8727 - f1_score: 0.1949 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9467 - val_loss: 0.1055 - val_precision_1: 0.9272 - val_recall_1: 0.8740 - val_f1_score: 0.2029 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9450
#
# Epoch 00066: val_loss improved from 0.10601 to 0.10550, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 67/80
# 442/442 [==============================] - 186s 412ms/step - loss: 0.1062 - precision_1: 0.9297 - recall_1: 0.8720 - f1_score: 0.1957 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9444 - val_loss: 0.1054 - val_precision_1: 0.9256 - val_recall_1: 0.8755 - val_f1_score: 0.2054 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9439
#
# Epoch 00067: val_loss improved from 0.10550 to 0.10542, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 68/80
# 442/442 [==============================] - 176s 391ms/step - loss: 0.1057 - precision_1: 0.9292 - recall_1: 0.8731 - f1_score: 0.1977 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9436 - val_loss: 0.1050 - val_precision_1: 0.9255 - val_recall_1: 0.8760 - val_f1_score: 0.2043 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9442
#
# Epoch 00068: val_loss improved from 0.10542 to 0.10498, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_5_ft.h5
# Epoch 69/80
# 442/442 [==============================] - 186s 411ms/step - loss: 0.1047 - precision_1: 0.9298 - recall_1: 0.8742 - f1_score: 0.1963 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9466 - val_loss: 0.1052 - val_precision_1: 0.9247 - val_recall_1: 0.8752 - val_f1_score: 0.2038 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9441
#
# Epoch 00069: val_loss did not improve from 0.10498
# Epoch 00069: early stopping
#
# done

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
l, p = labels_and_probs(nn, valid)

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)

# %%
test_report.round(4)

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
# %%bash
#
# if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#   mkdir -p /root/tensorflow_datasets/amazon-from-space/
#   gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
#   # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
#   #   /root/tensorflow_datasets/amazon-from-space/
# fi

# %%
test_dataset = AmazonFromSpace.load('/root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer_swa_1-10_5.csv'), index=False)
answer.head()

# %%
while True:pass

# %%
answer.head()
