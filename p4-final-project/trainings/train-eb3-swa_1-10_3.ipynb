# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
import tensorflow_addons as tfa

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
#      |████████████████████████████████| 686kB 13.5MB/s
#      |████████████████████████████████| 3.9MB 14.6MB/s
# Mounted at /content/drive
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = '/home/ldavid/Workspace'
  data_dir = '/home/ldavid/Workspace/datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )
    optimizer = tfa.optimizers.SWA(optimizer)

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce_swa_1-10_3/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 80
    learning_rate = .01

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )
    optimizer = tfa.optimizers.SWA(optimizer)

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-swa_1-10_3/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
# %%time
# %%bash

if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
  mkdir -p /root/tensorflow_datasets/amazon-from-space/

  gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
  # If the above is not working:
  # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
  #    /root/tensorflow_datasets/amazon-from-space/
else
  echo "Dir $data_path found. Skipping."
fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N
# To: /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
# 7.96GB [01:23, 95.1MB/s]
# CPU times: user 896 ms, sys: 199 ms, total: 1.1 s
# Wall time: 3min 25s

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 2s 0us/step

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/80
# 442/442 [==============================] - ETA: 0s - loss: 0.2425 - precision: 0.8703 - recall: 0.7211 - f1_score: 0.0793 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7691
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 155s 291ms/step - loss: 0.2425 - precision: 0.8703 - recall: 0.7211 - f1_score: 0.0793 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7691 - val_loss: 0.2083 - val_precision: 0.8796 - val_recall: 0.7269 - val_f1_score: 0.0766 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8001
#
# Epoch 00001: val_loss improved from inf to 0.20828, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 2/80
# 442/442 [==============================] - 148s 332ms/step - loss: 0.2066 - precision: 0.8829 - recall: 0.7244 - f1_score: 0.0753 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7842 - val_loss: 0.2015 - val_precision: 0.8887 - val_recall: 0.7156 - val_f1_score: 0.0727 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8041
#
# Epoch 00002: val_loss improved from 0.20828 to 0.20152, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 3/80
# 442/442 [==============================] - 124s 276ms/step - loss: 0.2014 - precision: 0.8825 - recall: 0.7224 - f1_score: 0.0717 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7899 - val_loss: 0.1969 - val_precision: 0.8817 - val_recall: 0.7202 - val_f1_score: 0.0731 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8121
#
# Epoch 00003: val_loss improved from 0.20152 to 0.19695, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 4/80
# 442/442 [==============================] - 124s 276ms/step - loss: 0.1972 - precision: 0.8832 - recall: 0.7212 - f1_score: 0.0698 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7993 - val_loss: 0.1937 - val_precision: 0.8854 - val_recall: 0.7233 - val_f1_score: 0.0727 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8160
#
# Epoch 00004: val_loss improved from 0.19695 to 0.19371, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 5/80
# 442/442 [==============================] - 126s 281ms/step - loss: 0.1946 - precision: 0.8843 - recall: 0.7211 - f1_score: 0.0690 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8030 - val_loss: 0.1917 - val_precision: 0.8876 - val_recall: 0.7129 - val_f1_score: 0.0677 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8218
#
# Epoch 00005: val_loss improved from 0.19371 to 0.19173, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 6/80
# 442/442 [==============================] - 125s 278ms/step - loss: 0.1928 - precision: 0.8847 - recall: 0.7201 - f1_score: 0.0656 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8083 - val_loss: 0.1907 - val_precision: 0.8873 - val_recall: 0.7090 - val_f1_score: 0.0677 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8237
#
# Epoch 00006: val_loss improved from 0.19173 to 0.19068, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 7/80
# 442/442 [==============================] - 147s 325ms/step - loss: 0.1915 - precision: 0.8845 - recall: 0.7184 - f1_score: 0.0658 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8132 - val_loss: 0.1891 - val_precision: 0.8861 - val_recall: 0.7129 - val_f1_score: 0.0700 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8317
#
# Epoch 00007: val_loss improved from 0.19068 to 0.18915, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 8/80
# 442/442 [==============================] - 149s 332ms/step - loss: 0.1904 - precision: 0.8843 - recall: 0.7202 - f1_score: 0.0663 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8175 - val_loss: 0.1882 - val_precision: 0.8849 - val_recall: 0.7159 - val_f1_score: 0.0683 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8318
#
# Epoch 00008: val_loss improved from 0.18915 to 0.18820, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 9/80
# 442/442 [==============================] - 154s 332ms/step - loss: 0.1901 - precision: 0.8845 - recall: 0.7188 - f1_score: 0.0661 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8175 - val_loss: 0.1878 - val_precision: 0.8922 - val_recall: 0.7127 - val_f1_score: 0.0701 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8360
#
# Epoch 00009: val_loss improved from 0.18820 to 0.18784, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 10/80
# 442/442 [==============================] - 151s 334ms/step - loss: 0.1895 - precision: 0.8846 - recall: 0.7184 - f1_score: 0.0650 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8270 - val_loss: 0.1873 - val_precision: 0.8818 - val_recall: 0.7170 - val_f1_score: 0.0638 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8334
#
# Epoch 00010: val_loss improved from 0.18784 to 0.18735, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 11/80
# 442/442 [==============================] - 155s 332ms/step - loss: 0.1889 - precision: 0.8847 - recall: 0.7179 - f1_score: 0.0647 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8280 - val_loss: 0.1869 - val_precision: 0.8890 - val_recall: 0.7112 - val_f1_score: 0.0667 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8345
#
# Epoch 00011: val_loss improved from 0.18735 to 0.18692, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 12/80
# 442/442 [==============================] - 150s 331ms/step - loss: 0.1884 - precision: 0.8839 - recall: 0.7185 - f1_score: 0.0647 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8293 - val_loss: 0.1866 - val_precision: 0.8860 - val_recall: 0.7127 - val_f1_score: 0.0642 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8408
#
# Epoch 00012: val_loss improved from 0.18692 to 0.18662, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 13/80
# 442/442 [==============================] - 150s 332ms/step - loss: 0.1884 - precision: 0.8846 - recall: 0.7178 - f1_score: 0.0642 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8297 - val_loss: 0.1862 - val_precision: 0.8838 - val_recall: 0.7139 - val_f1_score: 0.0638 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8470
#
# Epoch 00013: val_loss improved from 0.18662 to 0.18622, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 14/80
# 442/442 [==============================] - 152s 332ms/step - loss: 0.1881 - precision: 0.8837 - recall: 0.7176 - f1_score: 0.0637 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8301 - val_loss: 0.1861 - val_precision: 0.8834 - val_recall: 0.7194 - val_f1_score: 0.0675 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8468
#
# Epoch 00014: val_loss improved from 0.18622 to 0.18610, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 15/80
# 442/442 [==============================] - 152s 330ms/step - loss: 0.1883 - precision: 0.8832 - recall: 0.7167 - f1_score: 0.0632 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8301 - val_loss: 0.1859 - val_precision: 0.8894 - val_recall: 0.7147 - val_f1_score: 0.0674 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8398
#
# Epoch 00015: val_loss improved from 0.18610 to 0.18592, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 16/80
# 442/442 [==============================] - 143s 315ms/step - loss: 0.1883 - precision: 0.8835 - recall: 0.7168 - f1_score: 0.0637 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8265 - val_loss: 0.1865 - val_precision: 0.8844 - val_recall: 0.7132 - val_f1_score: 0.0655 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8498
#
# Epoch 00016: val_loss did not improve from 0.18592
# Epoch 17/80
# 442/442 [==============================] - 142s 314ms/step - loss: 0.1877 - precision: 0.8848 - recall: 0.7189 - f1_score: 0.0638 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8288 - val_loss: 0.1860 - val_precision: 0.8829 - val_recall: 0.7149 - val_f1_score: 0.0641 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8514
#
# Epoch 00017: val_loss did not improve from 0.18592
# Epoch 18/80
# 442/442 [==============================] - 150s 332ms/step - loss: 0.1877 - precision: 0.8846 - recall: 0.7176 - f1_score: 0.0630 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8242 - val_loss: 0.1859 - val_precision: 0.8860 - val_recall: 0.7130 - val_f1_score: 0.0652 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8522
#
# Epoch 00018: val_loss improved from 0.18592 to 0.18586, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 19/80
# 442/442 [==============================] - 153s 333ms/step - loss: 0.1877 - precision: 0.8845 - recall: 0.7180 - f1_score: 0.0640 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8276 - val_loss: 0.1855 - val_precision: 0.8855 - val_recall: 0.7139 - val_f1_score: 0.0663 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8451
#
# Epoch 00019: val_loss improved from 0.18586 to 0.18546, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 20/80
# 442/442 [==============================] - 153s 333ms/step - loss: 0.1877 - precision: 0.8840 - recall: 0.7179 - f1_score: 0.0630 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8236 - val_loss: 0.1856 - val_precision: 0.8876 - val_recall: 0.7149 - val_f1_score: 0.0635 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8449
#
# Epoch 00020: val_loss did not improve from 0.18546
# Epoch 21/80
# 442/442 [==============================] - 150s 332ms/step - loss: 0.1876 - precision: 0.8840 - recall: 0.7183 - f1_score: 0.0639 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8288 - val_loss: 0.1856 - val_precision: 0.8835 - val_recall: 0.7166 - val_f1_score: 0.0634 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8419
#
# Epoch 00021: val_loss did not improve from 0.18546
# Epoch 22/80
# 442/442 [==============================] - 150s 333ms/step - loss: 0.1876 - precision: 0.8837 - recall: 0.7190 - f1_score: 0.0630 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8266 - val_loss: 0.1855 - val_precision: 0.8840 - val_recall: 0.7135 - val_f1_score: 0.0649 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8505
#
# Epoch 00022: val_loss did not improve from 0.18546
# Epoch 23/80
# 442/442 [==============================] - 151s 335ms/step - loss: 0.1874 - precision: 0.8849 - recall: 0.7174 - f1_score: 0.0631 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8311 - val_loss: 0.1853 - val_precision: 0.8854 - val_recall: 0.7154 - val_f1_score: 0.0659 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8299
#
# Epoch 00023: val_loss improved from 0.18546 to 0.18528, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 24/80
# 442/442 [==============================] - 140s 309ms/step - loss: 0.1871 - precision: 0.8848 - recall: 0.7191 - f1_score: 0.0634 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8338 - val_loss: 0.1854 - val_precision: 0.8866 - val_recall: 0.7127 - val_f1_score: 0.0609 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8349
#
# Epoch 00024: val_loss did not improve from 0.18528
# Epoch 25/80
# 442/442 [==============================] - 154s 334ms/step - loss: 0.1875 - precision: 0.8844 - recall: 0.7175 - f1_score: 0.0631 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8329 - val_loss: 0.1856 - val_precision: 0.8841 - val_recall: 0.7153 - val_f1_score: 0.0619 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8371
#
# Epoch 00025: val_loss did not improve from 0.18528
# Epoch 26/80
# 442/442 [==============================] - 154s 334ms/step - loss: 0.1874 - precision: 0.8845 - recall: 0.7179 - f1_score: 0.0638 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8317 - val_loss: 0.1855 - val_precision: 0.8863 - val_recall: 0.7127 - val_f1_score: 0.0645 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8319
#
# Epoch 00026: val_loss did not improve from 0.18528
# Epoch 27/80
# 442/442 [==============================] - 151s 335ms/step - loss: 0.1876 - precision: 0.8847 - recall: 0.7176 - f1_score: 0.0637 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8356 - val_loss: 0.1857 - val_precision: 0.8825 - val_recall: 0.7133 - val_f1_score: 0.0606 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8525
#
# Epoch 00027: val_loss did not improve from 0.18528
# Epoch 28/80
# 442/442 [==============================] - 151s 333ms/step - loss: 0.1873 - precision: 0.8838 - recall: 0.7174 - f1_score: 0.0644 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8359 - val_loss: 0.1856 - val_precision: 0.8860 - val_recall: 0.7167 - val_f1_score: 0.0667 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8298
#
# Epoch 00028: val_loss did not improve from 0.18528
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# Epoch 29/80
# 442/442 [==============================] - 143s 315ms/step - loss: 0.1869 - precision: 0.8853 - recall: 0.7173 - f1_score: 0.0630 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8393 - val_loss: 0.1849 - val_precision: 0.8872 - val_recall: 0.7165 - val_f1_score: 0.0656 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8493
#
# Epoch 00029: val_loss improved from 0.18528 to 0.18488, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 30/80
# 442/442 [==============================] - 141s 308ms/step - loss: 0.1869 - precision: 0.8851 - recall: 0.7187 - f1_score: 0.0630 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8394 - val_loss: 0.1848 - val_precision: 0.8866 - val_recall: 0.7162 - val_f1_score: 0.0631 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8444
#
# Epoch 00030: val_loss improved from 0.18488 to 0.18477, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce_swa_1-10_3.h5
# Epoch 31/80
# 442/442 [==============================] - 154s 334ms/step - loss: 0.1867 - precision: 0.8846 - recall: 0.7171 - f1_score: 0.0633 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8375 - val_loss: 0.1849 - val_precision: 0.8864 - val_recall: 0.7154 - val_f1_score: 0.0629 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8419
#
# Epoch 00031: val_loss did not improve from 0.18477
# Epoch 00031: early stopping
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 31

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 32/80
# 442/442 [==============================] - ETA: 0s - loss: 0.2021 - precision_1: 0.8884 - recall_1: 0.7159 - f1_score: 0.0948 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7856
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 224s 418ms/step - loss: 0.2021 - precision_1: 0.8884 - recall_1: 0.7159 - f1_score: 0.0948 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7856 - val_loss: 0.1653 - val_precision_1: 0.9050 - val_recall_1: 0.7805 - val_f1_score: 0.1487 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8359
#
# Epoch 00032: val_loss improved from inf to 0.16531, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 33/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1615 - precision_1: 0.9094 - recall_1: 0.7749 - f1_score: 0.1306 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8466 - val_loss: 0.1458 - val_precision_1: 0.9158 - val_recall_1: 0.8106 - val_f1_score: 0.1669 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8697
#
# Epoch 00033: val_loss improved from 0.16531 to 0.14575, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 34/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1481 - precision_1: 0.9134 - recall_1: 0.7995 - f1_score: 0.1446 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8675 - val_loss: 0.1350 - val_precision_1: 0.9226 - val_recall_1: 0.8272 - val_f1_score: 0.1796 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8860
#
# Epoch 00034: val_loss improved from 0.14575 to 0.13495, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 35/80
# 442/442 [==============================] - 178s 392ms/step - loss: 0.1392 - precision_1: 0.9168 - recall_1: 0.8155 - f1_score: 0.1551 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8785 - val_loss: 0.1282 - val_precision_1: 0.9245 - val_recall_1: 0.8362 - val_f1_score: 0.1868 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8949
#
# Epoch 00035: val_loss improved from 0.13495 to 0.12818, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 36/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1337 - precision_1: 0.9173 - recall_1: 0.8245 - f1_score: 0.1614 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8886 - val_loss: 0.1232 - val_precision_1: 0.9267 - val_recall_1: 0.8417 - val_f1_score: 0.1872 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9026
#
# Epoch 00036: val_loss improved from 0.12818 to 0.12324, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 37/80
# 442/442 [==============================] - 184s 409ms/step - loss: 0.1296 - precision_1: 0.9181 - recall_1: 0.8305 - f1_score: 0.1667 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8919 - val_loss: 0.1197 - val_precision_1: 0.9281 - val_recall_1: 0.8455 - val_f1_score: 0.1955 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9058
#
# Epoch 00037: val_loss improved from 0.12324 to 0.11972, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 38/80
# 442/442 [==============================] - 185s 412ms/step - loss: 0.1264 - precision_1: 0.9185 - recall_1: 0.8340 - f1_score: 0.1692 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8955 - val_loss: 0.1171 - val_precision_1: 0.9281 - val_recall_1: 0.8488 - val_f1_score: 0.1999 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9075
#
# Epoch 00038: val_loss improved from 0.11972 to 0.11709, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 39/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1238 - precision_1: 0.9199 - recall_1: 0.8377 - f1_score: 0.1739 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8984 - val_loss: 0.1149 - val_precision_1: 0.9275 - val_recall_1: 0.8530 - val_f1_score: 0.1981 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9087
#
# Epoch 00039: val_loss improved from 0.11709 to 0.11494, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 40/80
# 442/442 [==============================] - 178s 394ms/step - loss: 0.1215 - precision_1: 0.9200 - recall_1: 0.8415 - f1_score: 0.1756 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9022 - val_loss: 0.1131 - val_precision_1: 0.9299 - val_recall_1: 0.8544 - val_f1_score: 0.1991 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9088
#
# Epoch 00040: val_loss improved from 0.11494 to 0.11310, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 41/80
# 442/442 [==============================] - 177s 392ms/step - loss: 0.1198 - precision_1: 0.9204 - recall_1: 0.8429 - f1_score: 0.1778 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9027 - val_loss: 0.1115 - val_precision_1: 0.9299 - val_recall_1: 0.8561 - val_f1_score: 0.2014 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9098
#
# Epoch 00041: val_loss improved from 0.11310 to 0.11153, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 42/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1184 - precision_1: 0.9203 - recall_1: 0.8463 - f1_score: 0.1796 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9035 - val_loss: 0.1102 - val_precision_1: 0.9294 - val_recall_1: 0.8585 - val_f1_score: 0.1996 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9116
#
# Epoch 00042: val_loss improved from 0.11153 to 0.11019, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 43/80
# 442/442 [==============================] - 186s 412ms/step - loss: 0.1166 - precision_1: 0.9213 - recall_1: 0.8493 - f1_score: 0.1813 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9060 - val_loss: 0.1092 - val_precision_1: 0.9301 - val_recall_1: 0.8591 - val_f1_score: 0.2000 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9122
#
# Epoch 00043: val_loss improved from 0.11019 to 0.10917, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 44/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1155 - precision_1: 0.9217 - recall_1: 0.8515 - f1_score: 0.1847 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9066 - val_loss: 0.1083 - val_precision_1: 0.9297 - val_recall_1: 0.8615 - val_f1_score: 0.2013 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9126
#
# Epoch 00044: val_loss improved from 0.10917 to 0.10833, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 45/80
# 442/442 [==============================] - 185s 410ms/step - loss: 0.1137 - precision_1: 0.9233 - recall_1: 0.8532 - f1_score: 0.1859 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9100 - val_loss: 0.1074 - val_precision_1: 0.9290 - val_recall_1: 0.8634 - val_f1_score: 0.2034 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9120
#
# Epoch 00045: val_loss improved from 0.10833 to 0.10744, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 46/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1131 - precision_1: 0.9227 - recall_1: 0.8536 - f1_score: 0.1862 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9097 - val_loss: 0.1066 - val_precision_1: 0.9289 - val_recall_1: 0.8648 - val_f1_score: 0.2055 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9132
#
# Epoch 00046: val_loss improved from 0.10744 to 0.10663, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 47/80
# 442/442 [==============================] - 177s 392ms/step - loss: 0.1124 - precision_1: 0.9238 - recall_1: 0.8549 - f1_score: 0.1858 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9091 - val_loss: 0.1061 - val_precision_1: 0.9289 - val_recall_1: 0.8641 - val_f1_score: 0.2046 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9130
#
# Epoch 00047: val_loss improved from 0.10663 to 0.10609, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 48/80
# 442/442 [==============================] - 184s 410ms/step - loss: 0.1110 - precision_1: 0.9239 - recall_1: 0.8571 - f1_score: 0.1895 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9122 - val_loss: 0.1056 - val_precision_1: 0.9302 - val_recall_1: 0.8638 - val_f1_score: 0.2108 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9133
#
# Epoch 00048: val_loss improved from 0.10609 to 0.10555, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 49/80
# 442/442 [==============================] - 185s 411ms/step - loss: 0.1107 - precision_1: 0.9241 - recall_1: 0.8582 - f1_score: 0.1865 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9123 - val_loss: 0.1049 - val_precision_1: 0.9297 - val_recall_1: 0.8654 - val_f1_score: 0.2074 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9160
#
# Epoch 00049: val_loss improved from 0.10555 to 0.10488, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 50/80
# 442/442 [==============================] - 177s 393ms/step - loss: 0.1091 - precision_1: 0.9249 - recall_1: 0.8602 - f1_score: 0.1901 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9150 - val_loss: 0.1045 - val_precision_1: 0.9284 - val_recall_1: 0.8674 - val_f1_score: 0.2051 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9161
#
# Epoch 00050: val_loss improved from 0.10488 to 0.10453, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 51/80
# 442/442 [==============================] - 185s 412ms/step - loss: 0.1085 - precision_1: 0.9260 - recall_1: 0.8600 - f1_score: 0.1908 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9142 - val_loss: 0.1042 - val_precision_1: 0.9303 - val_recall_1: 0.8659 - val_f1_score: 0.2091 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9168
#
# Epoch 00051: val_loss improved from 0.10453 to 0.10422, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 52/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1078 - precision_1: 0.9260 - recall_1: 0.8616 - f1_score: 0.1927 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9151 - val_loss: 0.1036 - val_precision_1: 0.9282 - val_recall_1: 0.8686 - val_f1_score: 0.2062 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9158
#
# Epoch 00052: val_loss improved from 0.10422 to 0.10358, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 53/80
# 442/442 [==============================] - 179s 398ms/step - loss: 0.1071 - precision_1: 0.9255 - recall_1: 0.8628 - f1_score: 0.1928 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9162 - val_loss: 0.1032 - val_precision_1: 0.9301 - val_recall_1: 0.8682 - val_f1_score: 0.2109 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9182
#
# Epoch 00053: val_loss improved from 0.10358 to 0.10322, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 54/80
# 442/442 [==============================] - 179s 398ms/step - loss: 0.1064 - precision_1: 0.9264 - recall_1: 0.8639 - f1_score: 0.1925 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9170 - val_loss: 0.1028 - val_precision_1: 0.9285 - val_recall_1: 0.8705 - val_f1_score: 0.2068 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9193
#
# Epoch 00054: val_loss improved from 0.10322 to 0.10280, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 55/80
# 442/442 [==============================] - 180s 400ms/step - loss: 0.1065 - precision_1: 0.9261 - recall_1: 0.8638 - f1_score: 0.1923 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9200 - val_loss: 0.1024 - val_precision_1: 0.9306 - val_recall_1: 0.8682 - val_f1_score: 0.2097 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9214
#
# Epoch 00055: val_loss improved from 0.10280 to 0.10242, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 56/80
# 442/442 [==============================] - 188s 418ms/step - loss: 0.1055 - precision_1: 0.9269 - recall_1: 0.8647 - f1_score: 0.1951 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9206 - val_loss: 0.1022 - val_precision_1: 0.9281 - val_recall_1: 0.8715 - val_f1_score: 0.2116 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9210
#
# Epoch 00056: val_loss improved from 0.10242 to 0.10215, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 57/80
# 442/442 [==============================] - 186s 414ms/step - loss: 0.1049 - precision_1: 0.9270 - recall_1: 0.8662 - f1_score: 0.1941 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9206 - val_loss: 0.1020 - val_precision_1: 0.9296 - val_recall_1: 0.8700 - val_f1_score: 0.2108 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9224
#
# Epoch 00057: val_loss improved from 0.10215 to 0.10197, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 58/80
# 442/442 [==============================] - 187s 414ms/step - loss: 0.1043 - precision_1: 0.9270 - recall_1: 0.8662 - f1_score: 0.1952 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9206 - val_loss: 0.1014 - val_precision_1: 0.9282 - val_recall_1: 0.8724 - val_f1_score: 0.2091 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9208
#
# Epoch 00058: val_loss improved from 0.10197 to 0.10140, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 59/80
# 442/442 [==============================] - 186s 413ms/step - loss: 0.1039 - precision_1: 0.9283 - recall_1: 0.8681 - f1_score: 0.1954 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9203 - val_loss: 0.1013 - val_precision_1: 0.9286 - val_recall_1: 0.8705 - val_f1_score: 0.2082 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9229
#
# Epoch 00059: val_loss improved from 0.10140 to 0.10134, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 60/80
# 442/442 [==============================] - 179s 398ms/step - loss: 0.1038 - precision_1: 0.9264 - recall_1: 0.8675 - f1_score: 0.1922 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9215 - val_loss: 0.1011 - val_precision_1: 0.9309 - val_recall_1: 0.8694 - val_f1_score: 0.2094 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9221
#
# Epoch 00060: val_loss improved from 0.10134 to 0.10115, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 61/80
# 442/442 [==============================] - 187s 415ms/step - loss: 0.1030 - precision_1: 0.9291 - recall_1: 0.8691 - f1_score: 0.1949 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9227 - val_loss: 0.1007 - val_precision_1: 0.9281 - val_recall_1: 0.8736 - val_f1_score: 0.2103 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9230
#
# Epoch 00061: val_loss improved from 0.10115 to 0.10072, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 62/80
# 442/442 [==============================] - 179s 396ms/step - loss: 0.1024 - precision_1: 0.9281 - recall_1: 0.8704 - f1_score: 0.1983 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9236 - val_loss: 0.1009 - val_precision_1: 0.9288 - val_recall_1: 0.8719 - val_f1_score: 0.2129 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9233
#
# Epoch 00062: val_loss did not improve from 0.10072
# Epoch 63/80
# 442/442 [==============================] - 178s 395ms/step - loss: 0.1020 - precision_1: 0.9285 - recall_1: 0.8697 - f1_score: 0.1977 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9222 - val_loss: 0.1008 - val_precision_1: 0.9291 - val_recall_1: 0.8710 - val_f1_score: 0.2113 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9234
#
# Epoch 00063: val_loss did not improve from 0.10072
# Epoch 64/80
# 442/442 [==============================] - 176s 390ms/step - loss: 0.1015 - precision_1: 0.9302 - recall_1: 0.8703 - f1_score: 0.1981 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9224 - val_loss: 0.1002 - val_precision_1: 0.9274 - val_recall_1: 0.8743 - val_f1_score: 0.2079 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9245
#
# Epoch 00064: val_loss improved from 0.10072 to 0.10017, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 65/80
# 442/442 [==============================] - 171s 380ms/step - loss: 0.1012 - precision_1: 0.9289 - recall_1: 0.8713 - f1_score: 0.1987 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9222 - val_loss: 0.1002 - val_precision_1: 0.9277 - val_recall_1: 0.8743 - val_f1_score: 0.2108 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9206
#
# Epoch 00065: val_loss did not improve from 0.10017
# Epoch 66/80
# 442/442 [==============================] - 162s 360ms/step - loss: 0.1008 - precision_1: 0.9287 - recall_1: 0.8728 - f1_score: 0.1980 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9223 - val_loss: 0.1000 - val_precision_1: 0.9294 - val_recall_1: 0.8729 - val_f1_score: 0.2150 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9249
#
# Epoch 00066: val_loss improved from 0.10017 to 0.10003, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 67/80
# 442/442 [==============================] - 165s 364ms/step - loss: 0.1005 - precision_1: 0.9300 - recall_1: 0.8719 - f1_score: 0.1984 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9246 - val_loss: 0.0998 - val_precision_1: 0.9278 - val_recall_1: 0.8748 - val_f1_score: 0.2140 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9244
#
# Epoch 00067: val_loss improved from 0.10003 to 0.09984, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 68/80
# 442/442 [==============================] - 184s 412ms/step - loss: 0.0998 - precision_1: 0.9301 - recall_1: 0.8732 - f1_score: 0.1993 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9262 - val_loss: 0.1002 - val_precision_1: 0.9280 - val_recall_1: 0.8732 - val_f1_score: 0.2107 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9256
#
# Epoch 00068: val_loss did not improve from 0.09984
# Epoch 69/80
# 442/442 [==============================] - 186s 412ms/step - loss: 0.0989 - precision_1: 0.9317 - recall_1: 0.8752 - f1_score: 0.2021 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9272 - val_loss: 0.0994 - val_precision_1: 0.9279 - val_recall_1: 0.8741 - val_f1_score: 0.2112 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9265
#
# Epoch 00069: val_loss improved from 0.09984 to 0.09945, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 70/80
# 442/442 [==============================] - 186s 413ms/step - loss: 0.0989 - precision_1: 0.9307 - recall_1: 0.8754 - f1_score: 0.2005 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9271 - val_loss: 0.0993 - val_precision_1: 0.9261 - val_recall_1: 0.8766 - val_f1_score: 0.2111 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9265
#
# Epoch 00070: val_loss improved from 0.09945 to 0.09928, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 71/80
# 442/442 [==============================] - 189s 413ms/step - loss: 0.0982 - precision_1: 0.9321 - recall_1: 0.8763 - f1_score: 0.2023 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9283 - val_loss: 0.0993 - val_precision_1: 0.9279 - val_recall_1: 0.8760 - val_f1_score: 0.2156 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9263
#
# Epoch 00071: val_loss improved from 0.09928 to 0.09926, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
# Epoch 72/80
# 442/442 [==============================] - 189s 414ms/step - loss: 0.0982 - precision_1: 0.9313 - recall_1: 0.8767 - f1_score: 0.2010 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9282 - val_loss: 0.0994 - val_precision_1: 0.9292 - val_recall_1: 0.8729 - val_f1_score: 0.2094 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9257
#
# Epoch 00072: val_loss did not improve from 0.09926
# Epoch 73/80
# 442/442 [==============================] - 185s 413ms/step - loss: 0.0979 - precision_1: 0.9317 - recall_1: 0.8764 - f1_score: 0.2013 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9264 - val_loss: 0.0993 - val_precision_1: 0.9285 - val_recall_1: 0.8734 - val_f1_score: 0.2096 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9268
#
# Epoch 00073: val_loss did not improve from 0.09926
# Epoch 74/80
# 442/442 [==============================] - 171s 381ms/step - loss: 0.0969 - precision_1: 0.9332 - recall_1: 0.8783 - f1_score: 0.2008 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9286 - val_loss: 0.0988 - val_precision_1: 0.9279 - val_recall_1: 0.8758 - val_f1_score: 0.2173 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9263
#
# Epoch 00074: val_loss improved from 0.09926 to 0.09880, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-swa_1-10_3.h5
#         0.07090237,  0.10579231, -0.01518189, -0.12257221, -0.04495537,
#        -0.00976985,  0.03765861, -0.0765766 , -0.10124511, -0.1009203 ,
#         0.05407459, -0.14542146, -0.05629472,  0.02295101, -0.12446442,
#        -0.0410527 , -0.14329626, -0.20279224,  0.06839384, -0.18307385,
#        -0.18772744,  0.07044517,  0.16550171, -0.12562107, -0.06788442,
#        -0.15446818, -0.08262924,  0.27925473, -0.16749495, -0.24159445,
#        -0.02158736, -0.03979737, -0.01411046,  0.12286671,  0.20675084,
#        -0.00645521, -0.06877556, -0.1325706 , -0.11657935,  0.06042717,
#         0.00936724,  0.04941949,  0.32815534,  0.06571286,  0.18587786,
#         0.08293741, -0.08300063,  0.07187401,  0.0252879 ,  0.31299764,
#         0.18538447,  0.07811702, -0.26385245, -0.106653  ,  0.13703813,
#        -0.06850062,  0.00679771,  0.05629491, -0.14109138, -0.08304721,
#         0.13953401, -0.03576074, -0.26778546, -0.03069706, -0.25168312,
#         0.00908725, -0.02530287, -0.3215984 , -0.16535574, -0.18753307,
#         0.24748103,  0.01848199,  0.16048294, -0.15651499, -0.0210353 ,
#        -0.00274857, -0.20832448,  0.15559559,  0.04762374, -0.22140086,
#         0.14360802, -0.09496798,  0.10286286, -0.15476185,  0.02878039,
#         0.00651391, -0.05304246,  0.15376242, -0.24706043,  0.10813709,
#         0.09607989,  0.11982704, -0.01683741, -0.19548419, -0.01943276,
#         0.2610897 ,  0.15519303,  0.12825239, -0.22608152,  0.11715194,
#        -0.10263818, -0.22759035,  0.04057418, -0.07268378, -0.24580117,
#        -0.31374553, -0.15931185, -0.00058338,  0.0808579 ,  0.2997588 ,
#        -0.06205348], dtype=float32)> : 'block5b_project_bn/moving_mean_3935'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'block5b_project_bn/moving_variance:0' shape=(136,) dtype=float32, numpy=
# array([0.18200175, 0.15007953, 0.20929894, 0.217733  , 0.13834351,
#        0.21109499, 0.19802573, 0.38024807, 0.17906766, 0.13998868,
#        0.22355972, 0.18072984, 0.22189797, 0.14159302, 0.15410511,
#        0.35412362, 0.15443534, 0.21321829, 0.25977567, 0.15582156,
#        0.27520984, 0.20495155, 0.17653531, 0.30071205, 0.22658063,
#        0.19451728, 0.1518698 , 0.10476582, 0.15712789, 0.1728158 ,
# ...
#        1.0831262 , 2.1289828 , 0.8335974 , 1.0830842 , 1.1778436 ,
#        1.0807518 , 1.5868498 , 1.1105658 , 1.3671805 ], dtype=float32)> : 'block7a_project_bn/moving_variance_6347'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'block7b_expand_bn/moving_mean:0' shape=(2304,) dtype=float32, numpy=
# array([ 0.00080194,  0.00048666,  0.00034204, ...,  0.00033396,
#        -0.00021985,  0.00054329], dtype=float32)> : 'block7b_expand_bn/moving_mean_6391'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'block7b_expand_bn/moving_variance:0' shape=(2304,) dtype=float32, numpy=
# array([  3.0217109,   4.538727 ,   8.691082 , ...,   3.2637799,
#        269.9143   ,   6.419659 ], dtype=float32)> : 'block7b_expand_bn/moving_variance_6396'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable '
#        0.08566937, 0.05166331, 0.05811994, 0.04776064, 0.05387061,
#        0.05234374, 0.08208622, 0.04298222, 0.03580678, 0.07452454,
#        0.04805019, 0.05474178, 0.08577288, 0.08882152, 0.03934935,
#        0.04045229, 0.04595251, 0.08150584, 0.0441379 , 0.06792983,
#        0.076824  , 0.08495152, 0.03398881, 0.08736024, 0.09147453,
#        0.04729484, 0.07568665, 0.07492745, 0.08182684, 0.07729542,
#        0.04761338, 0.05834482, 0.08436215, 0.04457958, 0.04655684,
#        0.07218421, 0.06642192, 0.05849399, 0.04251413, 0.11493642,
#        0.05844784, 0.04787961, 0.0502007 , 0.05366302, 0.06317253,
#        0.06136464, 0.04984552, 0.04070223, 0.09621187, 0.06871022,
#        0.04896066, 0.10447726, 0.05831881, 0.05421559, 0.07864957,
#        0.05084737, 0.05522282, 0.0488404 , 0.10417334, 0.08140029,
#        0.08253278, 0.04104658, 0.06061948, 0.11938161, 0.06079602,
#        0.05983568, 0.03806462, 0.05016378, 0.04802938, 0.10090554,
#        0.09669391, 0.04731223, 0.05862401, 0.04218276, 0.05525423,
#        0.08012282, 0.05507857, 0.05638897, 0.05865554, 0.04421395,
#        0.06746642, 0.10062455, 0.05316969, 0.04419981, 0.05013893,
#        0.05002856, 0.05102814, 0.07949851, 0.0589819 , 0.05212666,
#        0.05270165, 0.04237219, 0.04274279, 0.03426183, 0.09667233,
#        0.07316774, 0.07151506, 0.04273029, 0.07450637, 0.07181862,
#        0.09036038, 0.04297512, 0.04895615, 0.04879288, 0.09991652,
#        0.06511033, 0.08588207, 0.09705106, 0.08320777, 0.07595083,
#        0.05798662, 0.09108444, 0.03966095, 0.05321922, 0.05472807,
#        0.0439341 , 0.06565204, 0.05237499, 0.10028734, 0.04257549,
#        0.0758232 , 0.05988383, 0.04663664, 0.03786105, 0.05911698,
#        0.03566466, 0.08217384, 0.09006113, 0.03920776, 0.13790418,
#        0.10998353, 0.03975108, 0.04416994, 0.03554221, 0.06604156,
#        0.05941908, 0.09882752, 0.10832762, 0.05499616, 0.04574201,
#        0.05612199, 0.05481406, 0.07198894, 0.05217   , 0.0767004 ,
#        0.04923824, 0.03953829, 0.07672461, 0.07044148, 0.05152098,
#        0.05844493, 0.0729894 , 0.053481  , 0.04736276, 0.04059086,
#        0.0581162 , 0.03851561, 0.11300523, 0.04749036], dtype=float32)> : 'block7b_project_bn/moving_variance_6581'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'top_bn/moving_mean:0' shape=(1536,) dtype=float32, numpy=
# array([-0.81882864, -0.719087  , -0.5725819 , ..., -0.69739914,
#        -0.9511366 , -0.73550177], dtype=float32)> : 'top_bn/moving_mean_6632'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))
# /usr/local/lib/python3.7/dist-packages/tensorflow_addons/optimizers/average_wrapper.py:139: UserWarning: Unable to assign average slot to <tf.Variable 'top_bn/moving_variance:0' shape=(1536,) dtype=float32, numpy=
# array([17.29757 , 23.10865 , 12.876937, ..., 16.174511, 12.534349,
#        25.927286], dtype=float32)> : 'top_bn/moving_variance_6637'
#   warnings.warn("Unable to assign average slot to {} : {}".format(var, e))

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ............................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  ...  support              label
# 0            0.8398           0.9331  ...     3696        agriculture
# 1            0.7864           0.9991  ...      103     artisinal_mine
# 2            0.1044           0.9986  ...      249        bare_ground
# 3            0.0000           1.0000  ...      101           blooming
# 4            0.0000           1.0000  ...       40          blow_down
# 5            0.9688           0.9222  ...     8473              clear
# 6            0.8447           0.9915  ...      657             cloudy
# 7            0.0000           1.0000  ...       22  conventional_mine
# 8            0.4273           0.9824  ...     1306        cultivation
# 9            0.5961           0.9890  ...     1114         habitation
# 10           0.6457           0.9851  ...      796               haze
# 11           0.9157           0.9843  ...     2170      partly_cloudy
# 12           0.9888           0.7420  ...    11189            primary
# 13           0.8163           0.9713  ...     2444               road
# 14           0.0300           0.9997  ...      100  selective_logging
# 15           0.0000           1.0000  ...       59         slash_burn
# 16           0.7499           0.9750  ...     2219              water
#
# [17 rows x 11 columns]

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
# %%bash
#
# if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#   mkdir -p /root/tensorflow_datasets/amazon-from-space/
#   gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
#   # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
#   #   /root/tensorflow_datasets/amazon-from-space/
# fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC
# To: /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
# 12.0GB [02:20, 85.7MB/s]

# %%
test_dataset = AmazonFromSpace.load('/root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer_swa_1-10_3.csv'), index=False)
answer.head()
# Out:
#    image_name                                   tags
# 0  test_17823                          clear primary
# 1  test_29423         agriculture clear primary road
# 2   file_7472  agriculture clear cultivation primary
# 3  file_11084                          clear primary
# 4  file_16408         agriculture clear primary road

# %%
while True:pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-534b7a74019f> in <module>()
# ----> 1 while True:pass
#
# KeyboardInterrupt:

# %%
answer.head()

# %%
nn
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7bd55e9bf39> in <module>()
# ----> 1 nn
#
# NameError: name 'nn' is not defined
