# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
import tensorflow_addons as tfa

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_virtual_device_configuration(d,
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10240)])
    #tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = './'
  data_dir = './datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = 1e-3
    
    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    optimizer = tfa.optimizers.AdamW(
      learning_rate=learning_rate,
      weight_decay=1e-4
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-adamw/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-adamw.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 120
    learning_rate = 1e-4

    loss = tf.losses.BinaryCrossentropy(from_logits=True)
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tfa.optimizers.AdamW(
      learning_rate=learning_rate,
      weight_decay=1e-4
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-adamw-ft/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
"""
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
"""
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.
# Cannot set memory growth on device when virtual devices configured

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
#%%time
#%%bash

#  if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
#    mkdir -p /root/tensorflow_datasets/amazon-from-space/

#    gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
    # If the above is not working:
    # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
    #    /root/tensorflow_datasets/amazon-from-space/
#  else
#    echo "Dir $data_path found. Skipping."
#  fi

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

from pathlib import Path

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# Overriding previous training at .//logs/amazon-from-space-mo444/eb6-ce-adamw/.
# Epoch 1/80
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 442/442 [==============================] - ETA: 0s - loss: 0.2616 - precision: 0.8644 - recall: 0.7166 - f1_score: 0.0803 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7604
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\tensorflow\python\keras\metrics.py:254: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   warnings.warn('Metric %s implements a `reset_states()` method; rename it '
# 442/442 [==============================] - 75s 148ms/step - loss: 0.2616 - precision: 0.8644 - recall: 0.7166 - f1_score: 0.0803 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7604 - val_loss: 0.2170 - val_precision: 0.8770 - val_recall: 0.7283 - val_f1_score: 0.0794 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7934
#
# Epoch 00001: val_loss improved from inf to 0.21701, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 2/80
# 442/442 [==============================] - 66s 144ms/step - loss: 0.2173 - precision: 0.8828 - recall: 0.7264 - f1_score: 0.0811 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7740 - val_loss: 0.2134 - val_precision: 0.8883 - val_recall: 0.7155 - val_f1_score: 0.0778 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7935
#
# Epoch 00002: val_loss improved from 0.21701 to 0.21342, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 3/80
# 442/442 [==============================] - 66s 145ms/step - loss: 0.2139 - precision: 0.8825 - recall: 0.7247 - f1_score: 0.0782 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7751 - val_loss: 0.2095 - val_precision: 0.8814 - val_recall: 0.7248 - val_f1_score: 0.0829 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7977
#
# Epoch 00003: val_loss improved from 0.21342 to 0.20952, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 4/80
# 442/442 [==============================] - 115s 255ms/step - loss: 0.2100 - precision: 0.8833 - recall: 0.7249 - f1_score: 0.0765 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7801 - val_loss: 0.2062 - val_precision: 0.8810 - val_recall: 0.7290 - val_f1_score: 0.0755 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8012
#
# Epoch 00004: val_loss improved from 0.20952 to 0.20619, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 5/80
# 442/442 [==============================] - 115s 255ms/step - loss: 0.2068 - precision: 0.8830 - recall: 0.7246 - f1_score: 0.0753 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7832 - val_loss: 0.2037 - val_precision: 0.8831 - val_recall: 0.7211 - val_f1_score: 0.0729 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7992
#
# Epoch 00005: val_loss improved from 0.20619 to 0.20369, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 6/80
# 442/442 [==============================] - 115s 255ms/step - loss: 0.2044 - precision: 0.8832 - recall: 0.7231 - f1_score: 0.0742 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7868 - val_loss: 0.2016 - val_precision: 0.8884 - val_recall: 0.7099 - val_f1_score: 0.0709 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8028
#
# Epoch 00006: val_loss improved from 0.20369 to 0.20159, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 7/80
# 442/442 [==============================] - 120s 267ms/step - loss: 0.2017 - precision: 0.8844 - recall: 0.7239 - f1_score: 0.0732 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7879 - val_loss: 0.1987 - val_precision: 0.8859 - val_recall: 0.7162 - val_f1_score: 0.0784 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8063
#
# Epoch 00007: val_loss improved from 0.20159 to 0.19874, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 8/80
# 442/442 [==============================] - 118s 263ms/step - loss: 0.1999 - precision: 0.8836 - recall: 0.7227 - f1_score: 0.0720 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7894 - val_loss: 0.1969 - val_precision: 0.8817 - val_recall: 0.7214 - val_f1_score: 0.0703 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8107
#
# Epoch 00008: val_loss improved from 0.19874 to 0.19692, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 9/80
# 442/442 [==============================] - 117s 261ms/step - loss: 0.1984 - precision: 0.8837 - recall: 0.7225 - f1_score: 0.0709 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7942 - val_loss: 0.1956 - val_precision: 0.8901 - val_recall: 0.7166 - val_f1_score: 0.0721 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8124
#
# Epoch 00009: val_loss improved from 0.19692 to 0.19562, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 10/80
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1970 - precision: 0.8830 - recall: 0.7203 - f1_score: 0.0691 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7971 - val_loss: 0.1946 - val_precision: 0.8790 - val_recall: 0.7202 - val_f1_score: 0.0651 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8154
#
# Epoch 00010: val_loss improved from 0.19562 to 0.19460, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 11/80
# 442/442 [==============================] - 116s 257ms/step - loss: 0.1958 - precision: 0.8836 - recall: 0.7213 - f1_score: 0.0690 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7919 - val_loss: 0.1934 - val_precision: 0.8915 - val_recall: 0.7111 - val_f1_score: 0.0722 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8174
#
# Epoch 00011: val_loss improved from 0.19460 to 0.19342, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 12/80
# 442/442 [==============================] - 119s 264ms/step - loss: 0.1949 - precision: 0.8832 - recall: 0.7212 - f1_score: 0.0704 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7984 - val_loss: 0.1925 - val_precision: 0.8840 - val_recall: 0.7184 - val_f1_score: 0.0716 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8155
#
# Epoch 00012: val_loss improved from 0.19342 to 0.19245, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 13/80
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1938 - precision: 0.8835 - recall: 0.7221 - f1_score: 0.0696 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8025 - val_loss: 0.1916 - val_precision: 0.8820 - val_recall: 0.7153 - val_f1_score: 0.0608 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8240
#
# Epoch 00013: val_loss improved from 0.19245 to 0.19164, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 14/80
# 442/442 [==============================] - 120s 266ms/step - loss: 0.1931 - precision: 0.8825 - recall: 0.7201 - f1_score: 0.0694 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8058 - val_loss: 0.1906 - val_precision: 0.8819 - val_recall: 0.7232 - val_f1_score: 0.0726 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8224
#
# Epoch 00014: val_loss improved from 0.19164 to 0.19062, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 15/80
# 442/442 [==============================] - 121s 268ms/step - loss: 0.1930 - precision: 0.8833 - recall: 0.7199 - f1_score: 0.0688 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8062 - val_loss: 0.1901 - val_precision: 0.8877 - val_recall: 0.7184 - val_f1_score: 0.0726 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8222
#
# Epoch 00015: val_loss improved from 0.19062 to 0.19009, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 16/80
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1921 - precision: 0.8831 - recall: 0.7204 - f1_score: 0.0679 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8096 - val_loss: 0.1905 - val_precision: 0.8842 - val_recall: 0.7140 - val_f1_score: 0.0680 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8305
#
# Epoch 00016: val_loss did not improve from 0.19009
# Epoch 17/80
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1915 - precision: 0.8842 - recall: 0.7218 - f1_score: 0.0679 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8067 - val_loss: 0.1895 - val_precision: 0.8811 - val_recall: 0.7171 - val_f1_score: 0.0649 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8241
#
# Epoch 00017: val_loss improved from 0.19009 to 0.18953, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 18/80
# 442/442 [==============================] - 122s 272ms/step - loss: 0.1914 - precision: 0.8841 - recall: 0.7216 - f1_score: 0.0678 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8117 - val_loss: 0.1895 - val_precision: 0.8847 - val_recall: 0.7128 - val_f1_score: 0.0658 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8273
#
# Epoch 00018: val_loss improved from 0.18953 to 0.18946, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 19/80
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1913 - precision: 0.8833 - recall: 0.7209 - f1_score: 0.0687 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8129 - val_loss: 0.1887 - val_precision: 0.8866 - val_recall: 0.7120 - val_f1_score: 0.0699 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8292
#
# Epoch 00019: val_loss improved from 0.18946 to 0.18872, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 20/80
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1909 - precision: 0.8832 - recall: 0.7211 - f1_score: 0.0668 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8155 - val_loss: 0.1888 - val_precision: 0.8852 - val_recall: 0.7167 - val_f1_score: 0.0634 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8360
#
# Epoch 00020: val_loss did not improve from 0.18872
# Epoch 21/80
# 442/442 [==============================] - 121s 269ms/step - loss: 0.1907 - precision: 0.8827 - recall: 0.7211 - f1_score: 0.0673 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8201 - val_loss: 0.1886 - val_precision: 0.8822 - val_recall: 0.7183 - val_f1_score: 0.0610 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8292
#
# Epoch 00021: val_loss improved from 0.18872 to 0.18855, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 22/80
# 442/442 [==============================] - 121s 269ms/step - loss: 0.1907 - precision: 0.8838 - recall: 0.7204 - f1_score: 0.0676 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8190 - val_loss: 0.1884 - val_precision: 0.8816 - val_recall: 0.7155 - val_f1_score: 0.0616 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8377
#
# Epoch 00022: val_loss improved from 0.18855 to 0.18844, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 23/80
# 442/442 [==============================] - 121s 269ms/step - loss: 0.1904 - precision: 0.8845 - recall: 0.7200 - f1_score: 0.0668 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8159 - val_loss: 0.1879 - val_precision: 0.8846 - val_recall: 0.7192 - val_f1_score: 0.0681 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8339
#
# Epoch 00023: val_loss improved from 0.18844 to 0.18791, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 24/80
# 442/442 [==============================] - 118s 262ms/step - loss: 0.1898 - precision: 0.8857 - recall: 0.7217 - f1_score: 0.0680 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8190 - val_loss: 0.1882 - val_precision: 0.8834 - val_recall: 0.7168 - val_f1_score: 0.0596 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8241
#
# Epoch 00024: val_loss did not improve from 0.18791
# Epoch 25/80
# 442/442 [==============================] - 121s 268ms/step - loss: 0.1903 - precision: 0.8834 - recall: 0.7193 - f1_score: 0.0666 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8160 - val_loss: 0.1880 - val_precision: 0.8846 - val_recall: 0.7160 - val_f1_score: 0.0679 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8352
#
# Epoch 00025: val_loss did not improve from 0.18791
# Epoch 26/80
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1900 - precision: 0.8825 - recall: 0.7202 - f1_score: 0.0681 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8172 - val_loss: 0.1879 - val_precision: 0.8882 - val_recall: 0.7107 - val_f1_score: 0.0702 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8291
#
# Epoch 00026: val_loss improved from 0.18791 to 0.18788, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 27/80
# 442/442 [==============================] - 118s 261ms/step - loss: 0.1902 - precision: 0.8834 - recall: 0.7202 - f1_score: 0.0678 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8149 - val_loss: 0.1884 - val_precision: 0.8790 - val_recall: 0.7161 - val_f1_score: 0.0610 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8367
#
# Epoch 00027: val_loss did not improve from 0.18788
# Epoch 28/80
# 442/442 [==============================] - 119s 265ms/step - loss: 0.1896 - precision: 0.8843 - recall: 0.7198 - f1_score: 0.0682 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8191 - val_loss: 0.1878 - val_precision: 0.8850 - val_recall: 0.7169 - val_f1_score: 0.0647 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8267
#
# Epoch 00028: val_loss improved from 0.18788 to 0.18782, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw.h5
# Epoch 29/80
# 442/442 [==============================] - 118s 261ms/step - loss: 0.1901 - precision: 0.8839 - recall: 0.7199 - f1_score: 0.0677 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8157 - val_loss: 0.1881 - val_precision: 0.8804 - val_recall: 0.7183 - val_f1_score: 0.0676 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8302
#
# Epoch 00029: val_loss did not improve from 0.18782
# Epoch 00029: early stopping
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 28

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# Epoch 29/120
# 442/442 [==============================] - 218s 466ms/step - loss: 0.1526 - precision_1: 0.9063 - recall_1: 0.8134 - f1_score: 0.1774 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8679 - val_loss: 0.1167 - val_precision_1: 0.9263 - val_recall_1: 0.8560 - val_f1_score: 0.1878 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9126
#
# Epoch 00029: val_loss improved from inf to 0.11667, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw-ft.h5
# Epoch 30/120
# 442/442 [==============================] - 208s 465ms/step - loss: 0.1189 - precision_1: 0.9197 - recall_1: 0.8539 - f1_score: 0.1996 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9132 - val_loss: 0.1109 - val_precision_1: 0.9335 - val_recall_1: 0.8560 - val_f1_score: 0.1999 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9181
#
# Epoch 00030: val_loss improved from 0.11667 to 0.11092, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw-ft.h5
# Epoch 31/120
# 442/442 [==============================] - 207s 464ms/step - loss: 0.1124 - precision_1: 0.9237 - recall_1: 0.8649 - f1_score: 0.2048 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9197 - val_loss: 0.1099 - val_precision_1: 0.9299 - val_recall_1: 0.8655 - val_f1_score: 0.2112 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9307
#
# Epoch 00031: val_loss improved from 0.11092 to 0.10993, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw-ft.h5
# Epoch 32/120
# 442/442 [==============================] - 209s 469ms/step - loss: 0.1099 - precision_1: 0.9255 - recall_1: 0.8695 - f1_score: 0.2074 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9252 - val_loss: 0.1086 - val_precision_1: 0.9329 - val_recall_1: 0.8650 - val_f1_score: 0.2127 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9281
#
# Epoch 00032: val_loss improved from 0.10993 to 0.10857, saving model to .//models/amazon-from-space-mo444\eb6-ce-adamw-ft.h5
# Epoch 33/120
# 442/442 [==============================] - 210s 472ms/step - loss: 0.1077 - precision_1: 0.9286 - recall_1: 0.8749 - f1_score: 0.2154 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9314 - val_loss: 0.1111 - val_precision_1: 0.9298 - val_recall_1: 0.8665 - val_f1_score: 0.2083 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9377
#
# Epoch 00033: val_loss did not improve from 0.10857
# Epoch 34/120
# 442/442 [==============================] - 213s 477ms/step - loss: 0.1058 - precision_1: 0.9313 - recall_1: 0.8793 - f1_score: 0.2196 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9336 - val_loss: 0.1128 - val_precision_1: 0.9290 - val_recall_1: 0.8638 - val_f1_score: 0.2389 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9341
#
# Epoch 00034: val_loss did not improve from 0.10857
# Epoch 35/120
# 442/442 [==============================] - 212s 476ms/step - loss: 0.1045 - precision_1: 0.9346 - recall_1: 0.8833 - f1_score: 0.2246 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9380 - val_loss: 0.1118 - val_precision_1: 0.9247 - val_recall_1: 0.8741 - val_f1_score: 0.2430 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9357
#
# Epoch 00035: val_loss did not improve from 0.10857
# Epoch 36/120
# 442/442 [==============================] - 212s 474ms/step - loss: 0.1037 - precision_1: 0.9342 - recall_1: 0.8859 - f1_score: 0.2297 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9415 - val_loss: 0.1140 - val_precision_1: 0.9275 - val_recall_1: 0.8692 - val_f1_score: 0.2472 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9373
#
# Epoch 00036: val_loss did not improve from 0.10857
# Epoch 37/120
# 442/442 [==============================] - 213s 477ms/step - loss: 0.1026 - precision_1: 0.9381 - recall_1: 0.8898 - f1_score: 0.2349 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9409 - val_loss: 0.1152 - val_precision_1: 0.9296 - val_recall_1: 0.8649 - val_f1_score: 0.2478 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9298
#
# Epoch 00037: val_loss did not improve from 0.10857
# Epoch 38/120
# 442/442 [==============================] - 216s 484ms/step - loss: 0.1013 - precision_1: 0.9400 - recall_1: 0.8930 - f1_score: 0.2382 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9435 - val_loss: 0.1165 - val_precision_1: 0.9291 - val_recall_1: 0.8650 - val_f1_score: 0.2688 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9291
#
# Epoch 00038: val_loss did not improve from 0.10857
# Epoch 39/120
# 442/442 [==============================] - 210s 470ms/step - loss: 0.1002 - precision_1: 0.9416 - recall_1: 0.8964 - f1_score: 0.2419 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9436 - val_loss: 0.1212 - val_precision_1: 0.9251 - val_recall_1: 0.8584 - val_f1_score: 0.2302 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9242
#
# Epoch 00039: val_loss did not improve from 0.10857
# Epoch 40/120
# 442/442 [==============================] - 208s 466ms/step - loss: 0.0992 - precision_1: 0.9439 - recall_1: 0.8985 - f1_score: 0.2447 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9441 - val_loss: 0.1203 - val_precision_1: 0.9306 - val_recall_1: 0.8608 - val_f1_score: 0.2373 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9292
#
# Epoch 00040: val_loss did not improve from 0.10857
# Epoch 41/120
# 442/442 [==============================] - 207s 465ms/step - loss: 0.0985 - precision_1: 0.9459 - recall_1: 0.9012 - f1_score: 0.2473 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9468 - val_loss: 0.1218 - val_precision_1: 0.9289 - val_recall_1: 0.8569 - val_f1_score: 0.2487 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9227
#
# Epoch 00041: val_loss did not improve from 0.10857
# Epoch 42/120
# 442/442 [==============================] - 208s 465ms/step - loss: 0.0971 - precision_1: 0.9474 - recall_1: 0.9038 - f1_score: 0.2510 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9505 - val_loss: 0.1199 - val_precision_1: 0.9327 - val_recall_1: 0.8604 - val_f1_score: 0.2386 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9268
#
# Epoch 00042: val_loss did not improve from 0.10857
# Epoch 43/120
# 442/442 [==============================] - 205s 459ms/step - loss: 0.0962 - precision_1: 0.9479 - recall_1: 0.9066 - f1_score: 0.2546 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9516 - val_loss: 0.1224 - val_precision_1: 0.9286 - val_recall_1: 0.8580 - val_f1_score: 0.2685 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9275
#
# Epoch 00043: val_loss did not improve from 0.10857
# Epoch 44/120
# 442/442 [==============================] - 208s 465ms/step - loss: 0.0958 - precision_1: 0.9490 - recall_1: 0.9066 - f1_score: 0.2566 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9535 - val_loss: 0.1248 - val_precision_1: 0.9260 - val_recall_1: 0.8643 - val_f1_score: 0.2674 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9318
#
# Epoch 00044: val_loss did not improve from 0.10857
# Epoch 45/120
# 442/442 [==============================] - 208s 465ms/step - loss: 0.0956 - precision_1: 0.9502 - recall_1: 0.9084 - f1_score: 0.2561 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9534 - val_loss: 0.1262 - val_precision_1: 0.9263 - val_recall_1: 0.8542 - val_f1_score: 0.2470 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9259
#
# Epoch 00045: val_loss did not improve from 0.10857
# Epoch 46/120
# 442/442 [==============================] - 208s 466ms/step - loss: 0.0956 - precision_1: 0.9503 - recall_1: 0.9085 - f1_score: 0.2544 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9532 - val_loss: 0.1304 - val_precision_1: 0.9295 - val_recall_1: 0.8518 - val_f1_score: 0.2651 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9241
#
# Epoch 00046: val_loss did not improve from 0.10857
# Epoch 47/120
# 442/442 [==============================] - 208s 465ms/step - loss: 0.0950 - precision_1: 0.9503 - recall_1: 0.9099 - f1_score: 0.2544 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9562 - val_loss: 0.1272 - val_precision_1: 0.9325 - val_recall_1: 0.8461 - val_f1_score: 0.2355 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9234
#
# Epoch 00047: val_loss did not improve from 0.10857
# Epoch 48/120
# 442/442 [==============================] - 208s 465ms/step - loss: 0.0954 - precision_1: 0.9509 - recall_1: 0.9092 - f1_score: 0.2509 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9539 - val_loss: 0.1268 - val_precision_1: 0.9262 - val_recall_1: 0.8536 - val_f1_score: 0.2695 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9363
#
# Epoch 00048: val_loss did not improve from 0.10857
# Epoch 49/120
# 442/442 [==============================] - 208s 466ms/step - loss: 0.0956 - precision_1: 0.9503 - recall_1: 0.9085 - f1_score: 0.2547 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9561 - val_loss: 0.1306 - val_precision_1: 0.9128 - val_recall_1: 0.8543 - val_f1_score: 0.2404 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9311
#
# Epoch 00049: val_loss did not improve from 0.10857
# Epoch 00049: early stopping
#
# done

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ............................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# c:\users\rodri\.conda\envs\mo443\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  false positive r  false negative r  \
# 0            0.8363           0.9339            0.0661            0.1637
# 1            0.7670           0.9982            0.0018            0.2330
# 2            0.0924           0.9985            0.0015            0.9076
# 3            0.0000           1.0000            0.0000            1.0000
# 4            0.0000           1.0000            0.0000            1.0000
# 5            0.9746           0.9092            0.0908            0.0254
# 6            0.8295           0.9914            0.0086            0.1705
# 7            0.0000           1.0000            0.0000            1.0000
# 8            0.3737           0.9878            0.0122            0.6263
# 9            0.5583           0.9909            0.0091            0.4417
# 10           0.5992           0.9884            0.0116            0.4008
# 11           0.8834           0.9889            0.0111            0.1166
# 12           0.9870           0.7420            0.2580            0.0130
# 13           0.8171           0.9709            0.0291            0.1829
# 14           0.0000           1.0000            0.0000            1.0000
# 15           0.0000           1.0000            0.0000            1.0000
# 16           0.6832           0.9848            0.0152            0.3168
#
#     precision  recall  auc_score  f1_score  f2_score  support  \
# 0      0.8478  0.8363     0.9641    0.8420    0.8386     3696
# 1      0.7900  0.7670     0.9981    0.7783    0.7715      103
# 2      0.5610  0.0924     0.9275    0.1586    0.1109      249
# 3      0.0000  0.0000     0.8445    0.0000    0.0000      101
# 4      0.0000  0.0000     0.6955    0.0000    0.0000       40
# 5      0.9617  0.9746     0.9899    0.9681    0.9720     8473
# 6      0.8476  0.8295     0.9950    0.8385    0.8331      657
# 7      0.0000  0.0000     0.9722    0.0000    0.0000       22
# 8      0.7871  0.3737     0.9228    0.5067    0.4175     1306
# 9      0.8615  0.5583     0.9627    0.6776    0.6006     1114
# 10     0.7845  0.5992     0.9698    0.6795    0.6290      796
# 11     0.9457  0.8834     0.9934    0.9135    0.8952     2170
# 12     0.9792  0.9870     0.9790    0.9831    0.9854    11189
# 13     0.8766  0.8171     0.9785    0.8458    0.8284     2444
# 14     0.0000  0.0000     0.9053    0.0000    0.0000      100
# 15     0.0000  0.0000     0.9077    0.0000    0.0000       59
# 16     0.9100  0.6832     0.9620    0.7804    0.7190     2219
#
#                 label
# 0         agriculture
# 1      artisinal_mine
# 2         bare_ground
# 3            blooming
# 4           blow_down
# 5               clear
# 6              cloudy
# 7   conventional_mine
# 8         cultivation
# 9          habitation
# 10               haze
# 11      partly_cloudy
# 12            primary
# 13               road
# 14  selective_logging
# 15         slash_burn
# 16              water

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
#%%bash

#if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#  mkdir -p /root/tensorflow_datasets/amazon-from-space/
#  gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
  # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
  #   /root/tensorflow_datasets/amazon-from-space/
#fi

# %%
test_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer.csv'), index=False)
answer.head()
# Out:
#    image_name                                   tags
# 0  test_17823                          clear primary
# 1  test_29423         agriculture clear primary road
# 2   file_7472  agriculture clear cultivation primary
# 3  file_11084                          clear primary
# 4  file_16408         agriculture clear primary road
