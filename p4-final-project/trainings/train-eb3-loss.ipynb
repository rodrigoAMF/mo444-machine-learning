# %% [markdown]
# # Multi-label Amazon From Space

# %%
#@title

! pip -qq install tensorflow-addons
! pip install -qq -U tensorflow_datasets

IS_COLAB = 'google.colab' in str(get_ipython())

if IS_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')

import tensorflow as tf
import tensorflow_addons as tfa

for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
#      |████████████████████████████████| 686kB 1.9MB/s
#      |████████████████████████████████| 3.9MB 4.5MB/s
# Mounted at /content/drive
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
if IS_COLAB:
  base_dir = '/content/drive/MyDrive'
  data_dir = '/root/tensorflow_datasets'
else:
  base_dir = '/home/jonathan/Workspace'
  data_dir = '/home/jonathan/Workspace/datasets'


class Config:
  class data:
    path = f'{data_dir}/amazon-from-space'
    size = (256, 256)
    shape = (*size, 3)
    batch_size = 64
    shuffle_buffer_size = 8 * batch_size
    prefetch_buffer_size = tf.data.experimental.AUTOTUNE
    train_shuffle_seed = 2142
    shuffle = True

    valid_size = 0.3

    preprocess = tf.keras.applications.efficientnet.preprocess_input
    deprocess = lambda x: tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

  class aug:
    brightness_delta =  .2
    saturation_lower =  .2
    saturation_upper = 1.0
    contrast_lower   =  .5
    contrast_upper   = 1.5
    hue_delta        =  .0
    
  class model:
    pool_layer = 'avg_pool'
    backbone = tf.keras.applications.EfficientNetB3

    build_options = {
      'predictions': {
        # 'kernel_regularizer': tf.keras.regularizers.L2(0.01),
        # 'bias_regularizer': tf.keras.regularizers.L2(0.01),
        # 'activity_regularizer': tf.keras.regularizers.L2(0.01),
      }
    }
  
  class training:
    epochs = 80
    learning_rate = .1
    
    # loss = tf.losses.BinaryCrossentropy(from_logits=True)
    loss = tfa.losses.SigmoidFocalCrossEntropy(
        from_logits=True
    )
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

  class fine_tuning:
    epochs = 120
    learning_rate = .01

    loss = tfa.losses.SigmoidFocalCrossEntropy(
        from_logits=True
    )
    # loss = tfa.losses.SigmoidFocalCrossEntropy(from_logits=True)
    optimizer = tf.optimizers.SGD(
      learning_rate=learning_rate,
      momentum=0.9,
      nesterov=True
    )

    logs    = f'{base_dir}/logs/amazon-from-space-mo444/eb6-ce-adamw-ft/'
    weights = f'{base_dir}/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5'

    callbacks = [
      tf.keras.callbacks.TerminateOnNaN(),
      tf.keras.callbacks.ModelCheckpoint(weights, save_best_only=True, save_weights_only=True, verbose=1),
      tf.keras.callbacks.TensorBoard(logs, profile_batch=0, histogram_freq=1),
      tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=0.0001, verbose=1),
      tf.keras.callbacks.EarlyStopping(patience=20, min_delta=0.01, verbose=1),
    ]

    unfreeze_layers = .6  # 60%
    frozen_bn = False

  class experiment:
    seed = 41248
    override = True

# %% [markdown]
# ## Setup

# %%
import os
import shutil
from math import ceil

from typing import List, Optional

import numpy as np
import pandas as pd
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import callbacks

# %%
for d in tf.config.list_physical_devices('GPU'):
  print(d)
  print(f'Setting device {d} to memory-growth mode.')
  try:
    tf.config.experimental.set_memory_growth(d, True)
  except Exception as e:
    print(e)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Setting device PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU') to memory-growth mode.

# %%
R = tf.random.Generator.from_seed(Config.experiment.seed, alg='philox')
C = np.asarray(sns.color_palette("Set1", 21))
CMAP = sns.color_palette("Set1", 21, as_cmap=True)

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
def opt_or_default(options):
  def _get_options(param):
    return options.get(param, {})
  
  return _get_options


def normalize(x, reduce_min=True, reduce_max=True):
  if reduce_min: x -= tf.reduce_min(x, axis=(-3, -2), keepdims=True)
  if reduce_max: x = tf.math.divide_no_nan(x, tf.reduce_max(x, axis=(-3, -2), keepdims=True))

  return x


def visualize(
    image,
    title=None,
    rows=2,
    cols=None,
    figsize=(16, 7.2),
    cmap=None
):
  if image is not None:
    if isinstance(image, (list, tuple)) or len(image.shape) > 3:  # many images
      plt.figure(figsize=figsize)
      cols = cols or ceil(len(image) / rows)
      for ix in range(len(image)):
        plt.subplot(rows, cols, ix+1)
        visualize(image[ix],
                 cmap=cmap,
                 title=title[ix] if title is not None and len(title) > ix else None)
      plt.tight_layout()
      return

    if isinstance(image, tf.Tensor): image = image.numpy()
    if image.shape[-1] == 1: image = image[..., 0]
    plt.imshow(image, cmap=cmap)
  
  if title is not None: plt.title(title)
  plt.axis('off')

# %%
tf.keras.Model
# Out:
# tensorflow.python.keras.engine.training.Model

# %%
def unfreeze_top_layers(
    model: tf.keras.Model,
    layers: float,
    freeze_bn: bool
):
  if not layers:
    model.trainable = False
    return

  model.trainable = True

  frozen_layer_ix = int((1-layers) * len(model.layers))
  for ix, l in enumerate(model.layers):
    l.trainable = (ix > frozen_layer_ix and
                   (not isinstance(l, tf.keras.layers.BatchNormalization) or
                    not freeze_bn))
  
  print(f'Unfreezing {layers:.0%} layers. Bottom-most is the {frozen_layer_ix}-nth layer ({model.layers[frozen_layer_ix].name}).')

# %% [markdown]
# ## Dataset

# %%
# %%time
# %%bash

if [ ! -d /root/tensorflow_datasets/amazon-from-space/ ]; then
  mkdir -p /root/tensorflow_datasets/amazon-from-space/

  gdown --id 11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N --output /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
  # If the above is not working:
  # cp /content/drive/MyDrive/datasets/amazon-from-space/train-jpg.tfrecords \
  #    /root/tensorflow_datasets/amazon-from-space/
else
  echo "Dir $data_path found. Skipping."
fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11DFKx6xQ2-I_zgZtvxUrCjq-50odGP5N
# To: /root/tensorflow_datasets/amazon-from-space/train-jpg.tfrecords
# 7.96GB [01:24, 94.6MB/s]
# CPU times: user 1.01 s, sys: 253 ms, total: 1.26 s
# Wall time: 3min 23s

# %%
class AmazonFromSpace:
    num_train_samples = 40479
    num_test_samples  = 61191

    classes_ = np.asarray(
        ['agriculture', 'artisinal_mine', 'bare_ground', 'blooming', 'blow_down',
         'clear', 'cloudy', 'conventional_mine', 'cultivation', 'habitation', 'haze',
         'partly_cloudy', 'primary', 'road', 'selective_logging', 'slash_burn', 'water'])

    @classmethod
    def int2str(cls, indices):
        return cls.classes_[indices]
    
    @staticmethod
    def _bytes_feature(value):
        return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value.tobytes()]))

    @staticmethod
    def _int64_feature(value):
        return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))
    
    @staticmethod
    def decode_fn(record_bytes):
        r = tf.io.parse_single_example(record_bytes, {
          'filename': tf.io.FixedLenFeature([], tf.string),
          'image': tf.io.FixedLenFeature([], tf.string),
          'height': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'width': tf.io.FixedLenFeature([], tf.int64, default_value=[256]),
          'channels': tf.io.FixedLenFeature([], tf.int64, default_value=[3]),
          'label': tf.io.VarLenFeature(tf.int64),
        })
        
        r['image'] = tf.reshape(tf.io.decode_raw(r['image'], tf.uint8),
                                (r['height'], r['width'], r['channels']))
        r['label'] = tf.sparse.to_dense(r['label'])

        return r
    
    @classmethod
    def load(cls, tfrecords_path):
        return tf.data.TFRecordDataset(tfrecords_path).map(cls.decode_fn, num_parallel_calls=tf.data.AUTOTUNE)

# %%
CLASSES = AmazonFromSpace.classes_
int2str = AmazonFromSpace.int2str
num_samples = AmazonFromSpace.num_train_samples
num_train_samples = int((1-Config.data.valid_size)*num_samples)
num_valid_samples = int(Config.data.valid_size*num_samples)

# %%
from functools import partial


@tf.function
def load_fn(d, augment=False):
  image = d['image']
  labels = d['label']

  image = tf.cast(image, tf.float32)
  image = tf.ensure_shape(image, Config.data.shape)
  image = (augment_policy_fn(image)
           if augment
           else default_policy_fn(image))
  
  image = Config.data.preprocess(image)

  return image, labels_to_one_hot(labels)


def labels_to_one_hot(labels):
  return tf.reduce_max(
      tf.one_hot(labels, depth=CLASSES.shape[0]),
    axis=0)


def prepare(ds, batch_size, cache=False, shuffle=False, augment=False):
  if cache: ds = ds.cache()
  if shuffle: ds = ds.shuffle(Config.data.shuffle_buffer_size, reshuffle_each_iteration=True, seed=Config.data.train_shuffle_seed)

  return (ds.map(partial(load_fn, augment=augment), num_parallel_calls=tf.data.AUTOTUNE)
            .batch(batch_size, drop_remainder=True)
            .prefetch(Config.data.prefetch_buffer_size))

# %%
def default_policy_fn(image):
  return image


def augment_policy_fn(image):
  seeds = R.make_seeds(6)

  image = tf.image.stateless_random_flip_left_right(image, seed=seeds[:, 0])
  image = tf.image.stateless_random_flip_up_down(image, seed=seeds[:, 1])
  image = tf.image.stateless_random_hue(image, Config.aug.hue_delta, seed=seeds[:, 2])
  image = tf.image.stateless_random_brightness(image, Config.aug.brightness_delta, seed=seeds[:, 3])
  image = tf.image.stateless_random_contrast(image, Config.aug.contrast_lower, Config.aug.contrast_upper, seed=seeds[:, 4])
  image = tf.image.stateless_random_saturation(image, Config.aug.saturation_lower, Config.aug.saturation_upper, seed=seeds[:, 5])

  return image

# %%
train_dataset = AmazonFromSpace.load(f'{data_dir}/amazon-from-space/train-jpg.tfrecords')
valid_dataset = train_dataset.take(num_valid_samples)
train_dataset = train_dataset.skip(num_valid_samples)

train = prepare(train_dataset, Config.data.batch_size, shuffle=True, augment=True)
valid = prepare(valid_dataset, Config.data.batch_size)

# %%
#@title

for stage, batches, samples in zip(('training', 'validation', 'testing'),
                                   (train, valid),
                                   (AmazonFromSpace.num_train_samples,
                                    num_valid_samples,
                                    AmazonFromSpace.num_test_samples)):
  print(stage)
  print(f'  {batches}')
  print(f'  samples: {samples}')
  print(f'  steps  : {samples // Config.data.batch_size}')
  print()
# Out:
# training
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 40479
#   steps  : 632
#
# validation
#   <PrefetchDataset shapes: ((64, 256, 256, 3), (64, 17)), types: (tf.float32, tf.float32)>
#   samples: 12143
#   steps  : 189

# %%
#@title

for images, labels in train.take(1):
  gt = [' '.join((e[:3] for e in CLASSES[l].astype(str))) for l in labels.numpy().astype(bool)]
  visualize(Config.data.deprocess(images[:16]), gt, rows=4, figsize=(12, 14));

# %% [markdown]
# ## Network

# %% [markdown]
# ### Backbone

# %%
print(f'Loading {Config.model.backbone.__name__}')

backbone = Config.model.backbone(
  classifier_activation=None,
  include_top=False,
  input_shape=Config.data.shape
)
# Out:
# Loading EfficientNetB3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 1s 0us/step

# %% [markdown]
# ### Classification Head

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Dropout, Dense


def build_classifier(opts):
  opts = opt_or_default(opts)

  x = tf.keras.Input(Config.data.shape, name='images')
  y = backbone(x)
  y = GlobalAveragePooling2D(name=Config.model.pool_layer)(y)
  y = Dense(len(CLASSES), name='predictions', **opts('predictions'))(y)

  return tf.keras.Model(
    inputs=x,
    outputs=y,
    name=f'clf_{Config.model.backbone.__name__}_voc12')

# %%
nn = build_classifier(Config.model.build_options)

# %%
tf.keras.utils.plot_model(nn, show_shapes=True)

# %% [markdown]
# ## Metrics

# %%
# Fix for tensorflow metrics that do not support
# sigmoid_crossentropy_with_logits, for some reason...

class FromLogitsMixin:
  def __init__(self, from_logits=False, *args, **kwargs):
    super().__init__(*args, **kwargs)
    self.from_logits = from_logits

  def update_state(self, y_true, y_pred, sample_weight=None):
    if self.from_logits:
      y_pred = tf.nn.sigmoid(y_pred)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
class AUC(FromLogitsMixin, tf.metrics.AUC):
  ...

class BinaryAccuracy(FromLogitsMixin, tf.metrics.BinaryAccuracy):
  ...

class TruePositives(FromLogitsMixin, tf.metrics.TruePositives):
  ...

class FalsePositives(FromLogitsMixin, tf.metrics.FalsePositives):
  ...

class TrueNegatives(FromLogitsMixin, tf.metrics.TrueNegatives):
  ...

class FalseNegatives(FromLogitsMixin, tf.metrics.FalseNegatives):
  ...

class Precision(FromLogitsMixin, tf.metrics.Precision):
  ...

class Recall(FromLogitsMixin, tf.metrics.Recall):
  ...

class F1Score(FromLogitsMixin, tfa.metrics.F1Score):
  ...

class MultiLabelConfusionMatrix(FromLogitsMixin, tfa.metrics.MultiLabelConfusionMatrix):
  ...

# %% [markdown]
# ## Training

# %%
def train_fn(
    epochs: int = 80,
    initial_epoch: int = 0,
    callbacks: Optional[List[tf.keras.callbacks.Callback]] = None,
    steps_per_epoch: Optional[int] = None,
    validation_steps: Optional[int] = None,

    logs: str = None,
    weights: str = None,
):
  try:
    if logs and os.path.exists(logs) and initial_epoch == 0:
      if not Config.experiment.override:
        raise ValueError(f'A training was found in {logs}. '
                         f'Either move it or set experiment.override to True.')

      print(f'Overriding previous training at {logs}.')
      shutil.rmtree(logs)
    
    if weights: os.makedirs(os.path.dirname(weights), exist_ok=True)

    nn.fit(
      train.repeat(),
      validation_data=valid.repeat(),
      epochs=epochs,
      steps_per_epoch=steps_per_epoch,
      validation_steps=validation_steps,
      initial_epoch=initial_epoch,
      callbacks=callbacks);

  except KeyboardInterrupt: print('\ninterrupted')
  else: print('\ndone')

# %%
print(Config.training.weights)
# Out:
# /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5

# %% [markdown]
# ### Top Classifier Training

# %%
backbone.trainable = False

# %%
nn.compile(
    optimizer=Config.training.optimizer,
    loss=Config.training.loss,
    metrics=[
      Precision(from_logits=True),
      Recall(from_logits=True),
      F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
      MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
      tf.metrics.AUC(multi_label=True, from_logits=True),
    ])

# %%
train_fn(
  epochs=Config.training.epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.training.callbacks,
  logs=Config.training.logs,
  weights=Config.training.weights,
)
# Out:
# Overriding previous training at /content/drive/MyDrive/logs/amazon-from-space-mo444/eb6-ce/.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/80
# 442/442 [==============================] - ETA: 0s - loss: 12.6294 - precision: 0.8721 - recall: 0.7066 - f1_score: 0.3375 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6617
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# 442/442 [==============================] - 207s 403ms/step - loss: 12.6294 - precision: 0.8721 - recall: 0.7066 - f1_score: 0.3375 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6617 - val_loss: 8.1986 - val_precision: 0.8920 - val_recall: 0.7122 - val_f1_score: 0.3460 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6865
#
# Epoch 00001: val_loss improved from inf to 8.19864, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 2/80
# 442/442 [==============================] - 176s 393ms/step - loss: 10.7489 - precision: 0.8869 - recall: 0.7252 - f1_score: 0.3747 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6866 - val_loss: 14.5996 - val_precision: 0.9131 - val_recall: 0.7554 - val_f1_score: 0.3544 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6731
#
# Epoch 00002: val_loss did not improve from 8.19864
# Epoch 3/80
# 442/442 [==============================] - 176s 393ms/step - loss: 10.1147 - precision: 0.8891 - recall: 0.7290 - f1_score: 0.3818 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6920 - val_loss: 9.6856 - val_precision: 0.9290 - val_recall: 0.6948 - val_f1_score: 0.3451 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6878
#
# Epoch 00003: val_loss did not improve from 8.19864
# Epoch 4/80
# 442/442 [==============================] - 187s 417ms/step - loss: 9.6519 - precision: 0.8909 - recall: 0.7330 - f1_score: 0.3868 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6945 - val_loss: 10.1270 - val_precision: 0.9176 - val_recall: 0.7007 - val_f1_score: 0.3552 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6832
#
# Epoch 00004: val_loss did not improve from 8.19864
# Epoch 5/80
# 442/442 [==============================] - 175s 390ms/step - loss: 9.7812 - precision: 0.8911 - recall: 0.7329 - f1_score: 0.3988 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.6986 - val_loss: 10.1028 - val_precision: 0.8973 - val_recall: 0.6883 - val_f1_score: 0.3661 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6948
#
# Epoch 00005: val_loss did not improve from 8.19864
# Epoch 6/80
# 442/442 [==============================] - 173s 387ms/step - loss: 9.7597 - precision: 0.8927 - recall: 0.7360 - f1_score: 0.4015 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7023 - val_loss: 8.9772 - val_precision: 0.9315 - val_recall: 0.7023 - val_f1_score: 0.3602 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.6870
#
# Epoch 00006: val_loss did not improve from 8.19864
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.05000000074505806.
# Epoch 7/80
# 442/442 [==============================] - 176s 389ms/step - loss: 5.8150 - precision: 0.9030 - recall: 0.7556 - f1_score: 0.4040 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7285 - val_loss: 5.3731 - val_precision: 0.8991 - val_recall: 0.7533 - val_f1_score: 0.3588 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7180
#
# Epoch 00007: val_loss improved from 8.19864 to 5.37307, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 8/80
# 442/442 [==============================] - 188s 419ms/step - loss: 5.0676 - precision: 0.9006 - recall: 0.7521 - f1_score: 0.3783 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7319 - val_loss: 5.2147 - val_precision: 0.9045 - val_recall: 0.7645 - val_f1_score: 0.3828 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7283
#
# Epoch 00008: val_loss improved from 5.37307 to 5.21473, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 9/80
# 442/442 [==============================] - 193s 399ms/step - loss: 4.9793 - precision: 0.8979 - recall: 0.7486 - f1_score: 0.3825 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7353 - val_loss: 5.0617 - val_precision: 0.9003 - val_recall: 0.7661 - val_f1_score: 0.3787 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7196
#
# Epoch 00009: val_loss improved from 5.21473 to 5.06168, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 10/80
# 442/442 [==============================] - 190s 421ms/step - loss: 4.8328 - precision: 0.8987 - recall: 0.7489 - f1_score: 0.3751 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7300 - val_loss: 4.9533 - val_precision: 0.8860 - val_recall: 0.7423 - val_f1_score: 0.3711 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7442
#
# Epoch 00010: val_loss improved from 5.06168 to 4.95327, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 11/80
# 442/442 [==============================] - 189s 420ms/step - loss: 4.9046 - precision: 0.8982 - recall: 0.7485 - f1_score: 0.3797 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7363 - val_loss: 5.2728 - val_precision: 0.8840 - val_recall: 0.7746 - val_f1_score: 0.3780 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7146
#
# Epoch 00011: val_loss did not improve from 4.95327
# Epoch 12/80
# 442/442 [==============================] - 189s 419ms/step - loss: 4.7832 - precision: 0.8983 - recall: 0.7488 - f1_score: 0.3796 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7333 - val_loss: 4.3010 - val_precision: 0.9000 - val_recall: 0.7611 - val_f1_score: 0.3572 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7400
#
# Epoch 00012: val_loss improved from 4.95327 to 4.30103, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 13/80
# 442/442 [==============================] - 179s 397ms/step - loss: 5.0578 - precision: 0.8977 - recall: 0.7471 - f1_score: 0.3759 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7391 - val_loss: 5.4559 - val_precision: 0.8831 - val_recall: 0.7702 - val_f1_score: 0.3362 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7272
#
# Epoch 00013: val_loss did not improve from 4.30103
# Epoch 14/80
# 442/442 [==============================] - 190s 421ms/step - loss: 4.8013 - precision: 0.8970 - recall: 0.7456 - f1_score: 0.3700 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7385 - val_loss: 5.0544 - val_precision: 0.8558 - val_recall: 0.7916 - val_f1_score: 0.3672 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7349
#
# Epoch 00014: val_loss did not improve from 4.30103
# Epoch 15/80
# 442/442 [==============================] - 189s 420ms/step - loss: 4.6961 - precision: 0.8975 - recall: 0.7467 - f1_score: 0.3753 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7368 - val_loss: 4.9111 - val_precision: 0.8967 - val_recall: 0.7564 - val_f1_score: 0.3591 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7289
#
# Epoch 00015: val_loss did not improve from 4.30103
# Epoch 16/80
# 442/442 [==============================] - 190s 421ms/step - loss: 4.6765 - precision: 0.8966 - recall: 0.7443 - f1_score: 0.3762 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7400 - val_loss: 4.9067 - val_precision: 0.8829 - val_recall: 0.7571 - val_f1_score: 0.3511 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7272
#
# Epoch 00016: val_loss did not improve from 4.30103
# Epoch 17/80
# 442/442 [==============================] - 183s 405ms/step - loss: 4.6978 - precision: 0.8969 - recall: 0.7461 - f1_score: 0.3783 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7409 - val_loss: 4.8710 - val_precision: 0.8984 - val_recall: 0.7539 - val_f1_score: 0.3512 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7234
#
# Epoch 00017: val_loss did not improve from 4.30103
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.02500000037252903.
# Epoch 18/80
# 442/442 [==============================] - 183s 405ms/step - loss: 3.0365 - precision: 0.9051 - recall: 0.7624 - f1_score: 0.3615 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7726 - val_loss: 3.1338 - val_precision: 0.9090 - val_recall: 0.7575 - val_f1_score: 0.3130 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7573
#
# Epoch 00018: val_loss improved from 4.30103 to 3.13379, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 19/80
# 442/442 [==============================] - 190s 421ms/step - loss: 2.6852 - precision: 0.9043 - recall: 0.7619 - f1_score: 0.3493 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7802 - val_loss: 2.9787 - val_precision: 0.9225 - val_recall: 0.7503 - val_f1_score: 0.3113 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7367
#
# Epoch 00019: val_loss improved from 3.13379 to 2.97875, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 20/80
# 442/442 [==============================] - 190s 420ms/step - loss: 2.5946 - precision: 0.9038 - recall: 0.7607 - f1_score: 0.3349 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7846 - val_loss: 2.6689 - val_precision: 0.9085 - val_recall: 0.7533 - val_f1_score: 0.2919 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7468
#
# Epoch 00020: val_loss improved from 2.97875 to 2.66894, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 21/80
# 442/442 [==============================] - 189s 419ms/step - loss: 2.5522 - precision: 0.9018 - recall: 0.7576 - f1_score: 0.3246 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7853 - val_loss: 2.6124 - val_precision: 0.8919 - val_recall: 0.7578 - val_f1_score: 0.2974 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7557
#
# Epoch 00021: val_loss improved from 2.66894 to 2.61244, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 22/80
# 442/442 [==============================] - 189s 419ms/step - loss: 2.4575 - precision: 0.9016 - recall: 0.7569 - f1_score: 0.3347 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7917 - val_loss: 2.6875 - val_precision: 0.8908 - val_recall: 0.7405 - val_f1_score: 0.2911 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7525
#
# Epoch 00022: val_loss did not improve from 2.61244
# Epoch 23/80
# 442/442 [==============================] - 188s 417ms/step - loss: 2.4252 - precision: 0.9005 - recall: 0.7541 - f1_score: 0.3151 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7821 - val_loss: 2.5969 - val_precision: 0.8816 - val_recall: 0.7656 - val_f1_score: 0.3029 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7588
#
# Epoch 00023: val_loss improved from 2.61244 to 2.59689, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 24/80
# 442/442 [==============================] - 189s 419ms/step - loss: 2.3917 - precision: 0.9010 - recall: 0.7572 - f1_score: 0.3234 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7876 - val_loss: 2.6567 - val_precision: 0.9020 - val_recall: 0.7585 - val_f1_score: 0.3016 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7541
#
# Epoch 00024: val_loss did not improve from 2.59689
# Epoch 25/80
# 442/442 [==============================] - 181s 401ms/step - loss: 2.4279 - precision: 0.9008 - recall: 0.7561 - f1_score: 0.3100 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7875 - val_loss: 2.4872 - val_precision: 0.9230 - val_recall: 0.7413 - val_f1_score: 0.2909 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7620
#
# Epoch 00025: val_loss improved from 2.59689 to 2.48721, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 26/80
# 442/442 [==============================] - 182s 402ms/step - loss: 2.3545 - precision: 0.9007 - recall: 0.7562 - f1_score: 0.3119 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7902 - val_loss: 2.8603 - val_precision: 0.8791 - val_recall: 0.7238 - val_f1_score: 0.2842 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7749
#
# Epoch 00026: val_loss did not improve from 2.48721
# Epoch 27/80
# 442/442 [==============================] - 181s 402ms/step - loss: 2.2640 - precision: 0.9000 - recall: 0.7543 - f1_score: 0.3110 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7902 - val_loss: 2.5735 - val_precision: 0.8890 - val_recall: 0.7330 - val_f1_score: 0.3082 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7518
#
# Epoch 00027: val_loss did not improve from 2.48721
# Epoch 28/80
# 442/442 [==============================] - 189s 419ms/step - loss: 2.2607 - precision: 0.9005 - recall: 0.7548 - f1_score: 0.3155 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7886 - val_loss: 2.3090 - val_precision: 0.9201 - val_recall: 0.7457 - val_f1_score: 0.2795 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7356
#
# Epoch 00028: val_loss improved from 2.48721 to 2.30897, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 29/80
# 442/442 [==============================] - 182s 403ms/step - loss: 2.3333 - precision: 0.8999 - recall: 0.7539 - f1_score: 0.3119 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7925 - val_loss: 2.4700 - val_precision: 0.9285 - val_recall: 0.7397 - val_f1_score: 0.2550 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7491
#
# Epoch 00029: val_loss did not improve from 2.30897
# Epoch 30/80
# 442/442 [==============================] - 190s 420ms/step - loss: 2.2976 - precision: 0.8990 - recall: 0.7519 - f1_score: 0.3024 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7919 - val_loss: 2.3172 - val_precision: 0.8902 - val_recall: 0.7684 - val_f1_score: 0.2918 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7467
#
# Epoch 00030: val_loss did not improve from 2.30897
# Epoch 31/80
# 442/442 [==============================] - 179s 397ms/step - loss: 2.2440 - precision: 0.8983 - recall: 0.7515 - f1_score: 0.3011 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7949 - val_loss: 3.4124 - val_precision: 0.9083 - val_recall: 0.7534 - val_f1_score: 0.2975 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7471
#
# Epoch 00031: val_loss did not improve from 2.30897
# Epoch 32/80
# 442/442 [==============================] - 189s 420ms/step - loss: 2.3677 - precision: 0.8982 - recall: 0.7513 - f1_score: 0.3067 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7918 - val_loss: 3.5641 - val_precision: 0.8846 - val_recall: 0.7629 - val_f1_score: 0.2971 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7462
#
# Epoch 00032: val_loss did not improve from 2.30897
# Epoch 33/80
# 442/442 [==============================] - 189s 418ms/step - loss: 2.2500 - precision: 0.8995 - recall: 0.7533 - f1_score: 0.3014 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.7950 - val_loss: 2.3564 - val_precision: 0.9142 - val_recall: 0.7540 - val_f1_score: 0.2580 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7536
#
# Epoch 00033: val_loss did not improve from 2.30897
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.012500000186264515.
# Epoch 34/80
# 442/442 [==============================] - 181s 401ms/step - loss: 1.5309 - precision: 0.9062 - recall: 0.7670 - f1_score: 0.2735 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8304 - val_loss: 1.5996 - val_precision: 0.9178 - val_recall: 0.7649 - val_f1_score: 0.2468 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7814
#
# Epoch 00034: val_loss improved from 2.30897 to 1.59955, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 35/80
# 442/442 [==============================] - 189s 419ms/step - loss: 1.3631 - precision: 0.9039 - recall: 0.7642 - f1_score: 0.2623 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8348 - val_loss: 1.5927 - val_precision: 0.8982 - val_recall: 0.7657 - val_f1_score: 0.2510 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7756
#
# Epoch 00035: val_loss improved from 1.59955 to 1.59268, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 36/80
# 442/442 [==============================] - 189s 419ms/step - loss: 1.3037 - precision: 0.9030 - recall: 0.7629 - f1_score: 0.2549 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8332 - val_loss: 1.4655 - val_precision: 0.8854 - val_recall: 0.7516 - val_f1_score: 0.2333 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8143
#
# Epoch 00036: val_loss improved from 1.59268 to 1.46553, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 37/80
# 442/442 [==============================] - 189s 419ms/step - loss: 1.3296 - precision: 0.9020 - recall: 0.7625 - f1_score: 0.2558 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8403 - val_loss: 1.5048 - val_precision: 0.8990 - val_recall: 0.7881 - val_f1_score: 0.2363 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7983
#
# Epoch 00037: val_loss did not improve from 1.46553
# Epoch 38/80
# 442/442 [==============================] - 190s 421ms/step - loss: 1.2471 - precision: 0.9025 - recall: 0.7625 - f1_score: 0.2554 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8421 - val_loss: 1.4307 - val_precision: 0.9201 - val_recall: 0.7291 - val_f1_score: 0.2264 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7693
#
# Epoch 00038: val_loss improved from 1.46553 to 1.43073, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 39/80
# 442/442 [==============================] - 192s 426ms/step - loss: 1.2125 - precision: 0.9022 - recall: 0.7615 - f1_score: 0.2502 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8450 - val_loss: 1.4700 - val_precision: 0.8695 - val_recall: 0.7768 - val_f1_score: 0.2148 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7794
#
# Epoch 00039: val_loss did not improve from 1.43073
# Epoch 40/80
# 442/442 [==============================] - 182s 402ms/step - loss: 1.1628 - precision: 0.9019 - recall: 0.7617 - f1_score: 0.2488 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8473 - val_loss: 1.4269 - val_precision: 0.8685 - val_recall: 0.7824 - val_f1_score: 0.2209 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7900
#
# Epoch 00040: val_loss improved from 1.43073 to 1.42690, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 41/80
# 442/442 [==============================] - 190s 420ms/step - loss: 1.1705 - precision: 0.9004 - recall: 0.7586 - f1_score: 0.2401 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8473 - val_loss: 1.2963 - val_precision: 0.8805 - val_recall: 0.7795 - val_f1_score: 0.2388 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7893
#
# Epoch 00041: val_loss improved from 1.42690 to 1.29631, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 42/80
# 442/442 [==============================] - 192s 424ms/step - loss: 1.1443 - precision: 0.9021 - recall: 0.7621 - f1_score: 0.2404 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8465 - val_loss: 1.4029 - val_precision: 0.9146 - val_recall: 0.7167 - val_f1_score: 0.2089 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7846
#
# Epoch 00042: val_loss did not improve from 1.29631
# Epoch 43/80
# 442/442 [==============================] - 181s 400ms/step - loss: 1.1124 - precision: 0.9004 - recall: 0.7589 - f1_score: 0.2376 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8507 - val_loss: 1.2451 - val_precision: 0.9042 - val_recall: 0.7584 - val_f1_score: 0.1891 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7935
#
# Epoch 00043: val_loss improved from 1.29631 to 1.24510, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 44/80
# 442/442 [==============================] - 190s 421ms/step - loss: 1.1050 - precision: 0.9005 - recall: 0.7591 - f1_score: 0.2422 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8436 - val_loss: 1.3264 - val_precision: 0.9248 - val_recall: 0.7055 - val_f1_score: 0.2029 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7842
#
# Epoch 00044: val_loss did not improve from 1.24510
# Epoch 45/80
# 442/442 [==============================] - 191s 424ms/step - loss: 1.1087 - precision: 0.8999 - recall: 0.7585 - f1_score: 0.2361 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8493 - val_loss: 1.1735 - val_precision: 0.9034 - val_recall: 0.7744 - val_f1_score: 0.1956 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8025
#
# Epoch 00045: val_loss improved from 1.24510 to 1.17352, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 46/80
# 442/442 [==============================] - 190s 421ms/step - loss: 1.0919 - precision: 0.8998 - recall: 0.7577 - f1_score: 0.2402 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8468 - val_loss: 1.4909 - val_precision: 0.8555 - val_recall: 0.7695 - val_f1_score: 0.1899 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7944
#
# Epoch 00046: val_loss did not improve from 1.17352
# Epoch 47/80
# 442/442 [==============================] - 190s 421ms/step - loss: 1.1080 - precision: 0.8995 - recall: 0.7564 - f1_score: 0.2387 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8495 - val_loss: 1.2148 - val_precision: 0.9028 - val_recall: 0.7572 - val_f1_score: 0.2184 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7820
#
# Epoch 00047: val_loss did not improve from 1.17352
# Epoch 48/80
# 442/442 [==============================] - 191s 423ms/step - loss: 1.1001 - precision: 0.8990 - recall: 0.7567 - f1_score: 0.2356 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8558 - val_loss: 1.3449 - val_precision: 0.8337 - val_recall: 0.7951 - val_f1_score: 0.1982 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8071
#
# Epoch 00048: val_loss did not improve from 1.17352
# Epoch 49/80
# 442/442 [==============================] - 182s 404ms/step - loss: 1.0623 - precision: 0.8997 - recall: 0.7564 - f1_score: 0.2348 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8502 - val_loss: 1.1809 - val_precision: 0.8658 - val_recall: 0.8137 - val_f1_score: 0.2000 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7968
#
# Epoch 00049: val_loss did not improve from 1.17352
# Epoch 50/80
# 442/442 [==============================] - 185s 410ms/step - loss: 1.0430 - precision: 0.8983 - recall: 0.7547 - f1_score: 0.2372 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8542 - val_loss: 1.2371 - val_precision: 0.9124 - val_recall: 0.7709 - val_f1_score: 0.2036 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.7858
#
# Epoch 00050: val_loss did not improve from 1.17352
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0062500000931322575.
# Epoch 51/80
# 442/442 [==============================] - 186s 412ms/step - loss: 0.7379 - precision: 0.9074 - recall: 0.7702 - f1_score: 0.2300 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8750 - val_loss: 0.8351 - val_precision: 0.9080 - val_recall: 0.7554 - val_f1_score: 0.1984 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8286
#
# Epoch 00051: val_loss improved from 1.17352 to 0.83513, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 52/80
# 442/442 [==============================] - 186s 412ms/step - loss: 0.6665 - precision: 0.9086 - recall: 0.7686 - f1_score: 0.2263 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8828 - val_loss: 0.8304 - val_precision: 0.9152 - val_recall: 0.7466 - val_f1_score: 0.1858 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8161
#
# Epoch 00052: val_loss improved from 0.83513 to 0.83043, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 53/80
# 442/442 [==============================] - 188s 415ms/step - loss: 0.6396 - precision: 0.9079 - recall: 0.7678 - f1_score: 0.2209 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8833 - val_loss: 0.7928 - val_precision: 0.8933 - val_recall: 0.7841 - val_f1_score: 0.2060 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8220
#
# Epoch 00053: val_loss improved from 0.83043 to 0.79282, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 54/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.6164 - precision: 0.9079 - recall: 0.7676 - f1_score: 0.2264 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8815 - val_loss: 0.7508 - val_precision: 0.9028 - val_recall: 0.7686 - val_f1_score: 0.1839 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8102
#
# Epoch 00054: val_loss improved from 0.79282 to 0.75084, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 55/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.6141 - precision: 0.9063 - recall: 0.7655 - f1_score: 0.2298 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8835 - val_loss: 0.7418 - val_precision: 0.9065 - val_recall: 0.7928 - val_f1_score: 0.1925 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8268
#
# Epoch 00055: val_loss improved from 0.75084 to 0.74180, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 56/80
# 442/442 [==============================] - 189s 418ms/step - loss: 0.5851 - precision: 0.9088 - recall: 0.7680 - f1_score: 0.2287 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8865 - val_loss: 0.7220 - val_precision: 0.9084 - val_recall: 0.7705 - val_f1_score: 0.2016 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8334
#
# Epoch 00056: val_loss improved from 0.74180 to 0.72197, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 57/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.5884 - precision: 0.9065 - recall: 0.7651 - f1_score: 0.2221 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8850 - val_loss: 0.7070 - val_precision: 0.9056 - val_recall: 0.7539 - val_f1_score: 0.1934 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8261
#
# Epoch 00057: val_loss improved from 0.72197 to 0.70703, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 58/80
# 442/442 [==============================] - 196s 435ms/step - loss: 0.5645 - precision: 0.9077 - recall: 0.7649 - f1_score: 0.2253 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8877 - val_loss: 0.6984 - val_precision: 0.8957 - val_recall: 0.7623 - val_f1_score: 0.2060 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8066
#
# Epoch 00058: val_loss improved from 0.70703 to 0.69836, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 59/80
# 442/442 [==============================] - 196s 435ms/step - loss: 0.5512 - precision: 0.9091 - recall: 0.7648 - f1_score: 0.2219 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8894 - val_loss: 0.6999 - val_precision: 0.9013 - val_recall: 0.7268 - val_f1_score: 0.1971 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8310
#
# Epoch 00059: val_loss did not improve from 0.69836
# Epoch 60/80
# 442/442 [==============================] - 196s 434ms/step - loss: 0.5426 - precision: 0.9087 - recall: 0.7643 - f1_score: 0.2244 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8931 - val_loss: 0.6686 - val_precision: 0.9263 - val_recall: 0.7155 - val_f1_score: 0.1859 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8242
#
# Epoch 00060: val_loss improved from 0.69836 to 0.66861, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 61/80
# 442/442 [==============================] - 196s 434ms/step - loss: 0.5399 - precision: 0.9080 - recall: 0.7620 - f1_score: 0.2210 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8866 - val_loss: 0.6741 - val_precision: 0.9054 - val_recall: 0.7674 - val_f1_score: 0.1788 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8302
#
# Epoch 00061: val_loss did not improve from 0.66861
# Epoch 62/80
# 442/442 [==============================] - 197s 436ms/step - loss: 0.5343 - precision: 0.9077 - recall: 0.7627 - f1_score: 0.2193 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8846 - val_loss: 0.6958 - val_precision: 0.9122 - val_recall: 0.7592 - val_f1_score: 0.1803 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8191
#
# Epoch 00062: val_loss did not improve from 0.66861
# Epoch 63/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.5209 - precision: 0.9088 - recall: 0.7625 - f1_score: 0.2224 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8897 - val_loss: 0.6485 - val_precision: 0.8978 - val_recall: 0.7836 - val_f1_score: 0.1847 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8179
#
# Epoch 00063: val_loss improved from 0.66861 to 0.64845, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 64/80
# 442/442 [==============================] - 189s 418ms/step - loss: 0.5257 - precision: 0.9081 - recall: 0.7616 - f1_score: 0.2124 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8914 - val_loss: 0.6428 - val_precision: 0.9199 - val_recall: 0.7105 - val_f1_score: 0.1860 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8333
#
# Epoch 00064: val_loss improved from 0.64845 to 0.64280, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 65/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.5110 - precision: 0.9091 - recall: 0.7619 - f1_score: 0.2182 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8942 - val_loss: 0.6391 - val_precision: 0.8952 - val_recall: 0.7493 - val_f1_score: 0.1765 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8189
#
# Epoch 00065: val_loss improved from 0.64280 to 0.63911, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 66/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.4972 - precision: 0.9092 - recall: 0.7607 - f1_score: 0.2213 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8925 - val_loss: 0.6242 - val_precision: 0.9089 - val_recall: 0.7367 - val_f1_score: 0.2031 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8379
#
# Epoch 00066: val_loss improved from 0.63911 to 0.62423, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 67/80
# 442/442 [==============================] - 187s 414ms/step - loss: 0.4883 - precision: 0.9098 - recall: 0.7630 - f1_score: 0.2210 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8933 - val_loss: 0.5957 - val_precision: 0.9197 - val_recall: 0.7440 - val_f1_score: 0.1921 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8405
#
# Epoch 00067: val_loss improved from 0.62423 to 0.59573, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 68/80
# 442/442 [==============================] - 197s 436ms/step - loss: 0.5054 - precision: 0.9087 - recall: 0.7600 - f1_score: 0.2159 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8935 - val_loss: 0.5921 - val_precision: 0.9138 - val_recall: 0.7367 - val_f1_score: 0.2243 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8348
#
# Epoch 00068: val_loss improved from 0.59573 to 0.59210, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 69/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.4881 - precision: 0.9093 - recall: 0.7601 - f1_score: 0.2213 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8927 - val_loss: 0.6054 - val_precision: 0.9035 - val_recall: 0.7399 - val_f1_score: 0.1969 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8298
#
# Epoch 00069: val_loss did not improve from 0.59210
# Epoch 70/80
# 442/442 [==============================] - 188s 417ms/step - loss: 0.4871 - precision: 0.9085 - recall: 0.7579 - f1_score: 0.2214 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8956 - val_loss: 0.5729 - val_precision: 0.9189 - val_recall: 0.7381 - val_f1_score: 0.2067 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8434
#
# Epoch 00070: val_loss improved from 0.59210 to 0.57295, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 71/80
# 442/442 [==============================] - 196s 435ms/step - loss: 0.4773 - precision: 0.9100 - recall: 0.7594 - f1_score: 0.2161 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8940 - val_loss: 0.5969 - val_precision: 0.8802 - val_recall: 0.7700 - val_f1_score: 0.1843 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8219
#
# Epoch 00071: val_loss did not improve from 0.57295
# Epoch 72/80
# 442/442 [==============================] - 196s 435ms/step - loss: 0.4656 - precision: 0.9103 - recall: 0.7596 - f1_score: 0.2241 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8983 - val_loss: 0.5722 - val_precision: 0.9230 - val_recall: 0.7368 - val_f1_score: 0.2066 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8310
#
# Epoch 00072: val_loss improved from 0.57295 to 0.57221, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 73/80
# 442/442 [==============================] - 197s 436ms/step - loss: 0.4646 - precision: 0.9107 - recall: 0.7605 - f1_score: 0.2244 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8936 - val_loss: 0.5640 - val_precision: 0.8958 - val_recall: 0.7525 - val_f1_score: 0.1960 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8227
#
# Epoch 00073: val_loss improved from 0.57221 to 0.56398, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 74/80
# 442/442 [==============================] - 197s 436ms/step - loss: 0.4714 - precision: 0.9086 - recall: 0.7566 - f1_score: 0.2198 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8925 - val_loss: 0.5748 - val_precision: 0.9178 - val_recall: 0.7432 - val_f1_score: 0.1837 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8352
#
# Epoch 00074: val_loss did not improve from 0.56398
# Epoch 75/80
# 442/442 [==============================] - 189s 418ms/step - loss: 0.4643 - precision: 0.9097 - recall: 0.7575 - f1_score: 0.2145 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8952 - val_loss: 0.5555 - val_precision: 0.9130 - val_recall: 0.7537 - val_f1_score: 0.2003 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8257
#
# Epoch 00075: val_loss improved from 0.56398 to 0.55548, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 76/80
# 442/442 [==============================] - 189s 417ms/step - loss: 0.4595 - precision: 0.9103 - recall: 0.7568 - f1_score: 0.2222 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8924 - val_loss: 0.5439 - val_precision: 0.9277 - val_recall: 0.7362 - val_f1_score: 0.1973 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8298
#
# Epoch 00076: val_loss improved from 0.55548 to 0.54392, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 77/80
# 442/442 [==============================] - 189s 419ms/step - loss: 0.4497 - precision: 0.9103 - recall: 0.7578 - f1_score: 0.2188 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.9011 - val_loss: 0.5621 - val_precision: 0.9260 - val_recall: 0.7485 - val_f1_score: 0.1820 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8383
#
# Epoch 00077: val_loss did not improve from 0.54392
# Epoch 78/80
# 442/442 [==============================] - 196s 435ms/step - loss: 0.4563 - precision: 0.9090 - recall: 0.7563 - f1_score: 0.2209 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8984 - val_loss: 0.5417 - val_precision: 0.9308 - val_recall: 0.7089 - val_f1_score: 0.1877 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8364
#
# Epoch 00078: val_loss improved from 0.54392 to 0.54171, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 79/80
# 442/442 [==============================] - 197s 436ms/step - loss: 0.4495 - precision: 0.9095 - recall: 0.7567 - f1_score: 0.2191 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8967 - val_loss: 0.5317 - val_precision: 0.9260 - val_recall: 0.7353 - val_f1_score: 0.1943 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8261
#
# Epoch 00079: val_loss improved from 0.54171 to 0.53165, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce.h5
# Epoch 80/80
# 442/442 [==============================] - 198s 438ms/step - loss: 0.4337 - precision: 0.9111 - recall: 0.7567 - f1_score: 0.2251 - Multilabel_confusion_matrix: 7072.0000 - auc: 0.8972 - val_loss: 0.5443 - val_precision: 0.8704 - val_recall: 0.8098 - val_f1_score: 0.1773 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc: 0.8211
#
# Epoch 00080: val_loss did not improve from 0.53165
#
# done

# %% [markdown]
# ### Fine-Tuning

# %%
trained_epochs = 79

backbone.trainable = False
nn.load_weights(Config.training.weights)

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.compile(
  optimizer=Config.fine_tuning.optimizer,
  loss=Config.fine_tuning.loss,
  metrics=[
    Precision(from_logits=True),
    Recall(from_logits=True),
    F1Score(num_classes=len(CLASSES), from_logits=True, average='macro'),
    MultiLabelConfusionMatrix(num_classes=len(CLASSES), from_logits=True),
    tf.metrics.AUC(multi_label=True, from_logits=True),
  ])
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
Config.fine_tuning.logs
# Out:
# '/content/drive/MyDrive/logs/amazon-from-space-mo444/eb6-ce-adamw-ft/'

# %%
train_fn(
  epochs=Config.fine_tuning.epochs,
  initial_epoch=trained_epochs,
  steps_per_epoch=num_train_samples // Config.data.batch_size,
  validation_steps=num_valid_samples // Config.data.batch_size,
  callbacks=Config.fine_tuning.callbacks,
  logs=Config.fine_tuning.logs,
  weights=Config.fine_tuning.weights,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric F1Score implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/metrics.py:257: UserWarning: Metric MultiLabelConfusionMatrix implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   'consistency.' % (self.__class__.__name__,))
# Epoch 80/120
# 442/442 [==============================] - 257s 575ms/step - loss: 4.2242 - precision_1: 0.7573 - recall_1: 0.4839 - f1_score: 0.1008 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.5911 - val_loss: 0.7188 - val_precision_1: 0.7498 - val_recall_1: 0.4646 - val_f1_score: 0.1164 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.7637
#
# Epoch 00080: val_loss did not improve from 0.24510
# Epoch 81/120
# 442/442 [==============================] - 258s 578ms/step - loss: 0.6309 - precision_1: 0.8525 - recall_1: 0.5223 - f1_score: 0.1108 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7046 - val_loss: 1.1036 - val_precision_1: 0.8471 - val_recall_1: 0.5695 - val_f1_score: 0.1264 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.7892
#
# Epoch 00081: val_loss did not improve from 0.24510
# Epoch 82/120
# 442/442 [==============================] - 271s 578ms/step - loss: 0.4428 - precision_1: 0.8915 - recall_1: 0.5585 - f1_score: 0.1178 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7526 - val_loss: 0.3161 - val_precision_1: 0.9008 - val_recall_1: 0.6133 - val_f1_score: 0.1036 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8520
#
# Epoch 00082: val_loss did not improve from 0.24510
# Epoch 83/120
# 442/442 [==============================] - 259s 577ms/step - loss: 0.3536 - precision_1: 0.9174 - recall_1: 0.5996 - f1_score: 0.1260 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.7885 - val_loss: 0.2834 - val_precision_1: 0.9401 - val_recall_1: 0.6444 - val_f1_score: 0.1479 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8705
#
# Epoch 00083: val_loss did not improve from 0.24510
# Epoch 84/120
# 442/442 [==============================] - 260s 579ms/step - loss: 0.3164 - precision_1: 0.9297 - recall_1: 0.6284 - f1_score: 0.1387 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8148 - val_loss: 0.2586 - val_precision_1: 0.9584 - val_recall_1: 0.6387 - val_f1_score: 0.1423 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8841
#
# Epoch 00084: val_loss did not improve from 0.24510
# Epoch 85/120
# 442/442 [==============================] - 259s 578ms/step - loss: 0.2980 - precision_1: 0.9331 - recall_1: 0.6423 - f1_score: 0.1446 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8302 - val_loss: 0.2769 - val_precision_1: 0.9426 - val_recall_1: 0.6877 - val_f1_score: 0.1645 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8704
#
# Epoch 00085: val_loss did not improve from 0.24510
# Epoch 86/120
# 442/442 [==============================] - 251s 560ms/step - loss: 0.2953 - precision_1: 0.9370 - recall_1: 0.6490 - f1_score: 0.1469 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8318 - val_loss: 0.2618 - val_precision_1: 0.9073 - val_recall_1: 0.7258 - val_f1_score: 0.1481 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8962
#
# Epoch 00086: val_loss did not improve from 0.24510
# Epoch 87/120
# 442/442 [==============================] - 260s 578ms/step - loss: 0.2846 - precision_1: 0.9394 - recall_1: 0.6573 - f1_score: 0.1526 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8436 - val_loss: 0.2511 - val_precision_1: 0.9716 - val_recall_1: 0.6190 - val_f1_score: 0.1721 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.8912
#
# Epoch 00087: val_loss did not improve from 0.24510
# Epoch 88/120
# 442/442 [==============================] - 259s 577ms/step - loss: 0.2721 - precision_1: 0.9408 - recall_1: 0.6661 - f1_score: 0.1498 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8597 - val_loss: 0.2855 - val_precision_1: 0.9110 - val_recall_1: 0.7337 - val_f1_score: 0.1363 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9009
#
# Epoch 00088: val_loss did not improve from 0.24510
# Epoch 89/120
# 442/442 [==============================] - 252s 561ms/step - loss: 0.2690 - precision_1: 0.9429 - recall_1: 0.6733 - f1_score: 0.1561 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8598 - val_loss: 0.2316 - val_precision_1: 0.9694 - val_recall_1: 0.6533 - val_f1_score: 0.1848 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9017
#
# Epoch 00089: val_loss improved from 0.24510 to 0.23158, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 90/120
# 442/442 [==============================] - 260s 579ms/step - loss: 0.2652 - precision_1: 0.9427 - recall_1: 0.6797 - f1_score: 0.1552 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8623 - val_loss: 0.2318 - val_precision_1: 0.9509 - val_recall_1: 0.7226 - val_f1_score: 0.1735 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9025
#
# Epoch 00090: val_loss did not improve from 0.23158
# Epoch 91/120
# 442/442 [==============================] - 259s 578ms/step - loss: 0.2600 - precision_1: 0.9442 - recall_1: 0.6882 - f1_score: 0.1575 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8688 - val_loss: 0.2311 - val_precision_1: 0.9469 - val_recall_1: 0.6987 - val_f1_score: 0.2033 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9093
#
# Epoch 00091: val_loss improved from 0.23158 to 0.23108, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 92/120
# 442/442 [==============================] - 251s 560ms/step - loss: 0.2541 - precision_1: 0.9456 - recall_1: 0.6932 - f1_score: 0.1557 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8774 - val_loss: 0.2427 - val_precision_1: 0.9401 - val_recall_1: 0.7148 - val_f1_score: 0.1168 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9167
#
# Epoch 00092: val_loss did not improve from 0.23108
# Epoch 93/120
# 442/442 [==============================] - 259s 578ms/step - loss: 0.2456 - precision_1: 0.9481 - recall_1: 0.7008 - f1_score: 0.1597 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8832 - val_loss: 0.2240 - val_precision_1: 0.9655 - val_recall_1: 0.6903 - val_f1_score: 0.1979 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9149
#
# Epoch 00093: val_loss improved from 0.23108 to 0.22396, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 94/120
# 442/442 [==============================] - 259s 578ms/step - loss: 0.2393 - precision_1: 0.9490 - recall_1: 0.7100 - f1_score: 0.1626 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8897 - val_loss: 0.2268 - val_precision_1: 0.9413 - val_recall_1: 0.7387 - val_f1_score: 0.1618 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9139
#
# Epoch 00094: val_loss did not improve from 0.22396
# Epoch 95/120
# 442/442 [==============================] - 251s 559ms/step - loss: 0.2397 - precision_1: 0.9488 - recall_1: 0.7111 - f1_score: 0.1658 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8900 - val_loss: 0.2190 - val_precision_1: 0.9569 - val_recall_1: 0.7375 - val_f1_score: 0.1580 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9166
#
# Epoch 00095: val_loss improved from 0.22396 to 0.21895, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 96/120
# 442/442 [==============================] - 252s 561ms/step - loss: 0.2362 - precision_1: 0.9496 - recall_1: 0.7132 - f1_score: 0.1620 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8888 - val_loss: 0.2055 - val_precision_1: 0.9591 - val_recall_1: 0.7413 - val_f1_score: 0.1602 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9227
#
# Epoch 00096: val_loss improved from 0.21895 to 0.20549, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 97/120
# 442/442 [==============================] - 259s 578ms/step - loss: 0.2381 - precision_1: 0.9506 - recall_1: 0.7147 - f1_score: 0.1619 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8899 - val_loss: 0.2138 - val_precision_1: 0.9480 - val_recall_1: 0.7543 - val_f1_score: 0.1383 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9146
#
# Epoch 00097: val_loss did not improve from 0.20549
# Epoch 98/120
# 442/442 [==============================] - 259s 578ms/step - loss: 0.2319 - precision_1: 0.9511 - recall_1: 0.7208 - f1_score: 0.1635 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8916 - val_loss: 0.2168 - val_precision_1: 0.9556 - val_recall_1: 0.7310 - val_f1_score: 0.1641 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9246
#
# Epoch 00098: val_loss did not improve from 0.20549
# Epoch 99/120
# 442/442 [==============================] - 252s 562ms/step - loss: 0.2267 - precision_1: 0.9518 - recall_1: 0.7225 - f1_score: 0.1672 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8992 - val_loss: 0.2207 - val_precision_1: 0.9492 - val_recall_1: 0.7502 - val_f1_score: 0.1508 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9283
#
# Epoch 00099: val_loss did not improve from 0.20549
# Epoch 100/120
# 442/442 [==============================] - 260s 579ms/step - loss: 0.2271 - precision_1: 0.9508 - recall_1: 0.7247 - f1_score: 0.1647 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.8987 - val_loss: 0.2045 - val_precision_1: 0.9680 - val_recall_1: 0.7112 - val_f1_score: 0.1897 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9218
#
# Epoch 00100: val_loss improved from 0.20549 to 0.20452, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 101/120
# 442/442 [==============================] - 260s 579ms/step - loss: 0.2240 - precision_1: 0.9524 - recall_1: 0.7292 - f1_score: 0.1662 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9042 - val_loss: 0.2012 - val_precision_1: 0.9566 - val_recall_1: 0.7568 - val_f1_score: 0.1644 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9304
#
# Epoch 00101: val_loss improved from 0.20452 to 0.20123, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 102/120
# 442/442 [==============================] - 252s 562ms/step - loss: 0.2207 - precision_1: 0.9525 - recall_1: 0.7309 - f1_score: 0.1681 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9052 - val_loss: 0.2004 - val_precision_1: 0.9502 - val_recall_1: 0.7644 - val_f1_score: 0.2226 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9310
#
# Epoch 00102: val_loss improved from 0.20123 to 0.20041, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 103/120
# 442/442 [==============================] - 260s 580ms/step - loss: 0.2174 - precision_1: 0.9537 - recall_1: 0.7353 - f1_score: 0.1700 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9057 - val_loss: 0.1955 - val_precision_1: 0.9644 - val_recall_1: 0.7387 - val_f1_score: 0.1804 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9342
#
# Epoch 00103: val_loss improved from 0.20041 to 0.19553, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 104/120
# 442/442 [==============================] - 252s 561ms/step - loss: 0.2225 - precision_1: 0.9528 - recall_1: 0.7298 - f1_score: 0.1698 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9010 - val_loss: 0.1885 - val_precision_1: 0.9647 - val_recall_1: 0.7504 - val_f1_score: 0.2116 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9333
#
# Epoch 00104: val_loss improved from 0.19553 to 0.18849, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 105/120
# 442/442 [==============================] - 260s 581ms/step - loss: 0.2147 - precision_1: 0.9539 - recall_1: 0.7368 - f1_score: 0.1750 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9105 - val_loss: 0.2026 - val_precision_1: 0.9629 - val_recall_1: 0.7302 - val_f1_score: 0.2100 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9355
#
# Epoch 00105: val_loss did not improve from 0.18849
# Epoch 106/120
# 442/442 [==============================] - 252s 561ms/step - loss: 0.2105 - precision_1: 0.9549 - recall_1: 0.7419 - f1_score: 0.1758 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9148 - val_loss: 0.1940 - val_precision_1: 0.9579 - val_recall_1: 0.7558 - val_f1_score: 0.1794 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9371
#
# Epoch 00106: val_loss did not improve from 0.18849
# Epoch 107/120
# 442/442 [==============================] - 260s 578ms/step - loss: 0.2088 - precision_1: 0.9548 - recall_1: 0.7453 - f1_score: 0.1760 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9121 - val_loss: 0.2038 - val_precision_1: 0.9450 - val_recall_1: 0.7718 - val_f1_score: 0.1805 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9380
#
# Epoch 00107: val_loss did not improve from 0.18849
# Epoch 108/120
# 442/442 [==============================] - 260s 580ms/step - loss: 0.2083 - precision_1: 0.9554 - recall_1: 0.7469 - f1_score: 0.1752 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9168 - val_loss: 0.1916 - val_precision_1: 0.9653 - val_recall_1: 0.7489 - val_f1_score: 0.1933 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9380
#
# Epoch 00108: val_loss did not improve from 0.18849
# Epoch 109/120
# 442/442 [==============================] - 260s 579ms/step - loss: 0.2088 - precision_1: 0.9560 - recall_1: 0.7458 - f1_score: 0.1725 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9183 - val_loss: 0.1910 - val_precision_1: 0.9617 - val_recall_1: 0.7540 - val_f1_score: 0.1796 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9431
#
# Epoch 00109: val_loss did not improve from 0.18849
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 110/120
# 442/442 [==============================] - 252s 561ms/step - loss: 0.1976 - precision_1: 0.9597 - recall_1: 0.7504 - f1_score: 0.1727 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9282 - val_loss: 0.1832 - val_precision_1: 0.9572 - val_recall_1: 0.7748 - val_f1_score: 0.1828 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9434
#
# Epoch 00110: val_loss improved from 0.18849 to 0.18325, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 111/120
# 442/442 [==============================] - 253s 563ms/step - loss: 0.1956 - precision_1: 0.9591 - recall_1: 0.7516 - f1_score: 0.1717 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9291 - val_loss: 0.1843 - val_precision_1: 0.9631 - val_recall_1: 0.7601 - val_f1_score: 0.1965 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9437
#
# Epoch 00111: val_loss did not improve from 0.18325
# Epoch 112/120
# 442/442 [==============================] - 261s 581ms/step - loss: 0.1940 - precision_1: 0.9599 - recall_1: 0.7542 - f1_score: 0.1743 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9304 - val_loss: 0.1867 - val_precision_1: 0.9594 - val_recall_1: 0.7620 - val_f1_score: 0.2218 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9442
#
# Epoch 00112: val_loss did not improve from 0.18325
# Epoch 113/120
# 442/442 [==============================] - 261s 581ms/step - loss: 0.1933 - precision_1: 0.9596 - recall_1: 0.7544 - f1_score: 0.1747 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9283 - val_loss: 0.1831 - val_precision_1: 0.9551 - val_recall_1: 0.7810 - val_f1_score: 0.1597 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9455
#
# Epoch 00113: val_loss improved from 0.18325 to 0.18310, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 114/120
# 442/442 [==============================] - 261s 583ms/step - loss: 0.1920 - precision_1: 0.9592 - recall_1: 0.7559 - f1_score: 0.1774 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9327 - val_loss: 0.1828 - val_precision_1: 0.9624 - val_recall_1: 0.7632 - val_f1_score: 0.1787 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9450
#
# Epoch 00114: val_loss improved from 0.18310 to 0.18285, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 115/120
# 442/442 [==============================] - 260s 580ms/step - loss: 0.1929 - precision_1: 0.9596 - recall_1: 0.7559 - f1_score: 0.1762 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9303 - val_loss: 0.1839 - val_precision_1: 0.9580 - val_recall_1: 0.7770 - val_f1_score: 0.2067 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9442
#
# Epoch 00115: val_loss did not improve from 0.18285
# Epoch 116/120
# 442/442 [==============================] - 261s 581ms/step - loss: 0.1924 - precision_1: 0.9590 - recall_1: 0.7565 - f1_score: 0.1784 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9307 - val_loss: 0.1773 - val_precision_1: 0.9656 - val_recall_1: 0.7670 - val_f1_score: 0.1731 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9442
#
# Epoch 00116: val_loss improved from 0.18285 to 0.17727, saving model to /content/drive/MyDrive/models/amazon-from-space-mo444/eb6-ce-adamw-ft.h5
# Epoch 117/120
# 442/442 [==============================] - 261s 582ms/step - loss: 0.1912 - precision_1: 0.9605 - recall_1: 0.7580 - f1_score: 0.1773 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9314 - val_loss: 0.1868 - val_precision_1: 0.9688 - val_recall_1: 0.7439 - val_f1_score: 0.2152 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9452
#
# Epoch 00117: val_loss did not improve from 0.17727
# Epoch 118/120
# 442/442 [==============================] - 261s 581ms/step - loss: 0.1906 - precision_1: 0.9597 - recall_1: 0.7573 - f1_score: 0.1798 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9329 - val_loss: 0.1807 - val_precision_1: 0.9596 - val_recall_1: 0.7743 - val_f1_score: 0.1793 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9456
#
# Epoch 00118: val_loss did not improve from 0.17727
# Epoch 119/120
# 442/442 [==============================] - 253s 563ms/step - loss: 0.1906 - precision_1: 0.9601 - recall_1: 0.7592 - f1_score: 0.1789 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9322 - val_loss: 0.1776 - val_precision_1: 0.9631 - val_recall_1: 0.7702 - val_f1_score: 0.2124 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9456
#
# Epoch 00119: val_loss did not improve from 0.17727
# Epoch 120/120
# 442/442 [==============================] - 260s 579ms/step - loss: 0.1908 - precision_1: 0.9597 - recall_1: 0.7574 - f1_score: 0.1743 - Multilabel_confusion_matrix: 7072.0000 - auc_1: 0.9348 - val_loss: 0.1804 - val_precision_1: 0.9610 - val_recall_1: 0.7671 - val_f1_score: 0.2108 - val_Multilabel_confusion_matrix: 3024.0000 - val_auc_1: 0.9466
#
# Epoch 00120: val_loss did not improve from 0.17727
#
# done

# %% [markdown]
# ## Evaluation

# %%
#@title


def labels_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for i, (images, labels) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(labels)
    probs_.append(y)

    print('.', end='' if i % 80 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))


def evaluate(l, p):
  acc, tpr, fpr, tnr, fnr, auc, mcm = metrics_per_label(l, p)

  return pd.DataFrame({
    'accuracy': acc,
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'roc auc score': auc,
    'support': tf.cast(tf.reduce_sum(l, axis=0), tf.int32),
    'label': CLASSES
  })

# %%
unfreeze_top_layers(
  backbone,
  Config.fine_tuning.unfreeze_layers,
  Config.fine_tuning.frozen_bn
)

nn.load_weights(Config.fine_tuning.weights)
# Out:
# Unfreezing 60% layers. Bottom-most is the 153-nth layer (block4c_se_reshape).

# %%
l, p = labels_and_probs(nn, valid)
# Out:
# .
# ................................................................................
# ................................................................................
# ............................

# %%
from sklearn import metrics as skmetrics

def metrics_per_label(gt, probs, threshold=0.5):
  p_pred = tf.cast(probs > threshold, probs.dtype).numpy()

  tru_ = tf.reduce_sum(gt, axis=0)
  neg_ = tf.reduce_sum(1- gt, axis=0)

  tpr = tf.reduce_sum(p_pred*gt, axis=0) / tru_
  fpr = tf.reduce_sum(p_pred*(1-gt), axis=0) / neg_
  tnr = tf.reduce_sum((1-p_pred)*(1-gt), axis=0) / neg_
  fnr = tf.reduce_sum((1-p_pred)*gt, axis=0) / tru_

  f2_score = skmetrics.fbeta_score(gt, p_pred, beta=2, average=None)
  precision, recall, f1_score, support = skmetrics.precision_recall_fscore_support(
    gt, p_pred, average=None)

  mcm = skmetrics.multilabel_confusion_matrix(gt, p_pred)

  skmetrics.accuracy_score(gt, p_pred)

  return pd.DataFrame({
    'true positive r': tpr,
    'true negative r': tnr,
    'false positive r': fpr,
    'false negative r': fnr,
    'precision': precision,
    'recall': recall,
    'auc_score': skmetrics.roc_auc_score(gt, probs, average=None),
    'f1_score': f1_score,
    'f2_score': f2_score,
    'support': support,
    'label': CLASSES
  }), mcm

test_report, test_mcm = metrics_per_label(l, p)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_report.round(4)
# Out:
#     true positive r  true negative r  ...  support              label
# 0            0.5676           0.9810  ...     3696        agriculture
# 1            0.6019           0.9990  ...      103     artisinal_mine
# 2            0.0000           1.0000  ...      249        bare_ground
# 3            0.0000           1.0000  ...      101           blooming
# 4            0.0000           1.0000  ...       40          blow_down
# 5            0.9517           0.9415  ...     8473              clear
# 6            0.7656           0.9951  ...      657             cloudy
# 7            0.0000           1.0000  ...       22  conventional_mine
# 8            0.1041           0.9981  ...     1306        cultivation
# 9            0.1715           0.9990  ...     1114         habitation
# 10           0.4585           0.9929  ...      796               haze
# 11           0.8134           0.9935  ...     2170      partly_cloudy
# 12           0.9753           0.8037  ...    11189            primary
# 13           0.5892           0.9914  ...     2444               road
# 14           0.0000           0.9997  ...      100  selective_logging
# 15           0.0000           1.0000  ...       59         slash_burn
# 16           0.4984           0.9931  ...     2219              water
#
# [17 rows x 11 columns]

# %%
d = tf.cast(p > 0.5, tf.float32)
co_occurrence = tf.transpose(d) @ d
occurrence = tf.reshape(np.diag(co_occurrence), (-1, 1))

co_occurrence_rate = tf.math.divide_no_nan(co_occurrence, occurrence)

# %%
#@title Predictions Relation Matrix

plt.figure(figsize=(16, 6))
plt.subplot(121)
sns.heatmap(
  co_occurrence.numpy().astype(int),
  annot=True,
  fmt='d',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)

plt.subplot(122)
sns.heatmap(
  co_occurrence_rate.numpy(),
  annot=True,
  fmt='.0%',
  xticklabels=CLASSES,
  yticklabels=CLASSES,
  cmap="RdPu",
  cbar=False
)
plt.tight_layout();

# %% [markdown]
# ## Generate Answers

# %%
# %%bash
#
# if [ ! -f /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords ]; then
#   mkdir -p /root/tensorflow_datasets/amazon-from-space/
#   gdown --id 1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC --output /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
#   # cp /content/drive/MyDrive/datasets/amazon-from-space/test-jpg.tfrecords \
#   #   /root/tensorflow_datasets/amazon-from-space/
# fi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M0S88-D1J59kHPr2vG3hpFaS7n8fOsRC
# To: /root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords
# 12.0GB [02:15, 88.9MB/s]

# %%
test_dataset = AmazonFromSpace.load('/root/tensorflow_datasets/amazon-from-space/test-jpg.tfrecords')

# %%
test = (
  test_dataset
  .map(lambda item: (item['filename'], load_fn(item)[0]), num_parallel_calls=tf.data.AUTOTUNE)
  .batch(64)
  .prefetch(Config.data.prefetch_buffer_size))

# %%
def filenames_and_probs(nn, dataset):
  labels_ = []
  probs_ = []

  for ix, (files, images) in enumerate(dataset):
    y = nn(images, training=False)
    y = tf.nn.sigmoid(y)

    labels_.append(files)
    probs_.append(y)

    print('.', end='' if ix % 200 else '\n')
  
  return (tf.concat(labels_, axis=0),
          tf.concat(probs_, axis=0))

# %%
files, preds = filenames_and_probs(nn, test)
# Out:
# .
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ........................................................................................................................................................................................................
# ............................................................................................................................................................

# %%
detection_threshold = 0.5

answer = pd.DataFrame({
  'image_name': files.numpy().astype(str),
  'tags': [' '.join(AmazonFromSpace.int2str(p)) for p in (preds > detection_threshold).numpy()]
})
answer['image_name'] = answer.image_name.str.split('.').str[0]

answer.to_csv(os.path.join(Config.fine_tuning.logs, 'test_answer.csv'), index=False)
answer.head()
# Out:
#    image_name                            tags
# 0  test_17823                   clear primary
# 1  test_29423  agriculture clear primary road
# 2   file_7472       clear cultivation primary
# 3  file_11084                   clear primary
# 4  file_16408        agriculture primary road
